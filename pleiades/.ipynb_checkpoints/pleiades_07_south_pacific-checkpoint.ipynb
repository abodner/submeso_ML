# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import xarray as xr
import xgcm 


#2d data
HBL_path = '/scratch/ab10313/pleiades/test_regions/07_south_pacific/raw_data/ds_HBL.nc'
Q_path = '/scratch/ab10313/pleiades/test_regions/07_south_pacific/raw_data/ds_Q.nc'
TAUX_path = '/scratch/ab10313/pleiades/test_regions/07_south_pacific/raw_data/ds_TAUX.nc'
TAUY_path = '/scratch/ab10313/pleiades/test_regions/07_south_pacific/raw_data/ds_TAUY.nc'

#3d data
T_path = '/scratch/ab10313/pleiades/test_regions/07_south_pacific/raw_data/ds_T.nc'
S_path = '/scratch/ab10313/pleiades/test_regions/07_south_pacific/raw_data/ds_S.nc'
U_path = '/scratch/ab10313/pleiades/test_regions/07_south_pacific/raw_data/ds_U.nc'
V_path = '/scratch/ab10313/pleiades/test_regions/07_south_pacific/raw_data/ds_V.nc'
W_path = '/scratch/ab10313/pleiades/test_regions/07_south_pacific/raw_data/ds_W.nc'

# %%
ds_W = xr.open_dataset(W_path,engine="h5netcdf")
ds_W.W.isel(time=0,k_l=0).plot(cmap='bwr')

# %%
ds_V = xr.open_dataset(V_path,engine="h5netcdf")
ds_V.V.isel(time=0,k=40).plot(cmap='bwr')

# %%
ds_U = xr.open_dataset(U_path,engine="h5netcdf")
ds_U.U.isel(time=0,k=0).plot(cmap='bwr')

# %%
ds_T = xr.open_dataset(T_path,engine="h5netcdf")
ds_T.Theta.isel(time=0,k=0).plot(cmap='bwr')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /ext3/miniconda3/lib/python3.9/site-packages/xarray/backends/file_manager.py:201, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     200 try:
# --> 201     file = self._cache[self._key]
#     202 except KeyError:
#
# File /ext3/miniconda3/lib/python3.9/site-packages/xarray/backends/lru_cache.py:55, in LRUCache.__getitem__(self, key)
#      54 with self._lock:
# ---> 55     value = self._cache[key]
#      56     self._cache.move_to_end(key)
#
# KeyError: [<class 'h5netcdf.core.File'>, ('/scratch/ab10313/pleiades/test_regions/07_south_pacific/raw_data/ds_T.nc',), 'r', (('decode_vlen_strings', True), ('invalid_netcdf', None))]
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ...

# %%
ds_S = xr.open_dataset(S_path,engine="h5netcdf")
ds_S.Salt.isel(time=0,k=10).plot(cmap='bwr')

# %%
ds_TAUY = xr.open_dataset(TAUY_path,engine="h5netcdf")
ds_TAUY.oceTAUY.isel(time=0).plot(cmap='bwr')

# %%
ds_TAUX = xr.open_dataset(TAUX_path,engine="h5netcdf")
ds_TAUX.oceTAUX.isel(time=0).plot(cmap='bwr')

# %%
ds_Q = xr.open_dataset(Q_path,engine="h5netcdf")
ds_Q.oceQnet.isel(time=0).plot(cmap='bwr')

# %%
ds_HBL = xr.open_dataset(HBL_path,engine="h5netcdf")
ds_HBL.KPPhbl.isel(time=0).plot()
