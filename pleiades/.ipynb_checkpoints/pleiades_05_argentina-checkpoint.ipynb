# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import xarray as xr

#2d data
#HBL_path = '/scratch/ab10313/pleiades/05_argentina/2d_data/ds_HBL.nc'
#Q_path = '/scratch/ab10313/pleiades/05_argentina/2d_data/ds_Q.nc'
#TAUX_path = '/scratch/ab10313/pleiades/05_argentina/2d_data/ds_TAUX.nc'
#TAUY_path = '/scratch/ab10313/pleiades/05_argentina/2d_data/ds_TAUY.nc'

#3d data
#T_path = '/scratch/ab10313/pleiades/05_argentina/3d_data/ds_T.nc'
#S_path = '/scratch/ab10313/pleiades/05_argentina/3d_data/ds_S.nc'
#U_path = '/scratch/ab10313/pleiades/05_argentina/3d_data/ds_U.nc'
#V_path = '/scratch/ab10313/pleiades/05_argentina/3d_data/ds_V.nc'
W_path_old = '/scratch/ab10313/pleiades/05_argentina/3d_data/ds_W.nc'

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import xarray as xr

#smooth path
HBL_path = '/scratch/ab10313/pleiades/05_argentina_smooth/ds_HBL.nc'
Q_path = '/scratch/ab10313/pleiades/05_argentina_smooth/ds_Q.nc'
TAUX_path = '/scratch/ab10313/pleiades/05_argentina_smooth/ds_TAUX.nc'
TAUY_path = '/scratch/ab10313/pleiades/05_argentina_smooth/ds_TAUY.nc'
T_path = '/scratch/ab10313/pleiades/05_argentina_smooth/ds_T.nc'
S_path = '/scratch/ab10313/pleiades/05_argentina_smooth/ds_S.nc'
U_path = '/scratch/ab10313/pleiades/05_argentina_smooth/ds_U.nc'
V_path = '/scratch/ab10313/pleiades/05_argentina_smooth/ds_V.nc'
W_path = '/scratch/ab10313/pleiades/05_argentina_smooth/ds_W.nc'

# %%
ds_W = xr.open_dataset(W_path,engine="h5netcdf")
ds_W.W.isel(time=0,k_l=0).plot(cmap='bwr',vmin=-5e-6, vmax=5e-6)

# %%
ds_W_old = xr.open_dataset(W_path_old,engine="h5netcdf")
ds_W_old.W.isel(time=0,k_l=0).plot(cmap='bwr')

# %%
ds_V = xr.open_dataset(V_path,engine="h5netcdf")
ds_V.V.isel(time=800,k=40).plot(cmap='bwr')

# %%
ds_U = xr.open_dataset(U_path,engine="h5netcdf")
ds_U.U.isel(time=300,k=0).plot(cmap='bwr')

# %%
ds_T = xr.open_dataset(T_path,engine="h5netcdf")
ds_T.Theta.isel(time=800,k=0).plot(cmap='bwr')

# %%
ds_S = xr.open_dataset(S_path,engine="h5netcdf")
ds_S.Salt.isel(time=200,k=10).plot(cmap='bwr')

# %%
ds_TAUY = xr.open_dataset(TAUY_path,engine="h5netcdf")
ds_TAUY.oceTAUY.isel(time=315).plot(cmap='bwr')

# %%
ds_TAUX = xr.open_dataset(TAUX_path,engine="h5netcdf")
ds_TAUX.oceTAUX.isel(time=611).plot(cmap='bwr')

# %%
ds_Q = xr.open_dataset(Q_path,engine="h5netcdf")
ds_Q.oceQnet.isel(time=610).plot(cmap='bwr')

# %%
ds_HBL = xr.open_dataset(HBL_path,engine="h5netcdf")
ds_HBL.KPPhbl.isel(time=10).plot()
