# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import xarray as xr

#2d data
HBL_path = '/scratch/ab10313/pleiades/15_bengal_smooth/ds_HBL.nc'
Q_path = '/scratch/ab10313/pleiades/15_bengal_smooth/ds_Q.nc'
TAUX_path = '/scratch/ab10313/pleiades/15_bengal_smooth/ds_TAUX.nc'
TAUY_path = '/scratch/ab10313/pleiades/15_bengal_smooth/ds_TAUY.nc'

#3d data
T_path = '/scratch/ab10313/pleiades/15_bengal_smooth/ds_T.nc'
S_path = '/scratch/ab10313/pleiades/15_bengal_smooth/ds_S.nc'
U_path = '/scratch/ab10313/pleiades/15_bengal_smooth/ds_U.nc'
V_path = '/scratch/ab10313/pleiades/15_bengal_smooth/ds_V.nc'
W_path = '/scratch/ab10313/pleiades/15_bengal_smooth/ds_W.nc'

# %%
ds_W = xr.open_dataset(W_path,engine="h5netcdf")
ds_W.W.isel(time=805,k_l=40,i=slice(0,720)).plot(cmap='bwr')

# %%
ds_V = xr.open_dataset(V_path,engine="h5netcdf")
ds_V.V.isel(time=800,k=0,i=slice(0,720)).plot(cmap='bwr')

# %%
ds_U = xr.open_dataset(U_path,engine="h5netcdf")
ds_U.U.isel(time=300,k=0,i_g=slice(0,720)).plot(cmap='bwr')

# %%
ds_T = xr.open_dataset(T_path,engine="h5netcdf")
ds_T.Theta.isel(time=800,k=0,i=slice(0,720)).plot(cmap='bwr')

# %%
ds_T = xr.open_dataset(T_path,engine="h5netcdf")
ds_T.Theta.isel(time=800,k=40,i=slice(0,720)).plot(cmap='bwr')

# %%
ds_S = xr.open_dataset(S_path,engine="h5netcdf")
ds_S.Salt.isel(time=800,k=10,i=slice(0,720)).plot(cmap='bwr')

# %%
ds_TAUY = xr.open_dataset(TAUY_path,engine="h5netcdf")
ds_TAUY.oceTAUY.isel(time=115,i=slice(0,720)).plot(cmap='bwr')

# %%
ds_TAUX = xr.open_dataset(TAUX_path,engine="h5netcdf")
ds_TAUX.oceTAUX.isel(time=611,i_g=slice(0,720)).plot(cmap='bwr')

# %%
ds_Q = xr.open_dataset(Q_path,engine="h5netcdf")
ds_Q.oceQnet.isel(time=610,i=slice(0,720)).plot(cmap='bwr')

# %%
ds_HBL = xr.open_dataset(HBL_path,engine="h5netcdf")
ds_HBL.KPPhbl.isel(time=100,i=slice(0,720)).plot()
