# %%
import numpy as np
import matplotlib.pyplot as plt

CASE_NAME = 'agulhas/'
BASE = '/scratch/ab10313/submeso_ML_data/'
PATH = BASE+CASE_NAME

PATH_SNAP = PATH+'snapshots/'

lon = np.load(PATH_SNAP+'lon.npy')
lat = np.load(PATH_SNAP+'lat.npy')

lon_lowres = np.load('lon_lowres.npy')
lat_lowres = np.load('lat_lowres.npy')

# %%
B = np.load('B.npy')
plt.pcolor(lon,lat,B)
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
clb.ax.set_title('kg m s^-2')
plt.title('B')
plt.savefig('figures/B.png')

# %%
MLD = np.load('MLD.npy')
plt.pcolor(lon,lat,MLD)
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
clb.ax.set_title('m')
plt.title('MLD')
plt.savefig('figures/MLD.png')

# %%
U = np.load('U.npy')
plt.pcolor(lon,lat,U)
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
clb.ax.set_title('m/s')
plt.title('U')
plt.savefig('figures/U.png')

# %%
V = np.load('V.npy')
plt.pcolor(lon,lat,V)
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
clb.ax.set_title('m/s')
plt.title('V')
plt.savefig('figures/V.png')

# %%
W = np.load('W.npy')
plt.pcolor(lon,lat,W)
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
clb.ax.set_title('m/s')
plt.title('W')
plt.savefig('figures/W.png')

# %%
UsBs = np.load('UsBs.npy')
plt.pcolor(lon,lat,UsBs.transpose())
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
plt.title('UsBs')
plt.savefig('figures/UsBs.png')

# %%
VsBs = np.load('VsBs.npy')
plt.pcolor(lon,lat,VsBs.transpose())
plt.xlabel('lon')
plt.ylabel('lat')
plt.colorbar()
plt.title('VsBs')
plt.savefig('figures/VsBs.png')

# %%
WsBs = np.load('WsBs.npy')
plt.pcolor(lon,lat,WsBs.transpose())
plt.xlabel('lon')
plt.ylabel('lat')
plt.colorbar()
plt.title('WsBs')
plt.savefig('figures/WsBs.png')

# %%
Bm_x = np.load('Bm_x.npy')
plt.pcolor(lon,lat,Bm_x.transpose())
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
clb.ax.set_title('kg s^-2')
plt.title('Bm_x')
plt.savefig('figures/Bm_x.png')

# %%
Bm_y = np.load('Bm_y.npy')
plt.pcolor(lon,lat,Bm_y.transpose())
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
clb.ax.set_title('kg s^-2')
plt.title('Bm_y')
plt.savefig('figures/Bm_y.png')

# %%
Bm_z = np.load('Bm_z.npy')
plt.pcolor(lon,lat,Bm_z.transpose())
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
#clb.ax.set_title('kg s^-2')
plt.title('Bm_z')
plt.savefig('figures/Bm_z.png')

# %%
Um = np.load('Um.npy')
plt.pcolor(lon,lat,Um.transpose())
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
clb.ax.set_title('m/s')
plt.title('Um')
plt.savefig('figures/Um.png')

# %%
Vm = np.load('Vm.npy')
plt.pcolor(lon,lat,Vm.transpose())
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
clb.ax.set_title('m/s')
plt.title('Vm')
plt.savefig('figures/Vm.png')

# %%
Wm = np.load('Wm.npy')
plt.pcolor(lon,lat,Wm.transpose())
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
#clb.ax.set_title('m/s')
plt.title('Wm')
plt.savefig('figures/Wm.png')

# %%
Bm = np.load('Bm.npy')
plt.pcolor(lon,lat,Bm.transpose())
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
clb.ax.set_title('kg m s^-2')
plt.title('Bm')
plt.savefig('figures/Bm.png')

# %%
Us = np.load('Us.npy')
plt.pcolor(lon,lat,Us)
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
clb.ax.set_title('m/s')
plt.title('Us')
plt.savefig('figures/Us.png')

# %%
Vs = np.load('Vs.npy')
plt.pcolor(lon,lat,Vs)
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
clb.ax.set_title('m/s')
plt.title('Vs')
plt.savefig('figures/Vs.png')

# %%
Ws = np.load('Ws.npy')
plt.pcolor(lon,lat,Ws)
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
#clb.ax.set_title('m/s')
plt.title('Ws')
plt.savefig('figures/Ws.png')

# %%
Bs = np.load('Bs.npy')
plt.pcolor(lon,lat,Bs)
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
clb.ax.set_title('kg m s^-2')
plt.title('Bs')
plt.savefig('figures/Bs.png')

# %%
Bm_lowres = np.load('Bm_lowres.npy')
plt.pcolor(lat_lowres,lon_lowres,Bm_lowres)
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
clb.ax.set_title('kg m s^-2')
plt.title('Bm lowres')
plt.savefig('figures/Bm_lowres.png')

# %%
Um_lowres = np.load('Um_lowres.npy')
plt.pcolor(lat_lowres,lon_lowres,Um_lowres)
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
clb.ax.set_title('m/s')
plt.title('Um lowres')
plt.savefig('figures/Um_lowres.png')

# %%
Vm_lowres = np.load('Vm_lowres.npy')
plt.pcolor(lat_lowres,lon_lowres,Vm_lowres)
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
clb.ax.set_title('m/s')
plt.title('Vm lowres')
plt.savefig('figures/Vm_lowres.png')

# %%
Wm_lowres = np.load('Wm_lowres.npy')
plt.pcolor(lat_lowres,lon_lowres,Wm_lowres)
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
clb.ax.set_title('m/s')
plt.title('Wm lowres')
plt.savefig('figures/Wm_lowres.png')

# %%
UsBs_lowres = np.load('UsBs_lowres.npy')
plt.pcolor(lat_lowres,lon_lowres,UsBs_lowres)
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
#clb.ax.set_title('m/s')
plt.title('UsBs lowres')
plt.savefig('figures/UsBs_lowres.png')

# %%
VsBs_lowres = np.load('VsBs_lowres.npy')
plt.pcolor(lat_lowres,lon_lowres,VsBs_lowres)
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
#clb.ax.set_title('m/s')
plt.title('VsBs lowres')
plt.savefig('figures/VsBs_lowres.png')

# %%
WsBs_lowres = np.load('WsBs_lowres.npy')
plt.pcolor(lat_lowres,lon_lowres,WsBs_lowres)
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
#clb.ax.set_title('m/s')
plt.title('WsBs lowres')
plt.savefig('figures/WsBs_lowres.png')

# %%
Bm_x_lowres = np.load('Bm_x_lowres.npy')
plt.pcolor(lat_lowres,lon_lowres,Bm_x_lowres)
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
#clb.ax.set_title('m/s')
plt.title('Bm_x lowres')
plt.savefig('figures/Bm_x_lowres.png')

# %%
Bm_y_lowres = np.load('Bm_y_lowres.npy')
plt.pcolor(lat_lowres,lon_lowres,Bm_y_lowres)
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
clb.ax.set_title('kg s^-2')
plt.title('Bm_y lowres')
plt.savefig('figures/Bm_y_lowres.png')

# %%
Bm_z_lowres = np.load('Bm_z_lowres.npy')
plt.pcolor(lat_lowres,lon_lowres,Bm_z_lowres)
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
#clb.ax.set_title('kg s^-2')
plt.title('Bm_z lowres')
plt.savefig('figures/Bm_z_lowres.png')
