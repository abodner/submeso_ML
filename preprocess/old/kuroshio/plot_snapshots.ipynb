# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import xarray as xr

CASE_NAME = 'kuroshio/'
BASE = '/scratch/ab10313/submeso_ML_data/'
PATH = BASE+CASE_NAME

PATH_SNAP = PATH+'snapshots/'
#os.mkdir(PATH_SNAP+'figures/')

lon = np.load(PATH_SNAP+'lon.npy')
lat = np.load(PATH_SNAP+'lat.npy')

#lon_lowres = np.load(PATH_SNAP+'lon_lowres.npy')
#lat_lowres = np.load(PATH_SNAP+'lat_lowres.npy')

# %% [markdown]
# # Final preprocessed data: examples for single snapshot
# ## Filtered, averaged over MLD, and coarsed-grained

# %% [markdown]
# ## Load

# %%
# Load all datasets
PATH_PP = PATH+'preprocessed_data/'

# mesoscale fields
Bm_MLD_lowres = xr.open_dataarray(PATH_PP+'Bm_MLD_lowres.nc')
Um_MLD_lowres = xr.open_dataarray(PATH_PP+'Um_MLD_lowres.nc')
Vm_MLD_lowres = xr.open_dataarray(PATH_PP+'Vm_MLD_lowres.nc')
Wm_MLD_lowres = xr.open_dataarray(PATH_PP+'Wm_MLD_lowres.nc')

# submesoscale fields
UsBs_MLD_lowres = xr.open_dataarray(PATH_PP+'UsBs_MLD_lowres.nc')
VsBs_MLD_lowres = xr.open_dataarray(PATH_PP+'VsBs_MLD_lowres.nc')
WsBs_MLD_lowres = xr.open_dataarray(PATH_PP+'WsBs_MLD_lowres.nc')

# buoyancy gradients
Bm_x_MLD_lowres = xr.open_dataarray(PATH_PP+'Bm_x_MLD_lowres.nc')
Bm_y_MLD_lowres = xr.open_dataarray(PATH_PP+'Bm_y_MLD_lowres.nc')
Bm_z_MLD_lowres = xr.open_dataarray(PATH_PP+'Bm_z_MLD_lowres.nc')

# %% [markdown]
# ## Input

# %%
plt.pcolor(lat_lowres[:-2],lon_lowres[:],Bm_MLD_lowres[0,:,:-2])
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
clb.ax.set_title('kg m s^-2')
plt.title('Bm MLD lowres')
plt.savefig(PATH_SNAP+'figures/Bm_MLD_lowres.png')

# %%
plt.pcolor(lat_lowres[:-2],lon_lowres[:],Um_MLD_lowres[0,:,:-2])
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
clb.ax.set_title('m/s')
plt.title('Um MLD lowres')
plt.savefig(PATH_SNAP+'figures/Um_MLD_lowres.png')

# %%
plt.pcolor(lat_lowres[:-2],lon_lowres[:],Vm_MLD_lowres[0,:,:-2])
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
clb.ax.set_title('m/s')
plt.title('Vm MLD lowres')
plt.savefig(PATH_SNAP+'figures/Vm_MLD_lowres.png')

# %%
plt.pcolor(lat_lowres[:-3],lon_lowres[:],Wm_MLD_lowres[0,:,:-3])
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
clb.ax.set_title('m/s')
plt.title('Wm MLD lowres')
plt.savefig(PATH_SNAP+'figures/Wm_MLD_lowres.png')

# %% [markdown]
# ## Output

# %%
plt.pcolor(lat_lowres[:-3],lon_lowres[:],UsBs_MLD_lowres[0,:,:-3])
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
clb.ax.set_title('m/s')
plt.title('UsBs MLD lowres')
plt.savefig(PATH_SNAP+'figures/UsBs_MLD_lowres.png')

# %%
plt.pcolor(lat_lowres[:-3],lon_lowres[:],VsBs_MLD_lowres[0,:,:-3])
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
clb.ax.set_title('m/s')
plt.title('VsBs MLD lowres')
plt.savefig(PATH_SNAP+'figures/VsBs_MLD_lowres.png')

# %%
plt.pcolor(lat_lowres[:-3],lon_lowres[:],WsBs_MLD_lowres[0,:,:-3])
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
clb.ax.set_title('m/s')
plt.title('WsBs MLD lowres')
plt.savefig(PATH_SNAP+'figures/WsBs_MLD_lowres.png')

# %% [markdown]
# ## Loss

# %%
plt.pcolor(lat_lowres[:-3],lon_lowres[:],Bm_x_MLD_lowres[0,:,:-3])
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
#clb.ax.set_title('m/s')
plt.title('Bm_x MLD lowres')
plt.savefig(PATH_SNAP+'figures/Bm_x_MLD_lowres.png')

# %%
plt.pcolor(lat_lowres[:-3],lon_lowres[:],Bm_y_MLD_lowres[0,:,:-3])
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
#clb.ax.set_title('m/s')
plt.title('Bm_y MLD lowres')
plt.savefig(PATH_SNAP+'figures/Bm_y_MLD_lowres.png')

# %%
plt.pcolor(lat_lowres[:-3],lon_lowres[:],Bm_z_MLD_lowres[0,:,:-3])
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
#clb.ax.set_title('m/s')
plt.title('Bm_z MLD lowres')
plt.savefig(PATH_SNAP+'figures/Bm_z_MLD_lowres.png')

# %% [markdown]
# # Previous preprocessing steps: example for single snapshot

# %% [markdown]
# ## Full high resolution fields

# %%
B = np.load(PATH_SNAP+'B.npy')
plt.pcolor(lon,lat,B,cmap='Blues')
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
clb.ax.set_title('kg m s^-2')
plt.title('B')
plt.savefig(PATH_SNAP+'figures/B.png')

# %%
MLD = np.load(PATH_SNAP+'MLD.npy')
plt.pcolor(lon,lat,MLD)
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
clb.ax.set_title('m')
plt.title('MLD')
plt.savefig(PATH_SNAP+'figures/MLD.png')

# %%
U = np.load(PATH_SNAP+'U.npy')
plt.pcolor(lon[20:],lat,U[:,20:],cmap="Blues")
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
clb.ax.set_title('m/s')
plt.title('U')
plt.savefig(PATH_SNAP+'figures/U.png')

# %%
V = np.load(PATH_SNAP+'V.npy')
plt.pcolor(lon[20:],lat,V[:,20:])
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
clb.ax.set_title('m/s')
plt.title('V')
plt.savefig(PATH_SNAP+'figures/V.png')

# %%
W = np.load(PATH_SNAP+'W.npy')
plt.pcolor(lon,lat,W)
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
clb.ax.set_title('m/s')
plt.title('W')
plt.savefig(PATH_SNAP+'figures/W.png')

# %% [markdown]
# ## Filtered high reolution fields: surface and averaged over MLD

# %%
UsBs = np.load(PATH_SNAP+'UsBs.npy')
plt.pcolor(lon[20:],lat,UsBs.transpose()[:,20:])
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
plt.title('UsBs')
plt.savefig(PATH_SNAP+'figures/UsBs.png')

# %%
UsBs_MLD = np.load(PATH_SNAP+'UsBs_MLD.npy')
plt.pcolor(lon[20:],lat,UsBs_MLD.transpose()[:,20:])
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
plt.title('UsBs MLD')
plt.savefig(PATH_SNAP+'figures/UsBs_MLD.png')

# %%
VsBs = np.load(PATH_SNAP+'VsBs.npy')
plt.pcolor(lon[20:],lat,VsBs.transpose()[:,20:])
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
plt.title('VsBs')
plt.savefig(PATH_SNAP+'figures/VsBs.png')

# %%
VsBs_MLD = np.load(PATH_SNAP+'VsBs_MLD.npy')
plt.pcolor(lon[20:],lat,VsBs_MLD.transpose()[:,20:])
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
plt.title('VsBs MLD')
plt.savefig(PATH_SNAP+'figures/VsBs_MLD.png')

# %%
WsBs = np.load(PATH_SNAP+'WsBs.npy')
plt.pcolor(lon[20:],lat,WsBs.transpose()[:,20:])
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
plt.title('WsBs')
plt.savefig(PATH_SNAP+'figures/WsBs.png')

# %%
WsBs_MLD = np.load(PATH_SNAP+'WsBs_MLD.npy')
plt.pcolor(lon[20:],lat,WsBs_MLD.transpose()[:,20:])
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
plt.title('WsBs MLD')
plt.savefig(PATH_SNAP+'figures/WsBs_MLD.png')

# %%
Bm_x = np.load(PATH_SNAP+'Bm_x.npy')
plt.pcolor(lon[20:],lat,Bm_x.transpose()[:,20:])
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
clb.ax.set_title('kg s^-2')
plt.title('Bm_x')
plt.savefig(PATH_SNAP+'figures/Bm_x.png')

# %%
Bm_x_MLD = np.load(PATH_SNAP+'Bm_x_MLD.npy')
plt.pcolor(lon[20:],lat,Bm_x_MLD.transpose()[:,20:])
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
clb.ax.set_title('kg s^-2')
plt.title('Bm_x MLD')
plt.savefig(PATH_SNAP+'figures/Bm_x_MLD.png')

# %%
Bm_y = np.load(PATH_SNAP+'Bm_y.npy')
plt.pcolor(lon[20:],lat,Bm_y.transpose()[:,20:])
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
clb.ax.set_title('kg s^-2')
plt.title('Bm_y')
plt.savefig(PATH_SNAP+'figures/Bm_y.png')

# %%
Bm_y_MLD = np.load(PATH_SNAP+'Bm_y_MLD.npy')
plt.pcolor(lon[20:],lat,Bm_y_MLD.transpose()[:,20:])
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
clb.ax.set_title('kg s^-2')
plt.title('Bm_y_MLD')
plt.savefig(PATH_SNAP+'figures/Bm_y_MLD.png')

# %%
Bm_z = np.load(PATH_SNAP+'Bm_z.npy')
plt.pcolor(lon[20:],lat,Bm_z.transpose()[:,20:])
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
#clb.ax.set_title('kg s^-2')
plt.title('Bm_z')
plt.savefig(PATH_SNAP+'figures/Bm_z.png')

# %%
Bm_z_MLD = np.load(PATH_SNAP+'Bm_z_MLD.npy')
plt.pcolor(lon[20:],lat,Bm_z_MLD.transpose()[:,20:])
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
#clb.ax.set_title('kg s^-2')
plt.title('Bm_z MLD')
plt.savefig(PATH_SNAP+'figures/Bm_z_MLD.png')

# %%
Um = np.load(PATH_SNAP+'Um.npy')
plt.pcolor(lon[20:],lat,Um.transpose()[:,20:])
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
clb.ax.set_title('m/s')
plt.title('Um')
plt.savefig(PATH_SNAP+'figures/Um.png')

# %%
Um_MLD = np.load(PATH_SNAP+'Um_MLD.npy')
plt.pcolor(lon[20:],lat,Um_MLD.transpose()[:,20:])
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
clb.ax.set_title('m/s')
plt.title('Um MLD')
plt.savefig(PATH_SNAP+'figures/Um_MLD.png')

# %%
Vm = np.load(PATH_SNAP+'Vm.npy')
plt.pcolor(lon[20:],lat,Vm.transpose()[:,20:])
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
clb.ax.set_title('m/s')
plt.title('Vm')
plt.savefig(PATH_SNAP+'figures/Vm.png')

# %%
Vm_MLD = np.load(PATH_SNAP+'Vm_MLD.npy')
plt.pcolor(lon[20:],lat,Vm_MLD.transpose()[:,20:])
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
clb.ax.set_title('m/s')
plt.title('Vm MLD')
plt.savefig(PATH_SNAP+'figures/Vm_MLD.png')

# %%
Wm = np.load(PATH_SNAP+'Wm.npy')
plt.pcolor(lon[20:],lat,Wm.transpose()[:,20:])
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
#clb.ax.set_title('m/s')
plt.title('Wm')
plt.savefig(PATH_SNAP+'figures/Wm.png')

# %%
Wm_MLD = np.load(PATH_SNAP+'Wm_MLD.npy')
plt.pcolor(lon[20:],lat,Wm_MLD.transpose()[:,20:])
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
#clb.ax.set_title('m/s')
plt.title('Wm MLD')
plt.savefig(PATH_SNAP+'figures/Wm_MLD.png')

# %%
Bm = np.load(PATH_SNAP+'Bm.npy')
plt.pcolor(lon[20:],lat,Bm.transpose()[:,20:])
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
clb.ax.set_title('kg m s^-2')
plt.title('Bm')
plt.savefig(PATH_SNAP+'figures/Bm.png')

# %%
Bm_MLD = np.load(PATH_SNAP+'Bm_MLD.npy')
plt.pcolor(lon[20:],lat,Bm_MLD.transpose()[:,20:])
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
clb.ax.set_title('kg m s^-2')
plt.title('Bm MLD')
plt.savefig(PATH_SNAP+'figures/Bm_MLD.png')

# %%
Us = np.load(PATH_SNAP+'Us.npy')
plt.pcolor(lon[20:],lat,Us[:,20:])
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
clb.ax.set_title('m/s')
plt.title('Us')
plt.savefig(PATH_SNAP+'figures/Us.png')

# %%
Vs = np.load(PATH_SNAP+'Vs.npy')
plt.pcolor(lon[20:],lat,Vs[:,20:])
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
clb.ax.set_title('m/s')
plt.title('Vs')
plt.savefig(PATH_SNAP+'figures/Vs.png')

# %%
Ws = np.load(PATH_SNAP+'Ws.npy')
plt.pcolor(lon[20:],lat,Ws[:,20:])
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
#clb.ax.set_title('m/s')
plt.title('Ws')
plt.savefig(PATH_SNAP+'figures/Ws.png')

# %%
Bs = np.load(PATH_SNAP+'Bs.npy')
plt.pcolor(lon[20:],lat,Bs[:,20:])
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
clb.ax.set_title('kg m s^-2')
plt.title('Bs')
plt.savefig(PATH_SNAP+'figures/Bs.png')

# %%
Bm_lowres = np.load('Bm_lowres.npy')
plt.pcolor(lat_lowres,lon_lowres,Bm_lowres)
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
clb.ax.set_title('m/s')
plt.title('Bm lowres')
plt.savefig('figures/Bm_lowres.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /state/partition1/job-26139640/ipykernel_3135087/372251725.py in <module>
# ----> 1 Bm_MLD_lowres = np.load('Bm_MLD_lowres.npy')
#       2 plt.pcolor(lat_lowres,lon_lowres,Bm_MLD_lowres)
#       3 plt.xlabel('lon')
#       4 plt.ylabel('lat')
#       5 clb = plt.colorbar()
#
# /ext3/miniconda3/lib/python3.9/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     415             own_fid = False
#     416         else:
# --> 417             fid = stack.enter_context(open(os_fspath(file), "rb"))
#     418             own_fid = True
#     419
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Bm_MLD_lowres.npy'

# %%
Um_lowres = np.load('Um_lowres.npy')
plt.pcolor(lat_lowres,lon_lowres,Um_lowres)
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
clb.ax.set_title('m/s')
plt.title('Um lowres')
plt.savefig('figures/Um_lowres.png')

# %%
Vm_lowres = np.load('Vm_lowres.npy')
plt.pcolor(lat_lowres,lon_lowres,Vm_lowres)
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
clb.ax.set_title('m/s')
plt.title('Vm lowres')
plt.savefig('figures/Vm_lowres.png')

# %%
Wm_lowres = np.load('Wm_lowres.npy')
plt.pcolor(lat_lowres,lon_lowres,Wm_lowres)
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
clb.ax.set_title('m/s')
plt.title('Wm lowres')
plt.savefig('figures/Wm_lowres.png')

# %%
UsBs_lowres = np.load('UsBs_lowres.npy')
plt.pcolor(lat_lowres,lon_lowres,UsBs_lowres)
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
#clb.ax.set_title('m/s')
plt.title('UsBs lowres')
plt.savefig('figures/UsBs_lowres.png')

# %%
VsBs_lowres = np.load('VsBs_lowres.npy')
plt.pcolor(lat_lowres,lon_lowres,VsBs_lowres)
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
#clb.ax.set_title('m/s')
plt.title('VsBs lowres')
plt.savefig('figures/VsBs_lowres.png')

# %%
WsBs_lowres = np.load('WsBs_lowres.npy')
plt.pcolor(lat_lowres,lon_lowres,WsBs_lowres)
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
#clb.ax.set_title('m/s')
plt.title('WsBs lowres')
plt.savefig('figures/WsBs_lowres.png')

# %%
Bm_x_lowres = np.load('Bm_x_lowres.npy')
plt.pcolor(lat_lowres,lon_lowres,Bm_x_lowres)
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
#clb.ax.set_title('m/s')
plt.title('Bm_x lowres')
plt.savefig('figures/Bm_x_lowres.png')

# %%
Bm_y_lowres = np.load('Bm_y_lowres.npy')
plt.pcolor(lat_lowres,lon_lowres,Bm_y_lowres)
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
clb.ax.set_title('kg s^-2')
plt.title('Bm_y lowres')
plt.savefig('figures/Bm_y_lowres.png')

# %%
Bm_z_lowres = np.load('Bm_z_lowres.npy')
plt.pcolor(lat_lowres,lon_lowres,Bm_z_lowres)
plt.xlabel('lon')
plt.ylabel('lat')
clb = plt.colorbar()
#clb.ax.set_title('kg s^-2')
plt.title('Bm_z lowres')
plt.savefig('figures/Bm_z_lowres.png')
