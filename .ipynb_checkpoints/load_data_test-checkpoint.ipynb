# %%
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr

# %%
T_test = xr.open_dataset('/scratch/ab10313/submeso_ML_data/agulhas/raw_data/T.nc')

# %%
T_test.Theta.isel(time=0,k=0).plot()
