# %%
import torch
import torch.nn.functional as F
import torch.utils.data as Data
import torchvision
from torch import nn, optim
from torch.autograd import Variable
import numpy as np
import os
import glob
import xarray as xr
from sklearn import preprocessing
import netCDF4 as nc
import matplotlib.pyplot as plt



np.random.seed(14)  # For reproducibility
torch.manual_seed(14)  # For reproducibility

# %% [markdown]
# # Dataloader

# %% [markdown]
# ### Create input and output channels

# %%
# function that splits datasets along the spacial axes and concats them back into single array under time

def normalize(data):
    #normalized_data =  (data - data.mean(skipna=True).values)/data.std(skipna=True).values
    normalized_data = (data - np.mean(data))/np.std(data)
    return normalized_data


def load_norm_data(var_name_string):
    PATH_LIST = glob.glob(BASE+'*/preprocessed_data/'+var_name_string+'.nc') 
    data_app = normalize(xr.open_dataarray(PATH_LIST[0]).to_numpy()[:,5:-5,5:-5])
    for i_file in np.arange(1,len(PATH_LIST)):
        PATH = PATH_LIST[i_file]
        data = xr.open_dataarray(PATH).to_numpy()[:,5:-5,5:-5]
        data_norm = normalize(data)
        data_app = np.concatenate((data_app,data_norm),axis=0)
    return data_app

# depth of CNN * (kernel_num-1)/2
#def load_norm_data_out(var_name_string): #with cropping for output
#    PATH_LIST = glob.glob(BASE+'*/preprocessed_data/'+var_name_string+'.nc') 
#    data_app = normalize(xr.open_dataarray(PATH_LIST[0]).to_numpy()[:,14:-14,14:-14])
#    for i_file in np.arange(1,len(PATH_LIST)):
#        PATH = PATH_LIST[i_file]
#        data = xr.open_dataarray(PATH).to_numpy()[:,14:-14,14:-14]
#        data_norm = normalize(data)
#        data_app = np.concatenate((data_app,data_norm),axis=0)
#    return data_app


def split_data(data):
    data_split_halfs = np.concatenate((np.split(data,2,axis=1)[0],np.split(data,2,axis=1)[1]),0)
    data_split_quarters = np.concatenate((np.split(data_split_halfs,2,axis=2)[0],np.split(data_split_halfs,2,axis=2)[1]),0)
    return data#data_split_quarters



def load_split_norm_data(var_name_string):
    loaded_data = load_norm_data(var_name_string)
    splitted_data = split_data(loaded_data)
    return splitted_data
    
    
def load_split_norm_data_out(var_name_string):
    loaded_data = load_norm_data(var_name_string)
    splitted_data = split_data(loaded_data)
    cropped_output = splitted_data[:,5:-5,5:-5] # for a kernel of size 3 with 5 conv layers
    return cropped_output

# %%
# load preprocessed data, convert to numpy and stack channels

BASE = '/scratch/ab10313/submeso_ML_data/'
FULL_PATH_PP = glob.glob(BASE+'*/preprocessed_data/')

# X INPUT
ds_Bm = load_split_norm_data('Bm_MLD_lowres')
ds_Um = load_split_norm_data('Um_MLD_lowres')
ds_Vm = load_split_norm_data('Vm_MLD_lowres')
ds_Wm = load_split_norm_data('Wm_MLD_lowres')


X_input = np.stack([ds_Bm,ds_Um,ds_Vm,ds_Wm],axis=1)
print('X input shape:')
print( X_input.shape)
print('')


# Y OUTPUT
ds_UsBs = load_split_norm_data('UsBs_MLD_lowres')
ds_VsBs = load_split_norm_data('VsBs_MLD_lowres')
ds_WsBs = load_split_norm_data('WsBs_MLD_lowres')

Y_output = np.stack([ds_UsBs,ds_VsBs,ds_WsBs],axis=1)
print('Y output shape:')
print(Y_output.shape)
print('')


# GRAD B
ds_Bm_x = load_split_norm_data('Bm_x_MLD_lowres')
ds_Bm_y = load_split_norm_data('Bm_y_MLD_lowres')
ds_Bm_z = load_split_norm_data('Bm_z_MLD_lowres')

grad_b = np.stack([ds_Bm_x,ds_Bm_y,ds_Bm_z],axis=1)
print('grad b shape:')
print( grad_b.shape)
# Out:
# X input shape:
# (2150, 4, 30, 30)
#
# Y output shape:
# (2150, 3, 30, 30)
#
# grad b shape:
# (2150, 3, 30, 30)

# %% [markdown]
# ### randomly generate train, test and validation sets

# %%
# TRAIN AND TEST ONLY
# randomnly generate train, test and validation time indecies 
import random
time_ind = X_input.shape[0]
rand_ind = np.arange(time_ind)
rand_seed = 14
random.Random(rand_seed).shuffle(rand_ind)
train_percent = 0.9
test_percent = 0.1 
print(f"Dataset: train {np.round(train_percent*100)}%, test {np.round(test_percent*100)}%")
train_ind, test_ind =  rand_ind[:round(train_percent*time_ind)], rand_ind[round((train_percent)*time_ind):]                                                                        

# check no overlapping indecies
if np.intersect1d(train_ind, test_ind).any():
    print('overlapping indecies')
else:
    print ('no overlapping indecies')
# Out:
# Dataset: train 90.0%, test 10.0%
# no overlapping indecies

# %% [markdown]
# ### defined train, test and val dataloaders

# %%
# Define X,Y pairs (state, subgrid fluxes) for local network.local_torch_dataset = Data.TensorDataset(
BATCH_SIZE = 64  # Number of sample in each batch


###### training dataset #######
torch_dataset_train = Data.TensorDataset(
    torch.from_numpy(X_input[train_ind]).double(),
    torch.from_numpy(Y_output[train_ind]).double(),
)

loader_train = Data.DataLoader(
    dataset=torch_dataset_train, batch_size=BATCH_SIZE, shuffle=True
)
print('TRAIN')
print('X input shape:')
print( X_input[train_ind].shape)
print('Y output shape:')
print( Y_output[train_ind].shape)
print('')

###### test dataset #######
torch_dataset_test = Data.TensorDataset(
    torch.from_numpy(X_input[test_ind]).double(),
    torch.from_numpy(Y_output[test_ind]).double(),    
)

BATCH_SIZE_TEST = len(torch_dataset_test)

loader_test = Data.DataLoader(
    dataset=torch_dataset_test, batch_size=BATCH_SIZE_TEST, shuffle=True
)

print('TEST')
print('X input shape:')
print( X_input[test_ind].shape)
print('Y output shape:')
print( Y_output[test_ind].shape)
print('')

###### validation dataset #######
#torch_dataset_val = Data.TensorDataset(
#    torch.from_numpy(X_input[val_ind]).double(),
#    torch.from_numpy(Y_output[val_ind]).double(),
#)


#loader_val = Data.DataLoader(
#    dataset=torch_dataset_val, batch_size=BATCH_SIZE, shuffle=True
#)

#print('VAL')
#print('X input shape:')
#print( X_input[val_ind].shape)
#print('Y output shape:')
#print( Y_output[val_ind].shape)
#print('')
# Out:
# TRAIN
# X input shape:
# (1935, 4, 30, 30)
# Y output shape:
# (1935, 3, 30, 30)
#
# TEST
# X input shape:
# (215, 4, 30, 30)
# Y output shape:
# (215, 3, 30, 30)

# %% [markdown]
# ## CNN - direct fluxes 3 output channels

# %%
# define network structure in pytorch
import torch.nn.functional as FF

class CNN_direct(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(4, 32, 3, padding='same', padding_mode='reflect')  # 4 inputs, 64 neurons for first hidden layer
        self.dropout1 = nn.Dropout(0.05)
        self.conv1_bn=nn.BatchNorm2d(32)
        self.conv2 = nn.Conv2d(32, 16, 3, padding='same', padding_mode='reflect')  # 64 inputs, 32 neurons for first hidden layer
        self.dropout2 = nn.Dropout(0.05)
        self.conv2_bn=nn.BatchNorm2d(16)
        self.conv3 = nn.Conv2d(16, 3, 3, padding='same', padding_mode='reflect')  # 32 inputs, 24 neurons for first hidden layer
        self.dropout3 = nn.Dropout(0.05)
        self.conv3_bn=nn.BatchNorm2d(3) 

    def forward(self, x):
        x = self.conv1(x)
        x = self.dropout1(x)
        x = F.relu(self.conv1_bn(x))
        x = self.conv2(x)
        x = self.dropout2(x)
        x = F.relu(self.conv2_bn(x))
        x = self.conv3(x)
        x = self.dropout3(x)
        x = self.conv3_bn(x)
        return x
 
    
# define network structure in pytorch
import torch.nn.functional as FF

#class CNN_direct(nn.Module):
#    def __init__(self):
#        super().__init__()
#        self.conv1 = nn.Conv2d(4, 64, 5,padding='same')  # 4 inputs, 128 neurons for first hidden layer
#        self.conv2 = nn.Conv2d(64, 32, 5,padding='same')  # 64 inputs, 32 neurons for first hidden layer
#        self.conv3 = nn.Conv2d(32, 3, 5,padding='same')  # 32 inputs, 24 neurons for first hidden layer

#    def forward(self, x):
#        x = FF.relu(self.conv1(x))
#        x = FF.relu(self.conv2(x))
#        x = self.conv3(x)
#        return x

# %% [markdown]
# ## Train and test model: direct fluxes

# %%
# train network 
def train_model_direct(net, criterion, trainloader, optimizer, len_train_dataset, text="train"):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    net.to(device)
    device_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else "cpu"
    print(f"Training starts on device {device_name}, number of samples {len(trainloader)}")
    
    net.train()
    train_loss = 0
    for step, (batch_x, batch_y) in enumerate(trainloader):  # for each training step
        b_x = Variable(batch_x)  # Inputs
        b_y = Variable(batch_y)  # outputs
        prediction = net(b_x.to(device))
        loss = criterion(prediction, b_y.to(device))  # Calculating loss
        optimizer.zero_grad()  # clear gradients for next train
        loss.backward()  # backpropagation, compute gradients
        optimizer.step()  # apply gradients to update weights
        nb = b_y.shape[0]
        train_loss = train_loss + nb * loss.detach().cpu().numpy()  # Keep track of the loss
    train_loss /= len_train_dataset  # dividing by the number of batches
    print(text + " loss:", train_loss)
    return train_loss


def test_model_direct(net, criterion, testloader, optimizer,len_test_dataset, text="test"):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    net.to(device)
    device_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else "cpu"
    print(f"Training starts on device {device_name}, number of samples {len(testloader)}")
    
    net.eval()  # Evaluation mode (important when having dropout layers)
    test_loss = 0
    with torch.no_grad():
        for step, (batch_x, batch_y) in enumerate(
            testloader
        ):  # for each training step
            b_x = Variable(batch_x)  # Inputs
            b_y = Variable(batch_y)  # outputs
            prediction = net(b_x.to(device))
            loss = criterion(prediction, b_y.to(device))  # Calculating loss
            nb = b_y.shape[0]
            test_loss = test_loss + nb * loss.detach().cpu().numpy()  # Keep track of the loss
        test_loss /= len_test_dataset  # dividing by the number of batches
        #         print(len(trainloader))
        print(text + " loss:", test_loss)
    return test_loss



def plot_model_direct(net, criterion, testloader, optimizer, len_test_dataset, text="test"):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    net.to(device)
    device_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else "cpu"
    print(f"Training starts on device {device_name}, number of samples {len(testloader)}")
    
    net.eval()  # Evaluation mode (important when having dropout layers)
    test_loss = 0
    with torch.no_grad():
        for step, (batch_x, batch_y) in enumerate(
            testloader
        ):  # for each training step
            b_x = Variable(batch_x)  # Inputs
            b_y = Variable(batch_y)  # outputs
            prediction = net(b_x.to(device))
            loss = criterion(prediction, b_y.to(device))  # Calculating loss
            nb = b_y.shape[0]
            test_loss = test_loss + nb * loss.detach().cpu().numpy()  # Keep track of the loss
        test_loss /= len_test_dataset  # dividing by the number of batches
        #         print(len(trainloader))
        print(text + " loss:", test_loss)
    return b_x, b_y, prediction


criterion = torch.nn.MSELoss()  # MSE loss function

# %% [markdown]
# ## train CNN!

# %%
torch.manual_seed(14)  # For reproducibility
cnn_submeso = CNN_direct().double()

n_epochs = 100  # Number of epocs could be increased
optimizer = optim.Adam(cnn_submeso.parameters(), lr=0.03)
test_loss = list()
train_loss = list()
for epoch in range(1, n_epochs + 1):
    print("epoch:", epoch)
    train_loss.append(train_model_direct(cnn_submeso, criterion, loader_train, optimizer,len(torch_dataset_train)))
    test_loss.append(test_model_direct(cnn_submeso, criterion, loader_test, optimizer,len(torch_dataset_test)))
# Out:
# epoch: 1
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 1.206604036726879
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.9439384753932261
# epoch: 2
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.9403335868035815
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.9341772699355346
# epoch: 3
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.921772618755415
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.9256485618752451
# epoch: 4
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.9056618262042968
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.918582022804324
# epoch: 5
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8958961107699468
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.908964416525333
# epoch: 6
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8879565834719858
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8966052393909092
# epoch: 7
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.874167479401254
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8803733525175405
# epoch: 8
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8664025774064806
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8960743613957889
# epoch: 9
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8584167770265642
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8573710988999806
# epoch: 10
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8440575445400027
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8476660614120338
# epoch: 11
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.837885920321757
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8484341003498589
# epoch: 12
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8346176892939948
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8618062160855554
# epoch: 13
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8273098184973601
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8433386986875808
# epoch: 14
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.823718548155206
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.832586512077939
# epoch: 15
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8234349685020828
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8297377211062968
# epoch: 16
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8142209780314458
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8345183864868037
# epoch: 17
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8091362483013798
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.82076661640454
# epoch: 18
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8044329486636992
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8064735519416061
# epoch: 19
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7990339222352408
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8106627960665784
# epoch: 20
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7971650917671512
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8060181504728874
# epoch: 21
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.79397264560367
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8073447061358203
# epoch: 22
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8000295295245796
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7990285789862527
# epoch: 23
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.787156314095512
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8015914761523133
# epoch: 24
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7796232054428
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7827848617228758
# epoch: 25
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7778659609694855
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7882372914243511
# epoch: 26
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7737027946020751
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7787258131412509
# epoch: 27
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7699743075399993
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7736800475336868
# epoch: 28
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7693579297562566
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7746943148495988
# epoch: 29
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7639984586262819
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7696253462631379
# epoch: 30
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7627687865482123
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7807361990492646
# epoch: 31
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7598986320831465
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7659264790006819
# epoch: 32
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.757104164967944
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7568947169453044
# epoch: 33
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7560864576060466
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7643479327333575
# epoch: 34
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7536814268138908
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7630754946158443
# epoch: 35
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7475569955132788
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7477415535891443
# epoch: 36
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7458515842098886
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7564196308255231
# epoch: 37
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7479383842041327
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7442007502036527
# epoch: 38
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7430487971141001
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7598845814588077
# epoch: 39
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7399821963162178
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7431312049634381
# epoch: 40
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7402034253569169
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7419546332611507
# epoch: 41
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7376910614520733
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7545291015371912
# epoch: 42
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7459668455471019
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7550823123355035
# epoch: 43
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7372283982903014
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7376375760097467
# epoch: 44
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7292420969078582
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7729042891124163
# epoch: 45
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7349549720787086
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7403284994948414
# epoch: 46
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7298463615599139
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7417992136678491
# epoch: 47
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7261253983639618
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7374613002295232
# epoch: 48
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7266269639782958
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7195593798628893
# epoch: 49
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.725460072191077
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7333120681257079
# epoch: 50
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7222458614216876
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7461616517415975
# epoch: 51
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7214448923753469
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7292821155837899
# epoch: 52
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.721273024719047
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7330680083782339
# epoch: 53
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7205743987509164
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7274767793040363
# epoch: 54
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7240159511544142
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7177260963204352
# epoch: 55
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7182456709740278
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7458646614045401
# epoch: 56
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7181417221367681
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7308869482018782
# epoch: 57
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7142704090025082
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7308876446390253
# epoch: 58
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.712229343109868
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.717533541224391
# epoch: 59
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7106735445659945
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7680575408276697
# epoch: 60
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7132070043735438
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7225016905360787
# epoch: 61
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7090029533287457
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7151268822663304
# epoch: 62
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7087402489546019
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7151985790025728
# epoch: 63
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.711761628633205
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7143637165275122
# epoch: 64
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7103150316668964
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7175623142489803
# epoch: 65
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7143438601043575
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7170865652476676
# epoch: 66
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7115339971607987
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7151165647720978
# epoch: 67
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7120174597179575
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7331300072300663
# epoch: 68
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7099110173461817
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7334989168657742
# epoch: 69
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7072430528896649
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7122980571284543
# epoch: 70
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7067862318943154
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7027205160273731
# epoch: 71
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7044398333909729
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7207669360818859
# epoch: 72
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7057120809570315
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.71481171780088
# epoch: 73
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7034983025462299
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6990090277427027
# epoch: 74
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7074396685863866
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7243577389750225
# epoch: 75
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7069050732521663
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7074058885531815
# epoch: 76
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7044803944101478
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7067013916034723
# epoch: 77
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7026042168575211
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7159974953572811
# epoch: 78
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7070463995302281
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7384135054523638
# epoch: 79
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.702992038573066
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7198834302167205
# epoch: 80
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7019366240692336
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7061752360219329
# epoch: 81
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.70172454832737
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7043672182346464
# epoch: 82
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7022892199154498
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7222321473719628
# epoch: 83
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7025646100729959
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6995391858981236
# epoch: 84
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.702736792051912
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7036339412047714
# epoch: 85
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.700246807819758
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7069442124472185
# epoch: 86
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7047927305331646
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7044172305941747
# epoch: 87
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.6992777199882063
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7096395312184752
# epoch: 88
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7017741593316806
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7010252577945156
# epoch: 89
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7019462756088609
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.707945947943823
# epoch: 90
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7026350819442301
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7084979103365069
# epoch: 91
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.6988974603002865
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7072859671038776
# epoch: 92
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.6974152425346575
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7044992736460276
# epoch: 93
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.6960963504484786
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7026602011985995
# epoch: 94
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.6966420634287409
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6923482781095104
# epoch: 95
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.6975185922746177
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7290889031590398
# epoch: 96
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.6988775373900905
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7034893399327319
# epoch: 97
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.6998290058229789
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7028852210500213
# epoch: 98
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.7009725541340441
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6967862376310386
# epoch: 99
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.6965737684481705
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6999700347197724
# epoch: 100
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.6971802549668414
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7137959339616414

# %%
import matplotlib.pyplot as plt

plt.plot(train_loss[1:], "b", label="training loss")
plt.plot(test_loss[1:], "r", label="test loss")

plt.legend();

# %%
b_x, b_y, prediction = plot_model_direct(cnn_submeso, criterion, loader_test, optimizer,len(torch_dataset_test))
# Out:
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7137959339616414

# %%
from scipy import stats
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")


corr_pred_ub = stats.pearsonr(cnn_submeso(b_x.to(device)).detach().cpu().numpy()[:,0,:,:].flatten(), b_y[:,0,:,:].flatten())
corr_pred_vb = stats.pearsonr(cnn_submeso(b_x.to(device)).detach().cpu().numpy()[:,1,:,:].flatten(), b_y[:,1,:,:].flatten())
corr_pred_wb = stats.pearsonr(cnn_submeso(b_x.to(device)).detach().cpu().numpy()[:,2,:,:].flatten(), b_y[:,2,:,:].flatten())

print("correlation between prediction and target,  u'b':",corr_pred_ub )
print("correlation between prediction and target,  v'b':",corr_pred_vb )
print("correlation between prediction and target,  w'b':",corr_pred_wb )
# Out:
# correlation between prediction and target,  u'b': (0.5807963210454374, 0.0)
# correlation between prediction and target,  v'b': (0.6029633687898593, 0.0)
# correlation between prediction and target,  w'b': (0.46308174633610744, 0.0)

# %%
# visualize
it =10

fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(8, 4))
fig.tight_layout() # Or equivalently,  "plt.tight_layout()"

plt.subplot(231)
plt.pcolor(cnn_submeso(b_x.to(device)).detach().cpu().numpy()[it,0,:,:],cmap='viridis',vmin=-1,vmax =1)
plt.title('ub prediction')
plt.colorbar()

plt.subplot(234)
plt.pcolor(b_y[it,0,:,:],cmap='viridis',vmin=-1,vmax =1)
plt.title('ub target')
plt.colorbar()

plt.subplot(232)
plt.pcolor(cnn_submeso(b_x.to(device)).detach().cpu().numpy()[it,1,:,:],cmap='viridis',vmin=-1,vmax =1)
plt.title('vb prediction')
plt.colorbar()

plt.subplot(235)
plt.pcolor(b_y[it,1,:,:],cmap='viridis',vmin=-1,vmax =1)
plt.title('vb target')
plt.colorbar()

plt.subplot(233)
plt.pcolor(cnn_submeso(b_x.to(device)).detach().cpu().numpy()[it,2,:,:],cmap='viridis',vmin=-1,vmax =1)
plt.title('wb prediction')
plt.colorbar()

plt.subplot(236)
plt.pcolor(b_y[it,2,:,:],cmap='viridis',vmin=-1,vmax =1)
plt.title('wb target')
plt.colorbar()

# %%
_=plt.hist(b_y.detach().cpu().numpy().flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="target")
_=plt.hist(cnn_submeso(b_x.to(device)).detach().cpu().numpy().flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="prediction")

plt.xlim([-3,3])
plt.legend()
