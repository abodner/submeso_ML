# %%
import torch
import torch.nn.functional as F
import torch.utils.data as Data
import torchvision
from torch import nn, optim
from torch.autograd import Variable
import numpy as np
import os
import glob
import xarray as xr
from sklearn import preprocessing
import netCDF4 as nc
import matplotlib.pyplot as plt



np.random.seed(14)  # For reproducibility
torch.manual_seed(14)  # For reproducibility

# %% [markdown]
# # Dataloader

# %% [markdown]
# ### Create input and output channels

# %%
# function that splits datasets along the spacial axes and concats them back into single array under time

def normalize(data):
    #normalized_data =  (data - data.mean(skipna=True).values)/data.std(skipna=True).values
    normalized_data = (data - np.mean(data))/np.std(data)
    return normalized_data


def load_norm_data(var_name_string):
    PATH_LIST = glob.glob(BASE+'*/preprocessed_data/'+var_name_string+'.nc') 
    data_app = normalize(xr.open_dataarray(PATH_LIST[0]).to_numpy()[:,5:-5,5:-5])
    for i_file in np.arange(1,len(PATH_LIST)):
        PATH = PATH_LIST[i_file]
        data = xr.open_dataarray(PATH).to_numpy()[:,5:-5,5:-5]
        data_norm = normalize(data)
        data_app = np.concatenate((data_app,data_norm),axis=0)
    return data_app



def split_data(data):
    data_split_halfs = np.concatenate((np.split(data,2,axis=1)[0],np.split(data,2,axis=1)[1]),0)
    data_split_quarters = np.concatenate((np.split(data_split_halfs,2,axis=2)[0],np.split(data_split_halfs,2,axis=2)[1]),0)
    return data#data_split_quarters



def load_split_norm_data(var_name_string):
    loaded_data = load_norm_data(var_name_string)
    splitted_data = split_data(loaded_data)
    return splitted_data
    
    
def load_split_norm_data_out(var_name_string):
    loaded_data = load_norm_data(var_name_string)
    splitted_data = split_data(loaded_data)
    cropped_output = splitted_data[:,5:-5,5:-5] # for a kernel of size 3 with 5 conv layers
    return cropped_output

# %%
# load preprocessed data, convert to numpy and stack channels

BASE = '/scratch/ab10313/submeso_ML_data/'
FULL_PATH_PP = glob.glob(BASE+'*/preprocessed_data/')

# X INPUT
ds_Bm = load_split_norm_data('Bm_MLD_lowres')
ds_Um = load_split_norm_data('Um_MLD_lowres')
ds_Vm = load_split_norm_data('Vm_MLD_lowres')
ds_Wm = load_split_norm_data('Wm_MLD_lowres')


X_input = np.stack([ds_Bm,ds_Um,ds_Vm,ds_Wm],axis=1)
print('X input shape:')
print( X_input.shape)
print('')


# Y OUTPUT
ds_UsBs = load_split_norm_data('UsBs_MLD_lowres')
ds_VsBs = load_split_norm_data('VsBs_MLD_lowres')
ds_WsBs = load_split_norm_data('WsBs_MLD_lowres')

Y_output = np.stack([ds_UsBs,ds_VsBs,ds_WsBs],axis=1)
print('Y output shape:')
print(Y_output.shape)
print('')


# GRAD B
ds_Bm_x = load_split_norm_data('Bm_x_MLD_lowres')
ds_Bm_y = load_split_norm_data('Bm_y_MLD_lowres')
ds_Bm_z = load_split_norm_data('Bm_z_MLD_lowres')

grad_b = np.stack([ds_Bm_x,ds_Bm_y,ds_Bm_z],axis=1)
print('grad b shape:')
print( grad_b.shape)
# Out:
# X input shape:
# (2150, 4, 30, 30)
#
# Y output shape:
# (2150, 3, 30, 30)
#
# grad b shape:
# (2150, 3, 30, 30)

# %% [markdown]
# ### randomly generate train, test and validation sets

# %%
# TRAIN AND TEST ONLY
# randomnly generate train, test and validation time indecies 
import random
time_ind = X_input.shape[0]
rand_ind = np.arange(time_ind)
rand_seed = 14
random.Random(rand_seed).shuffle(rand_ind)
train_percent = 0.9
test_percent = 0.1 
print(f"Dataset: train {np.round(train_percent*100)}%, test {np.round(test_percent*100)}%")
train_ind, test_ind =  rand_ind[:round(train_percent*time_ind)], rand_ind[round((train_percent)*time_ind):]                                                                        

# check no overlapping indecies
if np.intersect1d(train_ind, test_ind).any():
    print('overlapping indecies')
else:
    print ('no overlapping indecies')
# Out:
# Dataset: train 90.0%, test 10.0%
# no overlapping indecies

# %% [markdown]
# ### defined train, test and val dataloaders

# %%
# Define X,Y pairs (state, subgrid fluxes) for local network.local_torch_dataset = Data.TensorDataset(
BATCH_SIZE = 32  # Number of sample in each batch


###### training dataset #######
torch_dataset_train = Data.TensorDataset(
    torch.from_numpy(X_input[train_ind]).double(),
    torch.from_numpy(Y_output[train_ind]).double(),
    torch.from_numpy(grad_b[train_ind]).double(),
)

loader_train = Data.DataLoader(
    dataset=torch_dataset_train, batch_size=BATCH_SIZE, shuffle=True
)
print('TRAIN')
print('X input shape:')
print( X_input[train_ind].shape)
print('Y output shape:')
print( Y_output[train_ind].shape)
print('grad b shape:')
print( grad_b[train_ind].shape)
print('')

###### test dataset #######
torch_dataset_test = Data.TensorDataset(
    torch.from_numpy(X_input[test_ind]).double(),
    torch.from_numpy(Y_output[test_ind]).double(),
    torch.from_numpy(grad_b[test_ind]).double(),
    
)

loader_test = Data.DataLoader(
    dataset=torch_dataset_test, batch_size=BATCH_SIZE, shuffle=True
)

print('TEST')
print('X input shape:')
print( X_input[test_ind].shape)
print('Y output shape:')
print( Y_output[test_ind].shape)
print('grad b shape:')
print( grad_b[test_ind].shape)
print('')

###### validation dataset #######
#torch_dataset_val = Data.TensorDataset(
#    torch.from_numpy(X_input[val_ind]).double(),
#    torch.from_numpy(Y_output[val_ind]).double(),
#    torch.from_numpy(grad_b[val_ind]).double(),
#)

#BATCH_SIZE_TEST = len(torch_dataset_test)

#loader_val = Data.DataLoader(
#    dataset=torch_dataset_val, batch_size=BATCH_SIZE_TEST, shuffle=True
#)

#print('VAL')
#print('X input shape:')
#print( X_input[val_ind].shape)
#print('Y output shape:')
#print( Y_output[val_ind].shape)
#print('grad b shape:')
#print( grad_b[val_ind].shape)
#print('')
# Out:
# TRAIN
# X input shape:
# (1935, 4, 30, 30)
# Y output shape:
# (1935, 3, 30, 30)
# grad b shape:
# (1935, 3, 30, 30)
#
# TEST
# X input shape:
# (215, 4, 30, 30)
# Y output shape:
# (215, 3, 30, 30)
# grad b shape:
# (215, 3, 30, 30)

# %% [markdown]
# ## CNN - skew fluxes 9 output channels represeting 3X3 J matrix

# %%
# define network structure in pytorch
import torch.nn.functional as FF

class CNN_skew(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(4, 128, 3, padding='same', padding_mode='reflect')  # 4 inputs, 64 neurons for first hidden layer
        self.dropout1 = nn.Dropout(0.2)
        self.conv1_bn=nn.BatchNorm2d(128)
        self.conv2 = nn.Conv2d(128, 64, 3, padding='same', padding_mode='reflect')  # 64 inputs, 32 neurons for first hidden layer
        self.dropout2 = nn.Dropout(0.2)
        self.conv2_bn=nn.BatchNorm2d(64)
        self.conv3 = nn.Conv2d(64, 32, 3, padding='same', padding_mode='reflect')  # 32 inputs, 16 neurons for first hidden layer
        self.dropout3 = nn.Dropout(0.2)
        self.conv3_bn=nn.BatchNorm2d(32)  
        self.conv4 = nn.Conv2d(32, 16, 3, padding='same', padding_mode='reflect')  # 16 inputs, 3 neurons for first hidden layer
        self.dropout4 = nn.Dropout(0.2)
        self.conv4_bn=nn.BatchNorm2d(16) 
        self.conv5 = nn.Conv2d(16, 9, 3, padding='same', padding_mode='reflect')  # 32 inputs, 24 neurons for first hidden layer
        self.dropout5 = nn.Dropout(0.2)
        self.conv5_bn=nn.BatchNorm2d(9) # 9 outputs

    def forward(self, x):
        x = self.conv1(x)
        x = self.dropout1(x)
        x = F.relu(self.conv1_bn(x))
        x = self.conv2(x)
        x = self.dropout2(x)
        x = F.relu(self.conv2_bn(x))
        x = self.conv3(x)
        x = self.dropout3(x)
        x = F.relu(self.conv3_bn(x))
        x = self.conv4(x)
        x = self.dropout4(x)
        x = F.relu(self.conv4_bn(x))
        x = self.conv5(x)
        x = self.dropout5(x)
        x = self.conv5_bn(x)
        return x
 
    
# define network structure in pytorch
import torch.nn.functional as FF

#class CNN_direct(nn.Module):
#    def __init__(self):
#        super().__init__()
#        self.conv1 = nn.Conv2d(4, 64, 5,padding='same')  # 4 inputs, 128 neurons for first hidden layer
#        self.conv2 = nn.Conv2d(64, 32, 5,padding='same')  # 64 inputs, 32 neurons for first hidden layer
#        self.conv3 = nn.Conv2d(32, 3, 5,padding='same')  # 32 inputs, 24 neurons for first hidden layer

#    def forward(self, x):
#        x = FF.relu(self.conv1(x))
#        x = FF.relu(self.conv2(x))
#        x = self.conv3(x)
#        return x

# %% [markdown]
# ## Train and test model: direct fluxes

# %%
# train network 
def train_model_skew(net, criterion, trainloader, optimizer, len_train_dataset, text="train"):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    net.to(device)
    device_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else "cpu"
    print(f"Training starts on device {device_name}, number of samples {len(trainloader)}")
    
    net.train()
    train_loss = 0
    for step, (batch_x, batch_y, batch_g) in enumerate(trainloader):  # for each training step
        b_x = Variable(batch_x)  # Inputs
        b_y = Variable(batch_y)  # outputs
        b_grad = Variable(batch_g) # grad b
        prediction = net(b_x.to(device))
            
        prediction_reshape = torch.reshape(prediction, (prediction.shape[0],prediction.shape[2],prediction.shape[3],3, 3))
        grad_b_reshape = torch.reshape(b_grad, (b_grad.shape[0],b_grad.shape[2],b_grad.shape[3],3,1)).to(device)
            
        b_grad_view = grad_b_reshape.view(-1,3,1)
        prediction_view = prediction_reshape.view(-1,3,3)
            
        #print(prediction_reshape.shape)
        #print(grad_b_reshape.shape)
        
        #b_y_reshape = torch.reshape(b_y, (3, b_y.shape[0],b_y.shape[2],b_y.shape[3]))
        product = torch.bmm(prediction_view,b_grad_view)
        #print(product.shape)
        product_reshape = torch.reshape(product, (b_grad.shape[0],b_grad.shape[1],b_grad.shape[2],b_grad.shape[3])).to(device)
        #print(product_reshape.shape)
        #print(b_y.shape)
        
        
        # Calculating loss to find J which is the prediction
        loss = criterion(product_reshape, b_y.to(device)) 
        optimizer.zero_grad()  # clear gradients for next train
        loss.backward()  # backpropagation, compute gradients
        optimizer.step()  # apply gradients to update weights
        nb = b_y.shape[0]
        train_loss = train_loss + nb * loss.detach().cpu().numpy()  # Keep track of the loss
    train_loss /= len_train_dataset # dividing by the number of batches
    print(text + " loss:", train_loss)
    return train_loss


def test_model_skew(net, criterion, testloader, optimizer,len_test_dataset, text="validation"):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    net.to(device)
    device_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else "cpu"
    print(f"Training starts on device {device_name}, number of samples {len(testloader)}")
    
    net.eval()  # Evaluation mode (important when having dropout layers)
    test_loss = 0
    with torch.no_grad():
        for step, (batch_x, batch_y, batch_g) in enumerate(
            testloader
        ):  # for each training step
            b_x = Variable(batch_x)  # Inputs
            b_y = Variable(batch_y)  # outputs
            b_grad = Variable(batch_g) # grad b
            prediction = net(b_x.to(device))
            prediction_reshape = torch.reshape(prediction, (prediction.shape[0],prediction.shape[2],prediction.shape[3],3, 3))
            grad_b_reshape = torch.reshape(b_grad, (b_grad.shape[0],b_grad.shape[2],b_grad.shape[3],3,1)).to(device)
            
            b_grad_view = grad_b_reshape.view(-1,3,1)
            prediction_view = prediction_reshape.view(-1,3,3)
            
        #print(prediction_reshape.shape)
        #print(grad_b_reshape.shape)
        
        #b_y_reshape = torch.reshape(b_y, (3, b_y.shape[0],b_y.shape[2],b_y.shape[3]))
            product = torch.bmm(prediction_view,b_grad_view)
        #print(product.shape)
            product_reshape = torch.reshape(product, (b_grad.shape[0],b_grad.shape[1],b_grad.shape[2],b_grad.shape[3])).to(device)
        #print(product_reshape.shape)
        #print(b_y.shape)
        
        
        # Calculating loss to find J which is the prediction
            loss = criterion(product_reshape, b_y.to(device)) 
            nb = b_y.shape[0]
            test_loss = test_loss + nb * loss.detach().cpu().numpy()  # Keep track of the loss
        test_loss /= len_test_dataset  # dividing by the number of batches
        #         print(len(trainloader))
        print(text + " loss:", test_loss)
    return test_loss



def plot_model_skew(net, criterion, testloader, optimizer, len_test_dataset,text="validation"):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    net.to(device)
    device_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else "cpu"
    print(f"Training starts on device {device_name}, number of samples {len(testloader)}")
    
    net.eval()  # Evaluation mode (important when having dropout layers)
    test_loss = 0
    with torch.no_grad():
        for step, (batch_x, batch_y,batch_g) in enumerate(
            testloader
        ):  # for each training step
            b_x = Variable(batch_x)  # Inputs
            b_y = Variable(batch_y)  # outputs
            b_grad = Variable(batch_g) # grad b
            prediction = net(b_x.to(device))
            prediction_reshape = torch.reshape(prediction, (prediction.shape[0],prediction.shape[2],prediction.shape[3],3, 3))
            grad_b_reshape = torch.reshape(b_grad, (b_grad.shape[0],b_grad.shape[2],b_grad.shape[3],3,1)).to(device)
            
            b_grad_view = grad_b_reshape.view(-1,3,1)
            prediction_view = prediction_reshape.view(-1,3,3)
            
        #print(prediction_reshape.shape)
        #print(grad_b_reshape.shape)
        
        #b_y_reshape = torch.reshape(b_y, (3, b_y.shape[0],b_y.shape[2],b_y.shape[3]))
            product = torch.bmm(prediction_view,b_grad_view)
        #print(product.shape)
            product_reshape = torch.reshape(product, (b_grad.shape[0],b_grad.shape[1],b_grad.shape[2],b_grad.shape[3])).to(device)
        #print(product_reshape.shape)
        #print(b_y.shape)
        
        
        # Calculating loss to find J which is the prediction
            loss = criterion(product_reshape, b_y.to(device)) 
            
            
            nb = b_y.shape[0]
            test_loss = test_loss + nb * loss.detach().cpu().numpy()  # Keep track of the loss
        test_loss /= len_test_dataset  # dividing by the number of batches
        #         print(len(trainloader))
        print(text + " loss:", test_loss)
    return b_x, b_y, product_reshape, prediction_view, b_grad_view


criterion = torch.nn.MSELoss()  # MSE loss function

# %% [markdown]
# ## train CNN!

# %%
torch.manual_seed(14)  # For reproducibility
cnn_submeso = CNN_skew().double()

n_epochs = 100  # Number of epocs could be increased
optimizer = optim.Adam(cnn_submeso.parameters(), lr=0.015)
test_loss = list()
train_loss = list()
for epoch in range(1, n_epochs + 1):
    print("epoch:", epoch)
    train_loss.append(train_model_skew(cnn_submeso, criterion, loader_train, optimizer,len(torch_dataset_train)))
    test_loss.append(test_model_skew(cnn_submeso, criterion, loader_test, optimizer,len(torch_dataset_test)))
# Out:
# epoch: 1
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 1.7974921357435323
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9879213157881704
# epoch: 2
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 1.0435410490135055
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9802576354492385
# epoch: 3
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9799263367908544
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9762611338497015
# epoch: 4
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.967596731988547
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9717394086223609
# epoch: 5
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9647005402533251
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9713969242302012
# epoch: 6
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9627657673267613
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9690613934278677
# epoch: 7
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9619388761580449
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.968537646065214
# epoch: 8
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.961684332608376
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9680280692285632
# epoch: 9
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9605975585541547
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9659844224821986
# epoch: 10
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9600753025670589
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9674096884036778
# epoch: 11
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9590298754276562
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9673324871100466
# epoch: 12
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9583016764750338
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9677587638151463
# epoch: 13
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9583394142812866
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9664879550171542
# epoch: 14
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9580581845396431
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9681651760571386
# epoch: 15
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9561580323763578
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9669688972232874
# epoch: 16
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.958051629018166
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9647189192103844
# epoch: 17
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9558922900720301
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9671109908680404
# epoch: 18
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9559583506328121
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9649111337615146
# epoch: 19
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9572584517805006
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9678689638456368
# epoch: 20
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9564533242147879
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9642700539849268
# epoch: 21
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9555045603553595
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9652813215123411
# epoch: 22
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9549539861237607
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9647579297808963
# epoch: 23
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9544143488693487
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9646300406301116
# epoch: 24
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9557450337779289
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9636477031225238
# epoch: 25
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9546591347117155
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9617933800320564
# epoch: 26
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.953634047581811
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9625683572365408
# epoch: 27
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9528621495136941
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9621451607245016
# epoch: 28
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.952755111728905
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9625810319048096
# epoch: 29
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9535284266538215
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9629752826823825
# epoch: 30
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.950791027797319
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9620233751963674
# epoch: 31
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9532220257836685
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9631657279380174
# epoch: 32
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9514349549289393
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9590460868938078
# epoch: 33
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9510862196482222
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9580111047923201
# epoch: 34
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9500159262395482
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9603734996928434
# epoch: 35
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9492368840542247
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9584544959369179
# epoch: 36
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9496844302560514
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9601220336010329
# epoch: 37
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.948442695773816
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9599546886939403
# epoch: 38
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.949061009325122
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.956216738953573
# epoch: 39
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.948544414776718
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9565401552673164
# epoch: 40
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.946759832088937
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9584303453169004
# epoch: 41
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9480309110516649
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9589415959277238
# epoch: 42
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9466833217761977
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.960284214273876
# epoch: 43
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9486072918225205
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9572495222746498
# epoch: 44
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9478267054836855
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9604941966535753
# epoch: 45
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9470407811970712
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9561814591403157
# epoch: 46
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9445401610923198
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.960180636165826
# epoch: 47
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9436487036803872
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.964554026549376
# epoch: 48
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9460965597441113
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9612228383924397
# epoch: 49
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9442564484905503
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9608006594217244
# epoch: 50
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9430224892109397
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9532677369536972
# epoch: 51
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9429653661539749
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9541732086130508
# epoch: 52
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9424155130998858
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9530673966609158
# epoch: 53
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9426951885270356
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9554698706678066
# epoch: 54
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9428093430350891
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9561158604293422
# epoch: 55
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9440709918760259
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.956441628714242
# epoch: 56
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9420528906131873
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9560275258761389
# epoch: 57
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9419258393134433
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9597868340105157
# epoch: 58
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9418139834866427
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9620060742804135
# epoch: 59
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9439984467045729
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9535403832794421
# epoch: 60
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9439742957386256
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9535639964190588
# epoch: 61
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9408688805269221
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.961542194114737
# epoch: 62
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9442231355794145
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9520249288897247
# epoch: 63
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9423793281007004
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9524409752244376
# epoch: 64
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9400078111371916
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9540124616477955
# epoch: 65
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9399042680605721
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9519629909290415
# epoch: 66
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9408658992491681
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9518292321002467
# epoch: 67
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9403773777966573
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9515197402661777
# epoch: 68
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9437781497457207
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9560456125339315
# epoch: 69
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9409985115651822
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9556590994482124
# epoch: 70
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9404070006744804
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9510836373577457
# epoch: 71
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9394518053607464
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9614100037723008
# epoch: 72
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9380694161630349
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9531714585396219
# epoch: 73
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9376011956087442
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9524306709508467
# epoch: 74
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9379646835377954
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9508140801344432
# epoch: 75
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9384207301430438
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9486013927191176
# epoch: 76
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.937036379995674
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9543231955131393
# epoch: 77
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9351003951270358
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9538388924966531
# epoch: 78
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9358774148384148
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9489453968772289
# epoch: 79
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9348358092108351
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9501397397600504
# epoch: 80
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.935829451321697
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9564933556260024
# epoch: 81
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9357163010666039
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9479092816346403
# epoch: 82
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9350906600577504
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9516592657585548
# epoch: 83
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9340131070096114
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9536545249461325
# epoch: 84
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9336143657578102
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9443791389037541
# epoch: 85
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9335041410760031
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9480790843001364
# epoch: 86
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9338445932259657
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9542048933463461
# epoch: 87
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9329384188578886
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.978469050598428
# epoch: 88
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9367375748251062
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9461781551279694
# epoch: 89
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9322105608245789
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9555959422413961
# epoch: 90
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9345934948470422
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9470769284342487
# epoch: 91
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9319106489915174
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9615435406110452
# epoch: 92
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9332786013748972
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9481154767555269
# epoch: 93
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9316989339913413
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9523122170081534
# epoch: 94
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9318677236573211
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9477589104832668
# epoch: 95
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9290992400889901
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9530354355521379
# epoch: 96
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9289091892843452
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9519536294679016
# epoch: 97
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9303297388060275
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9431154230565768
# epoch: 98
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9268764120150825
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9610026317465582
# epoch: 99
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.934421026098389
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9486668389329538
# epoch: 100
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9286435146384172
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9559912035216651

# %%
import matplotlib.pyplot as plt

plt.plot(train_loss[1:], "b", label="training loss")
plt.plot(test_loss[1:], "r", label="test loss")

plt.legend();

# %%
b_x, b_y, product_reshape, prediction_view, b_grad_view = plot_model_skew(cnn_submeso, criterion, loader_test, optimizer,len(torch_dataset_test))
# Out:
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.955991203521665

# %%
from scipy import stats
corr_pred_ub = stats.pearsonr(product_reshape.detach().cpu().numpy()[:,0,:,:].flatten(), b_y[:,0,:,:].flatten())
corr_pred_vb = stats.pearsonr(product_reshape.detach().cpu().numpy()[:,1,:,:].flatten(), b_y[:,1,:,:].flatten())
corr_pred_wb = stats.pearsonr(product_reshape.detach().cpu().numpy()[:,2,:,:].flatten(), b_y[:,2,:,:].flatten())

print("correlation between prediction and target,  u'b':",corr_pred_ub )
print("correlation between prediction and target,  v'b':",corr_pred_vb )
print("correlation between prediction and target,  w'b':",corr_pred_wb )
# Out:
# correlation between prediction and target,  u'b': (0.21003780595942315, 4.316373109576793e-205)
# correlation between prediction and target,  v'b': (0.21327505968337868, 1.5151622132854464e-211)
# correlation between prediction and target,  w'b': (0.3601050577447149, 0.0)

# %%
# visualize
it =18

fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(8, 4))
fig.tight_layout() # Or equivalently,  "plt.tight_layout()"

plt.subplot(231)
plt.pcolor(product_reshape.detach().cpu().numpy()[it,0,:,:],cmap='viridis',vmin=-1,vmax =1)
plt.title('ub prediction')
plt.colorbar()

plt.subplot(234)
plt.pcolor(b_y[it,0,:,:],cmap='viridis',vmin=-1,vmax =1)
plt.title('ub target')
plt.colorbar()

plt.subplot(232)
plt.pcolor(product_reshape.detach().cpu().numpy()[it,1,:,:],cmap='viridis',vmin=-1,vmax =1)
plt.title('vb prediction')
plt.colorbar()

plt.subplot(235)
plt.pcolor(b_y[it,1,:,:],cmap='viridis',vmin=-1,vmax =1)
plt.title('vb target')
plt.colorbar()

plt.subplot(233)
plt.pcolor(product_reshape.detach().cpu().numpy()[it,2,:,:],cmap='viridis',vmin=-1,vmax =1)
plt.title('wb prediction')
plt.colorbar()

plt.subplot(236)
plt.pcolor(b_y[it,2,:,:],cmap='viridis',vmin=-1,vmax =1)
plt.title('wb target')
plt.colorbar()

# %%
_=plt.hist(b_y.detach().cpu().numpy().flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="target")
_=plt.hist(product_reshape.detach().cpu().numpy().flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="prediction")

plt.xlim([-3,3])
plt.legend()

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(12, 4))
fig.tight_layout() # Or equivalently,  "plt.tight_layout()"

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

plt.subplot(131)
_=plt.hist(b_y.detach().cpu().numpy()[:,0,:,:].flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="target")
_=plt.hist(product_reshape.detach().cpu().numpy()[:,0,:,:].flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="prediction")
plt.xlim([-3,3])
plt.legend()
plt.title('ub')


plt.subplot(132)
_=plt.hist(b_y.detach().cpu().numpy()[:,1,:,:].flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="target")
_=plt.hist(product_reshape.detach().cpu().numpy()[:,1,:,:].flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="prediction")
plt.xlim([-3,3])
plt.legend()
plt.title('vb')

plt.subplot(133)
_=plt.hist(b_y.detach().cpu().numpy()[:,2,:,:].flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="target")
_=plt.hist(product_reshape.detach().cpu().numpy()[:,2,:,:].flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="prediction")
plt.xlim([-3,3])
plt.legend()
plt.title('wb')
# Out:
# Text(0.5, 1.0, 'wb')

# %%
target_da = xr.DataArray(b_y.detach().cpu().numpy(), dims=["time", "axis", "i","j"])
prediction_da = xr.DataArray(cnn_submeso(b_x.to(device)).detach().cpu().numpy(), dims=["time", "axis", "i","j"])

# %%
import xrft

# target vs prediction spectra
UsBs_target_spectra = xrft.isotropic_power_spectrum(target_da.isel(axis=0),dim=['i','j'], 
                                           detrend='linear', window=True).compute().mean('time')

UsBs_prediction_spectra = xrft.isotropic_power_spectrum(prediction_da.isel(axis=0),dim=['i','j'], 
                                           detrend='linear', window=True).compute().mean('time')


VsBs_target_spectra = xrft.isotropic_power_spectrum(target_da.isel(axis=1),dim=['i','j'], 
                                           detrend='linear', window=True).compute().mean('time')

VsBs_prediction_spectra = xrft.isotropic_power_spectrum(prediction_da.isel(axis=1),dim=['i','j'], 
                                           detrend='linear', window=True).compute().mean('time')


WsBs_target_spectra = xrft.isotropic_power_spectrum(target_da.isel(axis=2),dim=['i','j'], 
                                           detrend='linear', window=True).compute().mean('time')

WsBs_prediction_spectra = xrft.isotropic_power_spectrum(prediction_da.isel(axis=2),dim=['i','j'], 
                                           detrend='linear', window=True).compute().mean('time')
# Out:
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:47: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:1025: FutureWarning: Isotropic wavenumber larger than the Nyquist wavenumber may result.
#   warnings.warn(msg, FutureWarning)
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:47: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:1025: FutureWarning: Isotropic wavenumber larger than the Nyquist wavenumber may result.
#   warnings.warn(msg, FutureWarning)
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:47: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:1025: FutureWarning: Isotropic wavenumber larger than the Nyquist wavenumber may result.
#   warnings.warn(msg, FutureWarning)
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:47: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:1025: FutureWarning: Isotropic wavenumber larger than the Nyquist wavenumber may result.
#   warnings.warn(msg, FutureWarning)
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:47: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:1025: FutureWarning: Isotropic wavenumber larger than the Nyquist wavenumber may result.
#   warnings.warn(msg, FutureWarning)
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:47: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:1025: FutureWarning: Isotropic wavenumber larger than the Nyquist wavenumber may result.
#   warnings.warn(msg, FutureWarning)

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(20, 5))
fig.tight_layout() # Or equivalently,  "plt.tight_layout()"

plt.subplot(131)
#plt.loglog(UsBs_target_spectra.freq_r*2*np.pi, 5e-3*UsBs_target_spectra.freq_r**-2, '--',linewidth=1.5,color='black', label='k^{-2}')
#plt.loglog(UsBs_target_spectra.freq_r*2*np.pi, 2e-3*UsBs_target_spectra.freq_r**-3, '--',linewidth=1.5,color='gray', label='k^{-3}')
plt.loglog(UsBs_target_spectra.freq_r*2*np.pi, UsBs_target_spectra/UsBs_target_spectra[0],linewidth=2, label='target')
plt.loglog(UsBs_prediction_spectra.freq_r*2*np.pi, UsBs_prediction_spectra/UsBs_target_spectra[0],linewidth=2, label='prediction')
plt.legend()
plt.xlabel('$k_r$')
plt.ylabel('Normalized isotropic spectra')
plt.title('UsBs')


plt.subplot(132)
#plt.loglog(VsBs_target_spectra.freq_r*2*np.pi, 5e-3*VsBs_target_spectra.freq_r**-2, '--',linewidth=1.5,color='black', label='k^{-2}')
#plt.loglog(VsBs_target_spectra.freq_r*2*np.pi, 2e-3*VsBs_target_spectra.freq_r**-3, '--',linewidth=1.5,color='gray', label='k^{-3}')
plt.loglog(VsBs_target_spectra.freq_r*2*np.pi, VsBs_target_spectra/VsBs_target_spectra[0],linewidth=2, label='target')
plt.loglog(VsBs_prediction_spectra.freq_r*2*np.pi, VsBs_prediction_spectra/VsBs_target_spectra[0],linewidth=2, label='prediction')
plt.legend()
plt.xlabel('$k_r$')
#plt.ylabel('Normalized isotropic spectra')
plt.title('VsBs')


plt.subplot(133)
#plt.loglog(WsBs_target_spectra.freq_r*2*np.pi, 5e-3*WsBs_target_spectra.freq_r**-2, '--',linewidth=1.5,color='black', label='k^{-2}')
#plt.loglog(WsBs_target_spectra.freq_r*2*np.pi, 2e-3*WsBs_target_spectra.freq_r**-3, '--',linewidth=1.5,color='gray', label='k^{-3}')
plt.loglog(WsBs_target_spectra.freq_r*2*np.pi, WsBs_target_spectra/WsBs_target_spectra[0],linewidth=2, label='target')
plt.loglog(WsBs_target_spectra.freq_r*2*np.pi, WsBs_prediction_spectra/WsBs_target_spectra[0],linewidth=2, label='prediction')
plt.legend()
plt.xlabel('$k_r$')
#plt.ylabel('Normalized isotropic spectra')
plt.title('WsBs')
# Out:
# Text(0.5, 1.0, 'WsBs')
