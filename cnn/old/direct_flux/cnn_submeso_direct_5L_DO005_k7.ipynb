# %%
import torch
import torch.nn.functional as F
import torch.utils.data as Data
import torchvision
from torch import nn, optim
from torch.autograd import Variable
import numpy as np
import os
import glob
import xarray as xr
from sklearn import preprocessing
import netCDF4 as nc
import matplotlib.pyplot as plt



np.random.seed(14)  # For reproducibility
torch.manual_seed(14)  # For reproducibility

# %% [markdown]
# # Dataloader

# %% [markdown]
# ### Create input and output channels

# %%
# function that splits datasets along the spacial axes and concats them back into single array under time

def normalize(data):
    #normalized_data =  (data - data.mean(skipna=True).values)/data.std(skipna=True).values
    normalized_data = (data - np.mean(data))/np.std(data)
    return normalized_data


def load_norm_data(var_name_string):
    PATH_LIST = glob.glob(BASE+'*/preprocessed_data/'+var_name_string+'.nc') 
    data_app = normalize(xr.open_dataarray(PATH_LIST[0]).to_numpy()[:,5:-5,5:-5])
    for i_file in np.arange(1,len(PATH_LIST)):
        PATH = PATH_LIST[i_file]
        data = xr.open_dataarray(PATH).to_numpy()[:,5:-5,5:-5]
        data_norm = normalize(data)
        data_app = np.concatenate((data_app,data_norm),axis=0)
    return data_app

# depth of CNN * (kernel_num-1)/2
#def load_norm_data_out(var_name_string): #with cropping for output
#    PATH_LIST = glob.glob(BASE+'*/preprocessed_data/'+var_name_string+'.nc') 
#    data_app = normalize(xr.open_dataarray(PATH_LIST[0]).to_numpy()[:,14:-14,14:-14])
#    for i_file in np.arange(1,len(PATH_LIST)):
#        PATH = PATH_LIST[i_file]
#        data = xr.open_dataarray(PATH).to_numpy()[:,14:-14,14:-14]
#        data_norm = normalize(data)
#        data_app = np.concatenate((data_app,data_norm),axis=0)
#    return data_app


def split_data(data):
    data_split_halfs = np.concatenate((np.split(data,2,axis=1)[0],np.split(data,2,axis=1)[1]),0)
    data_split_quarters = np.concatenate((np.split(data_split_halfs,2,axis=2)[0],np.split(data_split_halfs,2,axis=2)[1]),0)
    return data#data_split_quarters



def load_split_norm_data(var_name_string):
    loaded_data = load_norm_data(var_name_string)
    splitted_data = split_data(loaded_data)
    return splitted_data
    
    
def load_split_norm_data_out(var_name_string):
    loaded_data = load_norm_data(var_name_string)
    splitted_data = split_data(loaded_data)
    cropped_output = splitted_data[:,5:-5,5:-5] # for a kernel of size 3 with 5 conv layers
    return cropped_output

# %%
# load preprocessed data, convert to numpy and stack channels

BASE = '/scratch/ab10313/submeso_ML_data/'
FULL_PATH_PP = glob.glob(BASE+'*/preprocessed_data/')

# X INPUT
ds_Bm = load_split_norm_data('Bm_MLD_lowres')
ds_Um = load_split_norm_data('Um_MLD_lowres')
ds_Vm = load_split_norm_data('Vm_MLD_lowres')
ds_Wm = load_split_norm_data('Wm_MLD_lowres')


X_input = np.stack([ds_Bm,ds_Um,ds_Vm,ds_Wm],axis=1)
print('X input shape:')
print( X_input.shape)
print('')


# Y OUTPUT
ds_UsBs = load_split_norm_data('UsBs_MLD_lowres')
ds_VsBs = load_split_norm_data('VsBs_MLD_lowres')
ds_WsBs = load_split_norm_data('WsBs_MLD_lowres')

Y_output = np.stack([ds_UsBs,ds_VsBs,ds_WsBs],axis=1)
print('Y output shape:')
print(Y_output.shape)
print('')


# GRAD B
ds_Bm_x = load_split_norm_data('Bm_x_MLD_lowres')
ds_Bm_y = load_split_norm_data('Bm_y_MLD_lowres')
ds_Bm_z = load_split_norm_data('Bm_z_MLD_lowres')

grad_b = np.stack([ds_Bm_x,ds_Bm_y,ds_Bm_z],axis=1)
print('grad b shape:')
print( grad_b.shape)
# Out:
# X input shape:
# (1720, 4, 30, 30)
#
# Y output shape:
# (1720, 3, 30, 30)
#
# grad b shape:
# (1720, 3, 30, 30)

# %% [markdown]
# ### randomly generate train, test and validation sets

# %%
# TRAIN AND TEST ONLY
# randomnly generate train, test and validation time indecies 
import random
time_ind = X_input.shape[0]
rand_ind = np.arange(time_ind)
rand_seed = 14
random.Random(rand_seed).shuffle(rand_ind)
train_percent = 0.9
test_percent = 0.1 
print(f"Dataset: train {np.round(train_percent*100)}%, test {np.round(test_percent*100)}%")
train_ind, test_ind =  rand_ind[:round(train_percent*time_ind)], rand_ind[round((train_percent)*time_ind):]                                                                        

# check no overlapping indecies
if np.intersect1d(train_ind, test_ind).any():
    print('overlapping indecies')
else:
    print ('no overlapping indecies')
# Out:
# Dataset: train 90.0%, test 10.0%
# no overlapping indecies

# %% [markdown]
# ### defined train, test and val dataloaders

# %%
# Define X,Y pairs (state, subgrid fluxes) for local network.local_torch_dataset = Data.TensorDataset(
BATCH_SIZE = 64  # Number of sample in each batch


###### training dataset #######
torch_dataset_train = Data.TensorDataset(
    torch.from_numpy(X_input[train_ind]).double(),
    torch.from_numpy(Y_output[train_ind]).double(),
)

loader_train = Data.DataLoader(
    dataset=torch_dataset_train, batch_size=BATCH_SIZE, shuffle=True
)
print('TRAIN')
print('X input shape:')
print( X_input[train_ind].shape)
print('Y output shape:')
print( Y_output[train_ind].shape)
print('')

###### test dataset #######
torch_dataset_test = Data.TensorDataset(
    torch.from_numpy(X_input[test_ind]).double(),
    torch.from_numpy(Y_output[test_ind]).double(),    
)

BATCH_SIZE_TEST = len(torch_dataset_test)

loader_test = Data.DataLoader(
    dataset=torch_dataset_test, batch_size=BATCH_SIZE_TEST, shuffle=True
)

print('TEST')
print('X input shape:')
print( X_input[test_ind].shape)
print('Y output shape:')
print( Y_output[test_ind].shape)
print('')

###### validation dataset #######
#torch_dataset_val = Data.TensorDataset(
#    torch.from_numpy(X_input[val_ind]).double(),
#    torch.from_numpy(Y_output[val_ind]).double(),
#)


#loader_val = Data.DataLoader(
#    dataset=torch_dataset_val, batch_size=BATCH_SIZE, shuffle=True
#)

#print('VAL')
#print('X input shape:')
#print( X_input[val_ind].shape)
#print('Y output shape:')
#print( Y_output[val_ind].shape)
#print('')
# Out:
# TRAIN
# X input shape:
# (1548, 4, 30, 30)
# Y output shape:
# (1548, 3, 30, 30)
#
# TEST
# X input shape:
# (172, 4, 30, 30)
# Y output shape:
# (172, 3, 30, 30)

# %% [markdown]
# ## CNN - direct fluxes 3 output channels

# %%
# define network structure in pytorch
import torch.nn.functional as FF

class CNN_direct(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(4, 128, 7, padding='same', padding_mode='reflect')  # 4 inputs, 64 neurons for first hidden layer
        self.dropout1 = nn.Dropout(0.05)
        self.conv1_bn=nn.BatchNorm2d(128)
        self.conv2 = nn.Conv2d(128, 64, 7, padding='same', padding_mode='reflect')  # 64 inputs, 32 neurons for first hidden layer
        self.dropout2 = nn.Dropout(0.05)
        self.conv2_bn=nn.BatchNorm2d(64)
        self.conv3 = nn.Conv2d(64, 32, 7, padding='same', padding_mode='reflect')  # 32 inputs, 16 neurons for first hidden layer
        self.dropout3 = nn.Dropout(0.05)
        self.conv3_bn=nn.BatchNorm2d(32)  
        self.conv4 = nn.Conv2d(32, 16, 7, padding='same', padding_mode='reflect')  # 16 inputs, 3 neurons for first hidden layer
        self.dropout4 = nn.Dropout(0.05)
        self.conv4_bn=nn.BatchNorm2d(16) 
        self.conv5 = nn.Conv2d(16, 3, 7, padding='same', padding_mode='reflect')  # 32 inputs, 24 neurons for first hidden layer
        self.dropout5 = nn.Dropout(0.05)
        self.conv5_bn=nn.BatchNorm2d(3) 

    def forward(self, x):
        x = self.conv1(x)
        x = self.dropout1(x)
        x = F.relu(self.conv1_bn(x))
        x = self.conv2(x)
        x = self.dropout2(x)
        x = F.relu(self.conv2_bn(x))
        x = self.conv3(x)
        x = self.dropout3(x)
        x = F.relu(self.conv3_bn(x))
        x = self.conv4(x)
        x = self.dropout4(x)
        x = F.relu(self.conv4_bn(x))
        x = self.conv5(x)
        x = self.dropout5(x)
        x = self.conv5_bn(x)
        return x
 
    
# define network structure in pytorch
import torch.nn.functional as FF

#class CNN_direct(nn.Module):
#    def __init__(self):
#        super().__init__()
#        self.conv1 = nn.Conv2d(4, 64, 5,padding='same')  # 4 inputs, 128 neurons for first hidden layer
#        self.conv2 = nn.Conv2d(64, 32, 5,padding='same')  # 64 inputs, 32 neurons for first hidden layer
#        self.conv3 = nn.Conv2d(32, 3, 5,padding='same')  # 32 inputs, 24 neurons for first hidden layer

#    def forward(self, x):
#        x = FF.relu(self.conv1(x))
#        x = FF.relu(self.conv2(x))
#        x = self.conv3(x)
#        return x

# %% [markdown]
# ## Train and test model: direct fluxes

# %%
# train network 
def train_model_direct(net, criterion, trainloader, optimizer, len_train_dataset, text="train"):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    net.to(device)
    device_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else "cpu"
    print(f"Training starts on device {device_name}, number of samples {len(trainloader)}")
    
    net.train()
    train_loss = 0
    for step, (batch_x, batch_y) in enumerate(trainloader):  # for each training step
        b_x = Variable(batch_x)  # Inputs
        b_y = Variable(batch_y)  # outputs
        prediction = net(b_x.to(device))
        loss = criterion(prediction, b_y.to(device))  # Calculating loss
        optimizer.zero_grad()  # clear gradients for next train
        loss.backward()  # backpropagation, compute gradients
        optimizer.step()  # apply gradients to update weights
        nb = b_y.shape[0]
        train_loss = train_loss + nb * loss.detach().cpu().numpy()  # Keep track of the loss
    train_loss /= len_train_dataset  # dividing by the number of batches
    print(text + " loss:", train_loss)
    return train_loss


def test_model_direct(net, criterion, testloader, optimizer,len_test_dataset, text="test"):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    net.to(device)
    device_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else "cpu"
    print(f"Training starts on device {device_name}, number of samples {len(testloader)}")
    
    net.eval()  # Evaluation mode (important when having dropout layers)
    test_loss = 0
    with torch.no_grad():
        for step, (batch_x, batch_y) in enumerate(
            testloader
        ):  # for each training step
            b_x = Variable(batch_x)  # Inputs
            b_y = Variable(batch_y)  # outputs
            prediction = net(b_x.to(device))
            loss = criterion(prediction, b_y.to(device))  # Calculating loss
            nb = b_y.shape[0]
            test_loss = test_loss + nb * loss.detach().cpu().numpy()  # Keep track of the loss
        test_loss /= len_test_dataset  # dividing by the number of batches
        #         print(len(trainloader))
        print(text + " loss:", test_loss)
    return test_loss



def plot_model_direct(net, criterion, testloader, optimizer, len_test_dataset, text="test"):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    net.to(device)
    device_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else "cpu"
    print(f"Training starts on device {device_name}, number of samples {len(testloader)}")
    
    net.eval()  # Evaluation mode (important when having dropout layers)
    test_loss = 0
    with torch.no_grad():
        for step, (batch_x, batch_y) in enumerate(
            testloader
        ):  # for each training step
            b_x = Variable(batch_x)  # Inputs
            b_y = Variable(batch_y)  # outputs
            prediction = net(b_x.to(device))
            loss = criterion(prediction, b_y.to(device))  # Calculating loss
            nb = b_y.shape[0]
            test_loss = test_loss + nb * loss.detach().cpu().numpy()  # Keep track of the loss
        test_loss /= len_test_dataset  # dividing by the number of batches
        #         print(len(trainloader))
        print(text + " loss:", test_loss)
    return b_x, b_y, prediction


criterion = torch.nn.MSELoss()  # MSE loss function

# %% [markdown]
# ## train CNN!

# %%
torch.manual_seed(14)  # For reproducibility
cnn_submeso = CNN_direct().double()

n_epochs = 100  # Number of epocs could be increased
optimizer = optim.Adam(cnn_submeso.parameters(), lr=0.03)
test_loss = list()
train_loss = list()
for epoch in range(1, n_epochs + 1):
    print("epoch:", epoch)
    train_loss.append(train_model_direct(cnn_submeso, criterion, loader_train, optimizer,len(torch_dataset_train)))
    test_loss.append(test_model_direct(cnn_submeso, criterion, loader_test, optimizer,len(torch_dataset_test)))
# Out:
# epoch: 1
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 1.2911210808808788
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 1.1743484969444178
# epoch: 2
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.9621006489099179
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.9051854220628637
# epoch: 3
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.9461853511892235
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8860631425356491
# epoch: 4
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.9304890022632439
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8777536000355425
# epoch: 5
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.9204040834771477
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8644618316142868
# epoch: 6
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.9093609735277827
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8514228497345318
# epoch: 7
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.8988184818746418
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8445844639078878
# epoch: 8
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.8876212878612352
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8524857336746012
# epoch: 9
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.8779294783653213
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8366254487284459
# epoch: 10
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.8700072458026711
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8160340826387723
# epoch: 11
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.8574650042973208
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8222043365710804
# epoch: 12
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.847160726838857
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.800985044666816
# epoch: 13
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.8392603955216906
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7895128680216483
# epoch: 14
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.832876888821961
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.794247222266798
# epoch: 15
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.8231470491531093
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.780637124357156
# epoch: 16
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.8129001445339276
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7759367008818537
# epoch: 17
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.8045888912680835
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7635665882314938
# epoch: 18
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.8012609139717528
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7581752343561992
# epoch: 19
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.788482564032201
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7639186019311274
# epoch: 20
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.7829226379926713
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7661838390217051
# epoch: 21
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.7742613628085815
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7552178140010933
# epoch: 22
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.7704733479674271
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7526770737754619
# epoch: 23
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.7653870680401069
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7422907646334608
# epoch: 24
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.755870704131733
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7406055683436664
# epoch: 25
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.750565229738524
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.717141949831562
# epoch: 26
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.7433842333183511
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7303609266675343
# epoch: 27
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.740066885009699
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7318727458465153
# epoch: 28
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.7372680262064264
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7146307845610383
# epoch: 29
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.7276969255850309
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7320252208232922
# epoch: 30
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.723320004863598
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7128267648933854
# epoch: 31
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.7202382125427566
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6991159868907431
# epoch: 32
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.7156518502656094
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7007543044972834
# epoch: 33
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.7167367447891461
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7085530444711925
# epoch: 34
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.7110928172737785
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7107448614563407
# epoch: 35
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.7057334950528957
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6899331505646689
# epoch: 36
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.6959456082306185
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7003681967799467
# epoch: 37
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.6999949845216781
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.704157032456564
# epoch: 38
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.690564178020178
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6688922860209316
# epoch: 39
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.6876880191302558
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6830524221820304
# epoch: 40
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.6877152656346465
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6736791721858693
# epoch: 41
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.6801616917507396
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6849505890468744
# epoch: 42
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.6767960100774438
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6905411048305888
# epoch: 43
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.6747838123851553
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6634084270908154
# epoch: 44
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.6724947490894091
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6813884452425368
# epoch: 45
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.6717688003029403
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.670113316457859
# epoch: 46
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.6689923493743185
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6536214194457407
# epoch: 47
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.6638309557359058
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6510610290724074
# epoch: 48
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.6613020665343057
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6500812403361678
# epoch: 49
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.6611983984773647
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6565252294238886
# epoch: 50
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.6545745769461673
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6406985314859781
# epoch: 51
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.6503745023512749
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6442282891385399
# epoch: 52
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.6526153723429672
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6506416541873958
# epoch: 53
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.6496340301717302
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6328043117132768
# epoch: 54
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.642398716440362
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6325437644716987
# epoch: 55
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.6422438687341875
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6719009361293142
# epoch: 56
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.6480765153623188
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6448234029463918
# epoch: 57
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.6396915911374073
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6318967065171932
# epoch: 58
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.637336098302329
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6313271923795879
# epoch: 59
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.6324956160030668
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.635717523827721
# epoch: 60
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.6352126952215996
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.664549006024115
# epoch: 61
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.6329732220771469
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7119786068374269
# epoch: 62
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.6297761289211031
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6284146345864812
# epoch: 63
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.6276147793460333
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6305589981114037
# epoch: 64
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.627220589100811
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6871965762324866
# epoch: 65
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.6269512775593316
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.657393146845713
# epoch: 66
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.6220521310254703
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6292205207615273
# epoch: 67
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.6205115350992187
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6377487768003022
# epoch: 68
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.6219537148899896
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6162495279811362
# epoch: 69
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.6204917500881943
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6137471955640571
# epoch: 70
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.6186208801808893
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6409391817377545
# epoch: 71
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.619750410558017
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6194045397235362
# epoch: 72
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.6141055083243769
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.630333598165039
# epoch: 73
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.6152648403106764
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6281534724043696
# epoch: 74
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.6150864149391108
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6305053232364718
# epoch: 75
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.6126432181987447
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.619135612681559
# epoch: 76
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.6100066138224305
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6054262913491432
# epoch: 77
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.6116387016113807
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.632786082445249
# epoch: 78
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.6101935079648066
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6185360314223626
# epoch: 79
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.609054232617748
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6467855701944659
# epoch: 80
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.607837689997974
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6241540919977899
# epoch: 81
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.6071855755149269
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6238827287835094
# epoch: 82
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.6084170630334532
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6183100810666804
# epoch: 83
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.6021722397613255
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6161348213151395
# epoch: 84
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.602989255383017
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6339351634340474
# epoch: 85
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.600871443853784
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6272761622501757
# epoch: 86
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.60201409185418
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6182595422194419
# epoch: 87
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.60398636475607
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6138475596742987
# epoch: 88
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.6000606388130131
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6152447313673327
# epoch: 89
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.5978563595776873
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6113537944642784
# epoch: 90
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.5946894875022637
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.618684890445001
# epoch: 91
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.5965655368736739
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6157453836648928
# epoch: 92
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.5956827492010709
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6114411494568859
# epoch: 93
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.5903569383973478
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.5963340520240344
# epoch: 94
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.596350095066605
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6526407072106838
# epoch: 95
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.5961467366750824
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.610612607240658
# epoch: 96
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.5917222638791368
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.5996299902091945
# epoch: 97
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.5918722169867691
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6219411607084993
# epoch: 98
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.5915090620456589
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.607746147222135
# epoch: 99
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.5912822616579169
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6249443593959157
# epoch: 100
# Training starts on device Tesla V100-SXM2-16GB, number of samples 25
# train loss: 0.5914694895987254
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6281125344657007

# %%
import matplotlib.pyplot as plt

plt.plot(train_loss[1:], "b", label="training loss")
plt.plot(test_loss[1:], "r", label="test loss")

plt.legend();

# %%
b_x, b_y, prediction = plot_model_direct(cnn_submeso, criterion, loader_test, optimizer,len(torch_dataset_test))
# Out:
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.6281125344657007

# %%
from scipy import stats

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

corr_pred_ub = stats.pearsonr(cnn_submeso(b_x.to(device)).detach().cpu().numpy()[:,0,:,:].flatten(), b_y[:,0,:,:].flatten())
corr_pred_vb = stats.pearsonr(cnn_submeso(b_x.to(device)).detach().cpu().numpy()[:,1,:,:].flatten(), b_y[:,1,:,:].flatten())
corr_pred_wb = stats.pearsonr(cnn_submeso(b_x.to(device)).detach().cpu().numpy()[:,2,:,:].flatten(), b_y[:,2,:,:].flatten())

print("correlation between prediction and target,  u'b':",corr_pred_ub )
print("correlation between prediction and target,  v'b':",corr_pred_vb )
print("correlation between prediction and target,  w'b':",corr_pred_wb )
# Out:
# correlation between prediction and target,  u'b': (0.628310814143245, 0.0)
# correlation between prediction and target,  v'b': (0.6540678626579353, 0.0)
# correlation between prediction and target,  w'b': (0.5492953291835837, 0.0)

# %%
# visualize
it =45

fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(8, 4))
fig.tight_layout() # Or equivalently,  "plt.tight_layout()"

plt.subplot(231)
plt.pcolor(cnn_submeso(b_x.to(device)).detach().cpu().numpy()[it,0,:,:],cmap='viridis',vmin=-1,vmax =1)
plt.title('ub prediction')
plt.colorbar()

plt.subplot(234)
plt.pcolor(b_y[it,0,:,:],cmap='viridis',vmin=-1,vmax =1)
plt.title('ub target')
plt.colorbar()

plt.subplot(232)
plt.pcolor(cnn_submeso(b_x.to(device)).detach().cpu().numpy()[it,1,:,:],cmap='viridis',vmin=-1,vmax =1)
plt.title('vb prediction')
plt.colorbar()

plt.subplot(235)
plt.pcolor(b_y[it,1,:,:],cmap='viridis',vmin=-1,vmax =1)
plt.title('vb target')
plt.colorbar()

plt.subplot(233)
plt.pcolor(cnn_submeso(b_x.to(device)).detach().cpu().numpy()[it,2,:,:],cmap='viridis',vmin=-1,vmax =1)
plt.title('wb prediction')
plt.colorbar()

plt.subplot(236)
plt.pcolor(b_y[it,2,:,:],cmap='viridis',vmin=-1,vmax =1)
plt.title('wb target')
plt.colorbar()

# %%
_=plt.hist(b_y.detach().cpu().numpy().flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="target")
_=plt.hist(cnn_submeso(b_x.to(device)).detach().cpu().numpy().flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="prediction")

plt.xlim([-3,3])
plt.legend()

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(12, 4))
fig.tight_layout() # Or equivalently,  "plt.tight_layout()"

plt.subplot(131)
_=plt.hist(b_y.detach().cpu().numpy()[:,0,:,:].flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="target")
_=plt.hist(cnn_submeso(b_x.to(device)).detach().cpu().numpy()[:,0,:,:].flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="prediction")
plt.xlim([-3,3])
plt.legend()
plt.title('ub')


plt.subplot(132)
_=plt.hist(b_y.detach().cpu().numpy()[:,1,:,:].flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="target")
_=plt.hist(cnn_submeso(b_x.to(device)).detach().cpu().numpy()[:,1,:,:].flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="prediction")
plt.xlim([-3,3])
plt.legend()
plt.title('vb')

plt.subplot(133)
_=plt.hist(b_y.detach().cpu().numpy()[:,2,:,:].flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="target")
_=plt.hist(cnn_submeso(b_x.to(device)).detach().cpu().numpy()[:,2,:,:].flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="prediction")
plt.xlim([-3,3])
plt.legend()
plt.title('wb')
# Out:
# Text(0.5, 1.0, 'wb')

# %%
target_da = xr.DataArray(b_y.detach().cpu().numpy(), dims=["time", "axis", "i","j"])
prediction_da = xr.DataArray(cnn_submeso(b_x.to(device)).detach().cpu().numpy(), dims=["time", "axis", "i","j"])

# %%
import xrft

# target vs prediction spectra
UsBs_target_spectra = xrft.isotropic_power_spectrum(target_da.isel(axis=0),dim=['i','j'], 
                                           detrend='linear', window=True).compute().mean('time')

UsBs_prediction_spectra = xrft.isotropic_power_spectrum(prediction_da.isel(axis=0),dim=['i','j'], 
                                           detrend='linear', window=True).compute().mean('time')


VsBs_target_spectra = xrft.isotropic_power_spectrum(target_da.isel(axis=1),dim=['i','j'], 
                                           detrend='linear', window=True).compute().mean('time')

VsBs_prediction_spectra = xrft.isotropic_power_spectrum(prediction_da.isel(axis=1),dim=['i','j'], 
                                           detrend='linear', window=True).compute().mean('time')


WsBs_target_spectra = xrft.isotropic_power_spectrum(target_da.isel(axis=2),dim=['i','j'], 
                                           detrend='linear', window=True).compute().mean('time')

WsBs_prediction_spectra = xrft.isotropic_power_spectrum(prediction_da.isel(axis=2),dim=['i','j'], 
                                           detrend='linear', window=True).compute().mean('time')
# Out:
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:47: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:1025: FutureWarning: Isotropic wavenumber larger than the Nyquist wavenumber may result.
#   warnings.warn(msg, FutureWarning)
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:47: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:1025: FutureWarning: Isotropic wavenumber larger than the Nyquist wavenumber may result.
#   warnings.warn(msg, FutureWarning)
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:47: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:1025: FutureWarning: Isotropic wavenumber larger than the Nyquist wavenumber may result.
#   warnings.warn(msg, FutureWarning)
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:47: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:1025: FutureWarning: Isotropic wavenumber larger than the Nyquist wavenumber may result.
#   warnings.warn(msg, FutureWarning)
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:47: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:1025: FutureWarning: Isotropic wavenumber larger than the Nyquist wavenumber may result.
#   warnings.warn(msg, FutureWarning)
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:47: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:1025: FutureWarning: Isotropic wavenumber larger than the Nyquist wavenumber may result.
#   warnings.warn(msg, FutureWarning)

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(20, 5))
fig.tight_layout() # Or equivalently,  "plt.tight_layout()"

plt.subplot(131)
#plt.loglog(UsBs_target_spectra.freq_r*2*np.pi, 5e-3*UsBs_target_spectra.freq_r**-2, '--',linewidth=1.5,color='black', label='k^{-2}')
#plt.loglog(UsBs_target_spectra.freq_r*2*np.pi, 2e-3*UsBs_target_spectra.freq_r**-3, '--',linewidth=1.5,color='gray', label='k^{-3}')
plt.loglog(UsBs_target_spectra.freq_r*2*np.pi, UsBs_target_spectra/UsBs_target_spectra[0],linewidth=2, label='target')
plt.loglog(UsBs_prediction_spectra.freq_r*2*np.pi, UsBs_prediction_spectra/UsBs_target_spectra[0],linewidth=2, label='prediction')
plt.legend()
plt.xlabel('$k_r$')
plt.ylabel('Normalized isotropic spectra')
plt.title('UsBs')
plt.ylim([1e-3, 2])


plt.subplot(132)
#plt.loglog(VsBs_target_spectra.freq_r*2*np.pi, 5e-3*VsBs_target_spectra.freq_r**-2, '--',linewidth=1.5,color='black', label='k^{-2}')
#plt.loglog(VsBs_target_spectra.freq_r*2*np.pi, 2e-3*VsBs_target_spectra.freq_r**-3, '--',linewidth=1.5,color='gray', label='k^{-3}')
plt.loglog(VsBs_target_spectra.freq_r*2*np.pi, VsBs_target_spectra/VsBs_target_spectra[0],linewidth=2, label='target')
plt.loglog(VsBs_prediction_spectra.freq_r*2*np.pi, VsBs_prediction_spectra/VsBs_target_spectra[0],linewidth=2, label='prediction')
plt.legend()
plt.xlabel('$k_r$')
#plt.ylabel('Normalized isotropic spectra')
plt.title('VsBs')
plt.ylim([1e-3, 2])


plt.subplot(133)
#plt.loglog(WsBs_target_spectra.freq_r*2*np.pi, 5e-3*WsBs_target_spectra.freq_r**-2, '--',linewidth=1.5,color='black', label='k^{-2}')
#plt.loglog(WsBs_target_spectra.freq_r*2*np.pi, 2e-3*WsBs_target_spectra.freq_r**-3, '--',linewidth=1.5,color='gray', label='k^{-3}')
plt.loglog(WsBs_target_spectra.freq_r*2*np.pi, WsBs_target_spectra/WsBs_target_spectra[0],linewidth=2, label='target')
plt.loglog(WsBs_target_spectra.freq_r*2*np.pi, WsBs_prediction_spectra/WsBs_prediction_spectra[0],linewidth=2, label='prediction')
plt.legend()
plt.xlabel('$k_r$')
#plt.ylabel('Normalized isotropic spectra')
plt.title('WsBs')
plt.ylim([1e-3, 2])
# Out:
# (0.001, 2)
