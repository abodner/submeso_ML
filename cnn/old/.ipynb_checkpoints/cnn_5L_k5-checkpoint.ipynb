# %%
import torch
import torch.nn.functional as F
import torch.utils.data as Data
import torchvision
from torch import nn, optim
from torch.autograd import Variable
import numpy as np
import os
import glob
import xarray as xr
from sklearn import preprocessing
import netCDF4 as nc
import matplotlib.pyplot as plt



np.random.seed(14)  # For reproducibility
torch.manual_seed(14)  # For reproducibility

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %% [markdown]
# # Dataloader

# %% [markdown]
# ### Create input and output channels

# %%
# load preprocessed data into input and output channels

BASE = '/scratch/ab10313/pleiades/'
PATH_NN = BASE+'NN_data/'

# X INPUT
grad_B = np.load(PATH_NN+'grad_B.npy')
HML = np.load(PATH_NN+'HML.npy')
TAU = np.load(PATH_NN+'TAU.npy')
U = np.load(PATH_NN+'U.npy')
V = np.load(PATH_NN+'V.npy')
Q = np.load(PATH_NN+'Q.npy')
HBL = np.load(PATH_NN+'HBL.npy')
FCOR = np.load(PATH_NN+'FCOR.npy')


X_input = np.stack([FCOR, grad_B, HML, TAU, U, V, Q, HBL],axis=1)
print('X input shape:')
print( X_input.shape)
print('')


# Y OUTPUT
WB_sg = np.load(PATH_NN+'WB_sg.npy')
              
Y_output = np.tile(WB_sg,(1,1,1,1)).reshape(WB_sg.shape[0],1,WB_sg.shape[1],WB_sg.shape[2]) 
print('Y output shape:')
print(Y_output.shape)
print('')

np.isnan(X_input).any()
np.isnan(Y_output).any()
# Out:
# X input shape:
# (8460, 8, 40, 40)
#
# Y output shape:
# (8460, 1, 40, 40)
# False

# %% [markdown]
# ### randomly generate train, test and validation sets

# %%
# TRAIN AND TEST ONLY
# randomnly generate train, test and validation time indecies 
import random
time_ind = X_input.shape[0]
rand_ind = np.arange(time_ind)
rand_seed = 14
random.Random(rand_seed).shuffle(rand_ind)
train_percent = 0.9
test_percent = 0.1 
print(f"Dataset: train {np.round(train_percent*100)}%, test {np.round(test_percent*100)}%")
train_ind, test_ind =  rand_ind[:round(train_percent*time_ind)], rand_ind[round((train_percent)*time_ind):]                                                                        

# check no overlapping indecies
if np.intersect1d(train_ind, test_ind).any():
    print('overlapping indecies')
else:
    print ('no overlapping indecies')
# Out:
# Dataset: train 90.0%, test 10.0%
# no overlapping indecies

# %% [markdown]
# ### defined train, test and val dataloaders

# %%
# Define X,Y pairs (state, subgrid fluxes) for local network.local_torch_dataset = Data.TensorDataset(
BATCH_SIZE = 64  # Number of sample in each batch


###### training dataset #######
torch_dataset_train = Data.TensorDataset(
    torch.from_numpy(X_input[train_ind]).double(),
    torch.from_numpy(Y_output[train_ind]).double(),
)

loader_train = Data.DataLoader(
    dataset=torch_dataset_train, batch_size=BATCH_SIZE, shuffle=True
)
print('TRAIN')
print('X input shape:')
print( X_input[train_ind].shape)
print('Y output shape:')
print( Y_output[train_ind].shape)
print('')

###### test dataset #######
torch_dataset_test = Data.TensorDataset(
    torch.from_numpy(X_input[test_ind]).double(),
    torch.from_numpy(Y_output[test_ind]).double(),    
)

BATCH_SIZE_TEST = len(torch_dataset_test)

loader_test = Data.DataLoader(
    dataset=torch_dataset_test, batch_size=BATCH_SIZE_TEST, shuffle=False
)

print('TEST')
print('X input shape:')
print( X_input[test_ind].shape)
print('Y output shape:')
print( Y_output[test_ind].shape)
print('')
# Out:
# TRAIN
# X input shape:
# (7614, 8, 40, 40)
# Y output shape:
# (7614, 1, 40, 40)
#
# TEST
# X input shape:
# (846, 8, 40, 40)
# Y output shape:
# (846, 1, 40, 40)

# %% [markdown]
# ## CNN - direct fluxes 3 output channels

# %%
# define network structure in pytorch
import torch.nn.functional as FF

class CNN_direct(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(8, 128, 5, padding='same', padding_mode='reflect')  # 7 inputs, 128 neurons for first hidden layer
        self.conv1_bn=nn.BatchNorm2d(128)
        self.conv2 = nn.Conv2d(128, 64, 5, padding='same', padding_mode='reflect')  # 128 inputs, 64 neurons for first hidden layer
        self.conv2_bn=nn.BatchNorm2d(64)
        self.conv3 = nn.Conv2d(64, 32, 5, padding='same', padding_mode='reflect')  # 64 inputs, 32 neurons for first hidden layer
        self.conv3_bn=nn.BatchNorm2d(32)  
        self.conv4 = nn.Conv2d(32, 16, 5, padding='same', padding_mode='reflect')  # 32 inputs, 16 neurons for first hidden layer
        self.conv4_bn=nn.BatchNorm2d(16) 
        self.conv5 = nn.Conv2d(16, 1, 5, padding='same', padding_mode='reflect')  # 16 inputs, 1 neurons for first hidden layer
        self.conv5_bn=nn.BatchNorm2d(1) 

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(self.conv1_bn(x))
        x = self.conv2(x)
        x = F.relu(self.conv2_bn(x))
        x = self.conv3(x)
        x = F.relu(self.conv3_bn(x))
        x = self.conv4(x)
        x = F.relu(self.conv4_bn(x))
        x = self.conv5(x)
        x = self.conv5_bn(x)
        return x

# %% [markdown]
# ## Train and test model: direct fluxes

# %%
# train network 
def train_model_direct(net, criterion, trainloader, optimizer, len_train_dataset, text="train"):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    net.to(device)
    device_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else "cpu"
    print(f"Training starts on device {device_name}, number of samples {len(trainloader)}")
    
    net.train()
    train_loss = 0
    for step, (batch_x, batch_y) in enumerate(trainloader):  # for each training step
        b_x = Variable(batch_x)  # Inputs
        b_y = Variable(batch_y)  # outputs
        prediction = net(b_x.to(device))
        loss = criterion(prediction, b_y.to(device))  # Calculating loss
        optimizer.zero_grad()  # clear gradients for next train
        loss.backward()  # backpropagation, compute gradients
        optimizer.step()  # apply gradients to update weights
        nb = b_y.shape[0]
        train_loss = train_loss + nb * loss.detach().cpu().numpy()  # Keep track of the loss
    train_loss /= len_train_dataset  # dividing by the number of batches
    print(text + " loss:", train_loss)
    return train_loss


def test_model_direct(net, criterion, testloader, optimizer,len_test_dataset, text="test"):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    net.to(device)
    device_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else "cpu"
    print(f"Training starts on device {device_name}, number of samples {len(testloader)}")
    
    net.eval()  # Evaluation mode (important when having dropout layers)
    test_loss = 0
    with torch.no_grad():
        for step, (batch_x, batch_y) in enumerate(
            testloader
        ):  # for each training step
            b_x = Variable(batch_x)  # Inputs
            b_y = Variable(batch_y)  # outputs
            prediction = net(b_x.to(device))
            loss = criterion(prediction, b_y.to(device))  # Calculating loss
            nb = b_y.shape[0]
            test_loss = test_loss + nb * loss.detach().cpu().numpy()  # Keep track of the loss
        test_loss /= len_test_dataset  # dividing by the number of batches
        #         print(len(trainloader))
        print(text + " loss:", test_loss)
    return test_loss



def plot_model_direct(net, criterion, testloader, optimizer, len_test_dataset, text="test"):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    net.to(device)
    device_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else "cpu"
    print(f"Training starts on device {device_name}, number of samples {len(testloader)}")
    
    net.eval()  # Evaluation mode (important when having dropout layers)
    test_loss = 0
    with torch.no_grad():
        for step, (batch_x, batch_y) in enumerate(
            testloader
        ):  # for each training step
            b_x = Variable(batch_x)  # Inputs
            b_y = Variable(batch_y)  # outputs
            prediction = net(b_x.to(device))
            loss = criterion(prediction, b_y.to(device))  # Calculating loss
            nb = b_y.shape[0]
            test_loss = test_loss + nb * loss.detach().cpu().numpy()  # Keep track of the loss
        test_loss /= len_test_dataset  # dividing by the number of batches
        #         print(len(trainloader))
        print(text + " loss:", test_loss)
    return b_x, b_y, prediction


criterion = torch.nn.MSELoss()  # MSE loss function

# %% [markdown]
# ## train CNN!

# %%
torch.manual_seed(14)  # For reproducibility
cnn_submeso = CNN_direct().double()

n_epochs = 100  # Number of epocs could be increased
optimizer = optim.Adam(cnn_submeso.parameters(), lr=0.1)
test_loss = list()
train_loss = list()
for epoch in range(1, n_epochs + 1):
    print("epoch:", epoch)
    train_loss.append(train_model_direct(cnn_submeso, criterion, loader_train, optimizer,len(torch_dataset_train)))
    test_loss.append(test_model_direct(cnn_submeso, criterion, loader_test, optimizer,len(torch_dataset_test)))
# Out:
# epoch: 1
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.9582241472614805
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.9430461511411713
# epoch: 2
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.9157185937265031
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.9215882864875221
# epoch: 3
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.9081981926893232
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.9276291216391043
# epoch: 4
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.9046212318940255
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.9225434527309315
# epoch: 5
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.9003336222646954
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.9140521485936001
# epoch: 6
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.900143272793247
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.9075547153948326
# epoch: 7
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.8970001819288395
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.9233392558483176
# epoch: 8
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.8934389972734484
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.9139278104597757
# epoch: 9
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.8917094845652244
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.9069441896862815
# epoch: 10
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.8870579653373049
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8960973604411182
# epoch: 11
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.8832887752000396
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8970450605344036
# epoch: 12
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.8807977760717145
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.9009758108138977
# epoch: 13
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.8718283825641058
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.9086702750160354
# epoch: 14
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.863746807392493
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8832669825421973
# epoch: 15
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.8607135906674028
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.866128592107053
# epoch: 16
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.8587949996140465
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8949206916264634
# epoch: 17
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.8580819248520889
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.877200584982835
# epoch: 18
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.8508060971740864
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8586057996119897
# epoch: 19
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.8466670120297378
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8521082237559774
# epoch: 20
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.8444763452820709
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8718512272919395
# epoch: 21
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.8453113000507533
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8599796652509537
# epoch: 22
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.8391478498148511
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8704335686620607
# epoch: 23
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.8378356524622108
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8497414766003331
# epoch: 24
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.8350398263135179
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8568004797245238
# epoch: 25
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.8288987287208631
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8415417325091908
# epoch: 26
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.8271590545815642
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8399655748840239
# epoch: 27
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.8295391410140184
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8393694950923539
# epoch: 28
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.8229556283567901
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8333953832340422
# epoch: 29
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.8216722451224975
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8353033013858847
# epoch: 30
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.8189726650912397
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8382729049575982
# epoch: 31
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.8228148503628746
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8417196191444426
# epoch: 32
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.8145559025205376
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8657495516150489
# epoch: 33
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.814263371580352
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8335882614168743
# epoch: 34
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.8114198340657451
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8258957763269891
# epoch: 35
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.8070479079507934
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8311656765790847
# epoch: 36
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.8060969762371374
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8415767890684597
# epoch: 37
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.8009146525344165
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.81476316248139
# epoch: 38
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7974101603166801
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 1.0020113029798388
# epoch: 39
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7966408975222952
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8089231544502522
# epoch: 40
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7934219700327703
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8216870269525595
# epoch: 41
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7888750517219345
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7941423158175629
# epoch: 42
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7849491503931721
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7989088636489965
# epoch: 43
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7832257508433632
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8129457597660884
# epoch: 44
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7842331166756144
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7909839974538175
# epoch: 45
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7709301076834936
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7753896725773418
# epoch: 46
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7679503559593692
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7958531556676096
# epoch: 47
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7671231734563135
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7672329402894835
# epoch: 48
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7614390691522092
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.786520492820261
# epoch: 49
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7541345816707418
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.774744423725548
# epoch: 50
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7524466321828431
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7586580635326902
# epoch: 51
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7554137419318022
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7904918025445057
# epoch: 52
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7505650021557541
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.787269732738939
# epoch: 53
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7525457225368859
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8325134875324349
# epoch: 54
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7371922464383639
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.753277773384629
# epoch: 55
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7421874680154257
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7587101034376627
# epoch: 56
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7277748504384662
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7465551319063558
# epoch: 57
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7295310511127782
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7598908752737452
# epoch: 58
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7347648670533121
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7360608953343681
# epoch: 59
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7308556639871758
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7429941778517841
# epoch: 60
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7230859796284275
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7372120527207047
# epoch: 61
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7186313635786407
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7390584030990506
# epoch: 62
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7161509232242657
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7665315362234609
# epoch: 63
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7145937067460562
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7565782434018206
# epoch: 64
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7107058595225828
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7859616699682161
# epoch: 65
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7078184599385425
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7211268381420448
# epoch: 66
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7064997355012025
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7260062089521152
# epoch: 67
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7028867739196516
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7217033235801635
# epoch: 68
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6989995828915917
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7213232461727386
# epoch: 69
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7030145973389285
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8152691471919409
# epoch: 70
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6922927853525725
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7001421492928165
# epoch: 71
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6905962012795206
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7398886623686861
# epoch: 72
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6899823144975005
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8036274003126214
# epoch: 73
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.691784282910533
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7230662753760158
# epoch: 74
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6893049530881493
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6962166234223127
# epoch: 75
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6813842524288823
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7245554491074154
# epoch: 76
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6799627573433146
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6943451738994401
# epoch: 77
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6763101408835052
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7227154043715661
# epoch: 78
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6797338735195131
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7432235678449423
# epoch: 79
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.675625719257468
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6992035674555155
# epoch: 80
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.675393613648457
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6984187831449481
# epoch: 81
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6661845020552666
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6752189999009585
# epoch: 82
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6643270704763741
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6795013957189335
# epoch: 83
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6622872727405743
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.690701827048901
# epoch: 84
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6633301111775968
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6852656743219361
# epoch: 85
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6632711221472867
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6992481983273149
# epoch: 86
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6579781860225913
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6893724301179606
# epoch: 87
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6536906483861884
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6799472959198817
# epoch: 88
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.656862874460173
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6784851150479041
# epoch: 89
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.65274811817764
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7135837960662829
# epoch: 90
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.653114261115645
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.761402940820256
# epoch: 91
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6511445377996213
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.675280208424523
# epoch: 92
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6482939465619924
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6881344037599758
# epoch: 93
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6503350411564226
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6842243632825555
# epoch: 94
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6399893324351121
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6567903408180892
# epoch: 95
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6468484718781926
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7029779024468622
# epoch: 96
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.642862039668776
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.662219736714794
# epoch: 97
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.64217167562287
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7015293319646158
# epoch: 98
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6409685248409297
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6856577906663107
# epoch: 99
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.639480742427698
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.660600160492359
# epoch: 100
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6375841332042349
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.679575105587879

# %%
import matplotlib.pyplot as plt

plt.plot(train_loss[1:], "b", linewidth=3,label="training loss")
plt.plot(test_loss[1:], "lightblue",linewidth=3, label="test loss")
plt.xlabel('Epochs')
plt.ylabel('MSE Loss')
plt.legend();

# %%
total_params = sum(
	param.numel() for param in cnn_submeso.parameters()
)
total_params
# Out:
# 295523

# %%
b_x, b_y, prediction = plot_model_direct(cnn_submeso, criterion, loader_test, optimizer,len(torch_dataset_test))
# Out:
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.679575105587879

# %%
# compare with FK
WB_FK = np.load(PATH_NN+'WB_FK.npy')
WB_FK_test = WB_FK[test_ind]

# %%
from scipy import stats

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

corr_pred_wb = stats.pearsonr(cnn_submeso(b_x.to(device)).detach().cpu().numpy().flatten(), b_y.flatten())

print("correlation between prediction and target,  w'b':",corr_pred_wb )
# Out:
# correlation between prediction and target,  w'b': (0.5912212419747392, 0.0)

# %%
# visualize
it =5

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(12, 6))
fig.tight_layout() # Or equivalently,  "plt.tight_layout()"

plt.subplot(231)
plt.pcolor(cnn_submeso(b_x.to(device)).detach().cpu().numpy()[it,0,:,:],cmap='coolwarm',vmin=-2,vmax =2)
plt.title('wb prediction')
plt.colorbar()
plt.axis('off')

plt.subplot(232)
plt.pcolor(b_y[it,0,:,:],cmap='coolwarm',vmin=-2,vmax =2)
plt.title('wb target')
plt.colorbar()
plt.axis('off')

plt.subplot(233)
plt.pcolor(WB_FK_test[it],cmap='coolwarm',vmin=-2,vmax =2)
plt.title('wb FK')
plt.colorbar()
plt.axis('off')
# Out:
# (0.0, 40.0, 0.0, 40.0)

# %%
_=plt.hist(b_y.detach().cpu().numpy().flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="target")
_=plt.hist(cnn_submeso(b_x.to(device)).detach().cpu().numpy().flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="prediction")

plt.xlim([-3,3])
plt.legend()

# %%
b_y.detach().cpu().numpy().shape
# Out:
# (846, 1, 40, 40)

# %%
target_da = xr.DataArray(b_y.detach().cpu().numpy(), dims=["time", "axis", "i","j"])[:,0,:,:]
prediction_da = xr.DataArray(cnn_submeso(b_x.to(device)).detach().cpu().numpy(), dims=["time", "axis", "i","j"])[:,0,:,:]

# %%
import xrft

# target vs prediction spectra

WsBs_target_spectra = xrft.isotropic_power_spectrum(target_da,dim=['i','j'], 
                                           detrend='linear', window=True).compute().mean('time')

WsBs_prediction_spectra = xrft.isotropic_power_spectrum(prediction_da,dim=['i','j'], 
                                           detrend='linear', window=True).compute().mean('time')
# Out:
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:47: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:1025: FutureWarning: Isotropic wavenumber larger than the Nyquist wavenumber may result.
#   warnings.warn(msg, FutureWarning)
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:47: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:1025: FutureWarning: Isotropic wavenumber larger than the Nyquist wavenumber may result.
#   warnings.warn(msg, FutureWarning)

# %%
WsBs_target_spectra
# Out:
# <xarray.DataArray (freq_r: 10)>
# array([0.0231168 , 0.02819176, 0.03467243, 0.03242226, 0.03966008,
#        0.03814904, 0.03636939, 0.03721488, 0.03496538, 0.03527698])
# Coordinates:
#   * freq_r   (freq_r) float64 0.04232 0.1063 0.1767 ... 0.524 0.5938 0.6585

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(4, 10))
fig.tight_layout() # Or equivalently,  "plt.tight_layout()"

plt.subplot(311)
#plt.loglog(WsBs_target_spectra.freq_r*2*np.pi, 5e-3*WsBs_target_spectra.freq_r**-2, '--',linewidth=1.5,color='black', label='k^{-2}')
#plt.loglog(WsBs_target_spectra.freq_r*2*np.pi, 2e-3*WsBs_target_spectra.freq_r**-3, '--',linewidth=1.5,color='gray', label='k^{-3}')
plt.loglog(WsBs_target_spectra.freq_r*2*np.pi, WsBs_target_spectra/WsBs_target_spectra[0],linewidth=3, label='target')
plt.loglog(WsBs_target_spectra.freq_r*2*np.pi, WsBs_prediction_spectra/WsBs_prediction_spectra[0],linewidth=3, label='prediction')
plt.legend()
plt.xlabel('$k_r$')
#plt.ylabel('Normalized isotropic spectra')
plt.title('WsBs')
plt.ylim([1e-3,3])
# Out:
# (0.001, 3)
