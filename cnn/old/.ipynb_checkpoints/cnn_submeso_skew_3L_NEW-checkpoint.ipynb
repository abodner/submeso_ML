# %%
import torch
import torch.nn.functional as F
import torch.utils.data as Data
import torchvision
from torch import nn, optim
from torch.autograd import Variable
import numpy as np
import os
import glob
import xarray as xr
from sklearn import preprocessing
import netCDF4 as nc
import matplotlib.pyplot as plt



np.random.seed(14)  # For reproducibility
torch.manual_seed(14)  # For reproducibility

# %% [markdown]
# # Dataloader

# %% [markdown]
# ### Create input and output channels

# %%
# function that splits datasets along the spacial axes and concats them back into single array under time

def normalize(data):
    #normalized_data =  (data - data.mean(skipna=True).values)/data.std(skipna=True).values
    normalized_data = (data - np.mean(data))/np.std(data)
    return normalized_data


def load_norm_data(var_name_string):
    PATH_LIST = glob.glob(BASE+'*/preprocessed_data/'+var_name_string+'.nc') 
    data_app = normalize(xr.open_dataarray(PATH_LIST[0]).to_numpy()[:,5:-5,5:-5])
    for i_file in np.arange(1,len(PATH_LIST)):
        PATH = PATH_LIST[i_file]
        data = xr.open_dataarray(PATH).to_numpy()[:,5:-5,5:-5]
        data_norm = normalize(data)
        data_app = np.concatenate((data_app,data_norm),axis=0)
    return data_app



def split_data(data):
    data_split_halfs = np.concatenate((np.split(data,2,axis=1)[0],np.split(data,2,axis=1)[1]),0)
    data_split_quarters = np.concatenate((np.split(data_split_halfs,2,axis=2)[0],np.split(data_split_halfs,2,axis=2)[1]),0)
    return data#data_split_quarters



def load_split_norm_data(var_name_string):
    loaded_data = load_norm_data(var_name_string)
    splitted_data = split_data(loaded_data)
    return splitted_data
    
    
def load_split_norm_data_out(var_name_string):
    loaded_data = load_norm_data(var_name_string)
    splitted_data = split_data(loaded_data)
    cropped_output = splitted_data[:,5:-5,5:-5] # for a kernel of size 3 with 5 conv layers
    return cropped_output

# %%
# load preprocessed data, convert to numpy and stack channels

BASE = '/scratch/ab10313/submeso_ML_data/'
FULL_PATH_PP = glob.glob(BASE+'*/preprocessed_data/')

# X INPUT
ds_Bm = load_split_norm_data('Bm_MLD_lowres')
ds_Um = load_split_norm_data('Um_MLD_lowres')
ds_Vm = load_split_norm_data('Vm_MLD_lowres')
ds_Wm = load_split_norm_data('Wm_MLD_lowres')


X_input = np.stack([ds_Bm,ds_Um,ds_Vm,ds_Wm],axis=1)
print('X input shape:')
print( X_input.shape)
print('')


# Y OUTPUT
ds_UsBs = load_split_norm_data('UsBs_MLD_lowres')
ds_VsBs = load_split_norm_data('VsBs_MLD_lowres')
ds_WsBs = load_split_norm_data('WsBs_MLD_lowres')

Y_output = np.stack([ds_UsBs,ds_VsBs,ds_WsBs],axis=1)
print('Y output shape:')
print(Y_output.shape)
print('')


# GRAD B
ds_Bm_x = load_split_norm_data('Bm_x_MLD_lowres')
ds_Bm_y = load_split_norm_data('Bm_y_MLD_lowres')
ds_Bm_z = load_split_norm_data('Bm_z_MLD_lowres')

grad_b = np.stack([ds_Bm_x,ds_Bm_y,ds_Bm_z],axis=1)
print('grad b shape:')
print( grad_b.shape)
# Out:
# X input shape:
# (2150, 4, 30, 30)
#
# Y output shape:
# (2150, 3, 30, 30)
#
# grad b shape:
# (2150, 3, 30, 30)

# %% [markdown]
# ### randomly generate train, test and validation sets

# %%
# TRAIN AND TEST ONLY
# randomnly generate train, test and validation time indecies 
import random
time_ind = X_input.shape[0]
rand_ind = np.arange(time_ind)
rand_seed = 14
random.Random(rand_seed).shuffle(rand_ind)
train_percent = 0.9
test_percent = 0.1 
print(f"Dataset: train {np.round(train_percent*100)}%, test {np.round(test_percent*100)}%")
train_ind, test_ind =  rand_ind[:round(train_percent*time_ind)], rand_ind[round((train_percent)*time_ind):]                                                                        

# check no overlapping indecies
if np.intersect1d(train_ind, test_ind).any():
    print('overlapping indecies')
else:
    print ('no overlapping indecies')
# Out:
# Dataset: train 90.0%, test 10.0%
# no overlapping indecies

# %% [markdown]
# ### defined train, test and val dataloaders

# %%
# Define X,Y pairs (state, subgrid fluxes) for local network.local_torch_dataset = Data.TensorDataset(
BATCH_SIZE = 32  # Number of sample in each batch


###### training dataset #######
torch_dataset_train = Data.TensorDataset(
    torch.from_numpy(X_input[train_ind]).double(),
    torch.from_numpy(Y_output[train_ind]).double(),
    torch.from_numpy(grad_b[train_ind]).double(),
)

loader_train = Data.DataLoader(
    dataset=torch_dataset_train, batch_size=BATCH_SIZE, shuffle=True
)
print('TRAIN')
print('X input shape:')
print( X_input[train_ind].shape)
print('Y output shape:')
print( Y_output[train_ind].shape)
print('grad b shape:')
print( grad_b[train_ind].shape)
print('')

###### test dataset #######
torch_dataset_test = Data.TensorDataset(
    torch.from_numpy(X_input[test_ind]).double(),
    torch.from_numpy(Y_output[test_ind]).double(),
    torch.from_numpy(grad_b[test_ind]).double(),
    
)

loader_test = Data.DataLoader(
    dataset=torch_dataset_test, batch_size=BATCH_SIZE, shuffle=True
)

print('TEST')
print('X input shape:')
print( X_input[test_ind].shape)
print('Y output shape:')
print( Y_output[test_ind].shape)
print('grad b shape:')
print( grad_b[test_ind].shape)
print('')

###### validation dataset #######
#torch_dataset_val = Data.TensorDataset(
#    torch.from_numpy(X_input[val_ind]).double(),
#    torch.from_numpy(Y_output[val_ind]).double(),
#    torch.from_numpy(grad_b[val_ind]).double(),
#)

#BATCH_SIZE_TEST = len(torch_dataset_test)

#loader_val = Data.DataLoader(
#    dataset=torch_dataset_val, batch_size=BATCH_SIZE_TEST, shuffle=True
#)

#print('VAL')
#print('X input shape:')
#print( X_input[val_ind].shape)
#print('Y output shape:')
#print( Y_output[val_ind].shape)
#print('grad b shape:')
#print( grad_b[val_ind].shape)
#print('')
# Out:
# TRAIN
# X input shape:
# (1935, 4, 30, 30)
# Y output shape:
# (1935, 3, 30, 30)
# grad b shape:
# (1935, 3, 30, 30)
#
# TEST
# X input shape:
# (215, 4, 30, 30)
# Y output shape:
# (215, 3, 30, 30)
# grad b shape:
# (215, 3, 30, 30)

# %% [markdown]
# ## CNN - skew fluxes 9 output channels represeting 3X3 J matrix

# %%
# define network structure in pytorch
import torch.nn.functional as FF

class CNN_skew(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(4, 32, 3, padding='same', padding_mode='reflect')  # 4 inputs, 64 neurons for first hidden layer
        self.dropout1 = nn.Dropout(0.1)
        self.conv1_bn=nn.BatchNorm2d(32)
        self.conv2 = nn.Conv2d(32, 16, 3, padding='same', padding_mode='reflect')  # 64 inputs, 32 neurons for first hidden layer
        self.dropout2 = nn.Dropout(0.1)
        self.conv2_bn=nn.BatchNorm2d(16)
        self.conv3 = nn.Conv2d(16, 9, 3, padding='same', padding_mode='reflect')  # 32 inputs, 24 neurons for first hidden layer
        self.dropout3 = nn.Dropout(0.1)
        self.conv3_bn=nn.BatchNorm2d(9) # 9 outputs

    def forward(self, x):
        x = self.conv1(x)
        x = self.dropout1(x)
        x = F.relu(self.conv1_bn(x))
        x = self.conv2(x)
        x = self.dropout2(x)
        x = F.relu(self.conv2_bn(x))
        x = self.conv3(x)
        x = self.dropout3(x)
        x = self.conv3_bn(x)
        return x
 
    
# define network structure in pytorch
import torch.nn.functional as FF

#class CNN_direct(nn.Module):
#    def __init__(self):
#        super().__init__()
#        self.conv1 = nn.Conv2d(4, 64, 5,padding='same')  # 4 inputs, 128 neurons for first hidden layer
#        self.conv2 = nn.Conv2d(64, 32, 5,padding='same')  # 64 inputs, 32 neurons for first hidden layer
#        self.conv3 = nn.Conv2d(32, 3, 5,padding='same')  # 32 inputs, 24 neurons for first hidden layer

#    def forward(self, x):
#        x = FF.relu(self.conv1(x))
#        x = FF.relu(self.conv2(x))
#        x = self.conv3(x)
#        return x

# %% [markdown]
# ## Train and test model: direct fluxes

# %%
# train network 
def train_model_skew(net, criterion, trainloader, optimizer, len_train_dataset, text="train"):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    net.to(device)
    device_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else "cpu"
    print(f"Training starts on device {device_name}, number of samples {len(trainloader)}")
    
    net.train()
    train_loss = 0
    for step, (batch_x, batch_y, batch_g) in enumerate(trainloader):  # for each training step
        b_x = Variable(batch_x)  # Inputs
        b_y = Variable(batch_y)  # outputs
        b_grad = Variable(batch_g) # grad b
        prediction = net(b_x.to(device))
            
        prediction_reshape = torch.reshape(prediction, (prediction.shape[0],prediction.shape[2],prediction.shape[3],3, 3))
        grad_b_reshape = torch.reshape(b_grad, (b_grad.shape[0],b_grad.shape[2],b_grad.shape[3],3,1)).to(device)
            
        b_grad_view = grad_b_reshape.view(-1,3,1)
        prediction_view = prediction_reshape.view(-1,3,3)
            
        #print(prediction_reshape.shape)
        #print(grad_b_reshape.shape)
        
        #b_y_reshape = torch.reshape(b_y, (3, b_y.shape[0],b_y.shape[2],b_y.shape[3]))
        product = torch.bmm(prediction_view,b_grad_view)
        #print(product.shape)
        product_reshape = torch.reshape(product, (b_grad.shape[0],b_grad.shape[1],b_grad.shape[2],b_grad.shape[3])).to(device)
        #print(product_reshape.shape)
        #print(b_y.shape)
        
        
        # Calculating loss to find J which is the prediction
        loss = criterion(product_reshape, b_y.to(device)) 
        optimizer.zero_grad()  # clear gradients for next train
        loss.backward()  # backpropagation, compute gradients
        optimizer.step()  # apply gradients to update weights
        nb = b_y.shape[0]
        train_loss = train_loss + nb * loss.detach().cpu().numpy()  # Keep track of the loss
    train_loss /= len_train_dataset # dividing by the number of batches
    print(text + " loss:", train_loss)
    return train_loss


def test_model_skew(net, criterion, testloader, optimizer,len_test_dataset, text="validation"):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    net.to(device)
    device_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else "cpu"
    print(f"Training starts on device {device_name}, number of samples {len(testloader)}")
    
    net.eval()  # Evaluation mode (important when having dropout layers)
    test_loss = 0
    with torch.no_grad():
        for step, (batch_x, batch_y, batch_g) in enumerate(
            testloader
        ):  # for each training step
            b_x = Variable(batch_x)  # Inputs
            b_y = Variable(batch_y)  # outputs
            b_grad = Variable(batch_g) # grad b
            prediction = net(b_x.to(device))
            prediction_reshape = torch.reshape(prediction, (prediction.shape[0],prediction.shape[2],prediction.shape[3],3, 3))
            grad_b_reshape = torch.reshape(b_grad, (b_grad.shape[0],b_grad.shape[2],b_grad.shape[3],3,1)).to(device)
            
            b_grad_view = grad_b_reshape.view(-1,3,1)
            prediction_view = prediction_reshape.view(-1,3,3)
            
        #print(prediction_reshape.shape)
        #print(grad_b_reshape.shape)
        
        #b_y_reshape = torch.reshape(b_y, (3, b_y.shape[0],b_y.shape[2],b_y.shape[3]))
            product = torch.bmm(prediction_view,b_grad_view)
        #print(product.shape)
            product_reshape = torch.reshape(product, (b_grad.shape[0],b_grad.shape[1],b_grad.shape[2],b_grad.shape[3])).to(device)
        #print(product_reshape.shape)
        #print(b_y.shape)
        
        
        # Calculating loss to find J which is the prediction
            loss = criterion(product_reshape, b_y.to(device)) 
            nb = b_y.shape[0]
            test_loss = test_loss + nb * loss.detach().cpu().numpy()  # Keep track of the loss
        test_loss /= len_test_dataset  # dividing by the number of batches
        #         print(len(trainloader))
        print(text + " loss:", test_loss)
    return test_loss



def plot_model_skew(net, criterion, testloader, optimizer, len_test_dataset,text="validation"):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    net.to(device)
    device_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else "cpu"
    print(f"Training starts on device {device_name}, number of samples {len(testloader)}")
    
    net.eval()  # Evaluation mode (important when having dropout layers)
    test_loss = 0
    with torch.no_grad():
        for step, (batch_x, batch_y,batch_g) in enumerate(
            testloader
        ):  # for each training step
            b_x = Variable(batch_x)  # Inputs
            b_y = Variable(batch_y)  # outputs
            b_grad = Variable(batch_g) # grad b
            prediction = net(b_x.to(device))
            prediction_reshape = torch.reshape(prediction, (prediction.shape[0],prediction.shape[2],prediction.shape[3],3, 3))
            grad_b_reshape = torch.reshape(b_grad, (b_grad.shape[0],b_grad.shape[2],b_grad.shape[3],3,1)).to(device)
            
            b_grad_view = grad_b_reshape.view(-1,3,1)
            prediction_view = prediction_reshape.view(-1,3,3)
            
        #print(prediction_reshape.shape)
        #print(grad_b_reshape.shape)
        
        #b_y_reshape = torch.reshape(b_y, (3, b_y.shape[0],b_y.shape[2],b_y.shape[3]))
            product = torch.bmm(prediction_view,b_grad_view)
        #print(product.shape)
            product_reshape = torch.reshape(product, (b_grad.shape[0],b_grad.shape[1],b_grad.shape[2],b_grad.shape[3])).to(device)
        #print(product_reshape.shape)
        #print(b_y.shape)
        
        
        # Calculating loss to find J which is the prediction
            loss = criterion(product_reshape, b_y.to(device)) 
            
            
            nb = b_y.shape[0]
            test_loss = test_loss + nb * loss.detach().cpu().numpy()  # Keep track of the loss
        test_loss /= len_test_dataset  # dividing by the number of batches
        #         print(len(trainloader))
        print(text + " loss:", test_loss)
    return b_x, b_y, product_reshape, prediction_view, b_grad_view


criterion = torch.nn.MSELoss()  # MSE loss function

# %% [markdown]
# ## train CNN!

# %%
torch.manual_seed(14)  # For reproducibility
cnn_submeso = CNN_skew().double()

n_epochs = 100  # Number of epocs could be increased
optimizer = optim.Adam(cnn_submeso.parameters(), lr=0.015)
test_loss = list()
train_loss = list()
for epoch in range(1, n_epochs + 1):
    print("epoch:", epoch)
    train_loss.append(train_model_skew(cnn_submeso, criterion, loader_train, optimizer,len(torch_dataset_train)))
    test_loss.append(test_model_skew(cnn_submeso, criterion, loader_test, optimizer,len(torch_dataset_test)))
# Out:
# epoch: 1
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 2.4407438219597863
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 1.1833606147995572
# epoch: 2
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 1.0658501124158544
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9955621082675525
# epoch: 3
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9795462047991109
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.974507417261137
# epoch: 4
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9666193286771739
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.971936511088592
# epoch: 5
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9640709901959209
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9717627168944214
# epoch: 6
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9634949052014166
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9699112769697302
# epoch: 7
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9624732347338446
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9704645084045784
# epoch: 8
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9622538417868632
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9690746107398405
# epoch: 9
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9619699769009027
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9688500452107366
# epoch: 10
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9615216131717932
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9687163722793767
# epoch: 11
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9610021521871177
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9684806162850107
# epoch: 12
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9604251276164504
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9682497629784854
# epoch: 13
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.960858363779006
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9681006269518184
# epoch: 14
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9606285561402746
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9684394166641068
# epoch: 15
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9601440061079615
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.967624390016885
# epoch: 16
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9603381560807807
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.967761594303216
# epoch: 17
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9591215383004124
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9669924698464862
# epoch: 18
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9593275756604345
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9722475121110606
# epoch: 19
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9590752867729386
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9681043864676316
# epoch: 20
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9587257087273878
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9692404572769945
# epoch: 21
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9583958187069072
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9662265707908892
# epoch: 22
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9583565627991975
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9669174648122597
# epoch: 23
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9582998861305098
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9662861542171055
# epoch: 24
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9578063821565267
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9675881682198789
# epoch: 25
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9581238061258217
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.968680486909364
# epoch: 26
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9578087754054803
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9658575151302384
# epoch: 27
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.957590363186399
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9656374347102066
# epoch: 28
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9572752680790121
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9658321396349233
# epoch: 29
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9576789205338521
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9667903161917105
# epoch: 30
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9563246139573736
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9659413579474172
# epoch: 31
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9552638002128546
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9651580952178757
# epoch: 32
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9559471638927506
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9660590517830462
# epoch: 33
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.956386951571186
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9643894019139888
# epoch: 34
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9556940037319703
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9647386620110742
# epoch: 35
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.954461445466516
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.964142568599044
# epoch: 36
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9546297003247891
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9646898083194556
# epoch: 37
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9561956879217205
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9648656176936444
# epoch: 38
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9564819866834069
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9641657544214095
# epoch: 39
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9553633470305408
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9637838007502537
# epoch: 40
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9531956858847546
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9644044947692368
# epoch: 41
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9546154365398385
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9626468428213555
# epoch: 42
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.954029700028847
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9628409926474626
# epoch: 43
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.953930673801652
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9655299482313531
# epoch: 44
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9537409472098103
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9636662323141102
# epoch: 45
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9534684687095635
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9656319855973375
# epoch: 46
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9539633487471955
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9615938908280757
# epoch: 47
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9525772551956827
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9646482375786242
# epoch: 48
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9529503021918728
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9632895842146028
# epoch: 49
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9526237373653104
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9638191199210921
# epoch: 50
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9520053355505992
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9606164917721051
# epoch: 51
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9525329616856231
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9615247727172654
# epoch: 52
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9511154958423075
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9614199195034914
# epoch: 53
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.951365664398602
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.961368255495431
# epoch: 54
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9508312251134756
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9626735104384155
# epoch: 55
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9503845314893979
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9603947604200864
# epoch: 56
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9505357112116726
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9610829313978652
# epoch: 57
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9515289384182324
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9590648218378486
# epoch: 58
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9493127012002814
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9600023643149092
# epoch: 59
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9502709476171821
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9587071384647824
# epoch: 60
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9507097238509731
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.959445181545884
# epoch: 61
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9496225295230835
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9613733649256748
# epoch: 62
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9493626471555558
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9639659323245697
# epoch: 63
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9501796357603836
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9602444561227254
# epoch: 64
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9499629985354897
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9624097482173228
# epoch: 65
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9488059446270152
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9610991064800384
# epoch: 66
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9488640979712601
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9605543794123936
# epoch: 67
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9501396854851376
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9623677608120303
# epoch: 68
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9476602068481704
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9708950608669822
# epoch: 69
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9485976010747765
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9660281926984069
# epoch: 70
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.951390571418507
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9594715563840966
# epoch: 71
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9492128197381969
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9638473129648837
# epoch: 72
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9488162830429122
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9579862831916678
# epoch: 73
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9493074830346149
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9595731898540735
# epoch: 74
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9470443234326393
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9590825608464716
# epoch: 75
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9478714929620714
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9609187954531547
# epoch: 76
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.946463004246939
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9606695169223286
# epoch: 77
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.948113568596295
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9570090209443194
# epoch: 78
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.947879901696701
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9603892055366564
# epoch: 79
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9473766710350148
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9580969073180854
# epoch: 80
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9471854199614917
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9572396700447429
# epoch: 81
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9476261319467202
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9560751515223316
# epoch: 82
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9478664434381604
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9604728854569052
# epoch: 83
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9472150914997745
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9672271194457404
# epoch: 84
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9488009083985716
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9614664234539525
# epoch: 85
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9480350835213707
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9586060907631233
# epoch: 86
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9466345126963795
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.957282975388431
# epoch: 87
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9467237666591738
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9593129107882993
# epoch: 88
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9459054545653957
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9572095879722142
# epoch: 89
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9457022609862155
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.962863197820123
# epoch: 90
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.946805589424865
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9557842061629453
# epoch: 91
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9473692223442403
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9587368134135941
# epoch: 92
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9455828747727409
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9702362576519575
# epoch: 93
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9471890961643343
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9587824312609443
# epoch: 94
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9461162481391707
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9582218544841677
# epoch: 95
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9458064912330406
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9581749290374024
# epoch: 96
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9459443098210234
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9556140657271607
# epoch: 97
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9462332633890836
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9552726906445179
# epoch: 98
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.94534105128159
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9568141476125535
# epoch: 99
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9464785135756063
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9561836729345452
# epoch: 100
# Training starts on device Tesla V100-SXM2-16GB, number of samples 61
# train loss: 0.9458191666397066
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.95855201831989

# %%
import matplotlib.pyplot as plt

plt.plot(train_loss[1:], "b", label="training loss")
plt.plot(test_loss[1:], "r", label="test loss")

plt.legend();

# %%
b_x, b_y, product_reshape, prediction_view, b_grad_view = plot_model_skew(cnn_submeso, criterion, loader_test, optimizer,len(torch_dataset_test))
# Out:
# Training starts on device Tesla V100-SXM2-16GB, number of samples 7
# validation loss: 0.9585520183198898

# %%
from scipy import stats
corr_pred_ub = stats.pearsonr(product_reshape.detach().cpu().numpy()[:,0,:,:].flatten(), b_y[:,0,:,:].flatten())
corr_pred_vb = stats.pearsonr(product_reshape.detach().cpu().numpy()[:,1,:,:].flatten(), b_y[:,1,:,:].flatten())
corr_pred_wb = stats.pearsonr(product_reshape.detach().cpu().numpy()[:,2,:,:].flatten(), b_y[:,2,:,:].flatten())

print("correlation between prediction and target,  u'b':",corr_pred_ub )
print("correlation between prediction and target,  v'b':",corr_pred_vb )
print("correlation between prediction and target,  w'b':",corr_pred_wb )
# Out:
# correlation between prediction and target,  u'b': (0.12124362093538102, 1.2562434920030912e-68)
# correlation between prediction and target,  v'b': (0.15820640434246985, 4.1475159582566607e-116)
# correlation between prediction and target,  w'b': (0.32647152932045376, 0.0)

# %%
# visualize
it =18

fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(8, 4))
fig.tight_layout() # Or equivalently,  "plt.tight_layout()"

plt.subplot(231)
plt.pcolor(product_reshape.detach().cpu().numpy()[it,0,:,:],cmap='viridis',vmin=-1,vmax =1)
plt.title('ub prediction')
plt.colorbar()

plt.subplot(234)
plt.pcolor(b_y[it,0,:,:],cmap='viridis',vmin=-1,vmax =1)
plt.title('ub target')
plt.colorbar()

plt.subplot(232)
plt.pcolor(product_reshape.detach().cpu().numpy()[it,1,:,:],cmap='viridis',vmin=-1,vmax =1)
plt.title('vb prediction')
plt.colorbar()

plt.subplot(235)
plt.pcolor(b_y[it,1,:,:],cmap='viridis',vmin=-1,vmax =1)
plt.title('vb target')
plt.colorbar()

plt.subplot(233)
plt.pcolor(product_reshape.detach().cpu().numpy()[it,2,:,:],cmap='viridis',vmin=-1,vmax =1)
plt.title('wb prediction')
plt.colorbar()

plt.subplot(236)
plt.pcolor(b_y[it,2,:,:],cmap='viridis',vmin=-1,vmax =1)
plt.title('wb target')
plt.colorbar()

# %%
_=plt.hist(b_y.detach().cpu().numpy().flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="target")
_=plt.hist(product_reshape.detach().cpu().numpy().flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="prediction")

plt.xlim([-3,3])
plt.legend()

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(12, 4))
fig.tight_layout() # Or equivalently,  "plt.tight_layout()"

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

plt.subplot(131)
_=plt.hist(b_y.detach().cpu().numpy()[:,0,:,:].flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="target")
_=plt.hist(product_reshape.detach().cpu().numpy()[:,0,:,:].flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="prediction")
plt.xlim([-3,3])
plt.legend()
plt.title('ub')


plt.subplot(132)
_=plt.hist(b_y.detach().cpu().numpy()[:,1,:,:].flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="target")
_=plt.hist(product_reshape.detach().cpu().numpy()[:,1,:,:].flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="prediction")
plt.xlim([-3,3])
plt.legend()
plt.title('vb')

plt.subplot(133)
_=plt.hist(b_y.detach().cpu().numpy()[:,2,:,:].flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="target")
_=plt.hist(product_reshape.detach().cpu().numpy()[:,2,:,:].flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="prediction")
plt.xlim([-3,3])
plt.legend()
plt.title('wb')
# Out:
# Text(0.5, 1.0, 'wb')

# %%
import xrft
