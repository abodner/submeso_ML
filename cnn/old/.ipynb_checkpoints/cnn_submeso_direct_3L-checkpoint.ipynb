# %%
import torch
import torch.nn.functional as F
import torch.utils.data as Data
import torchvision
from torch import nn, optim
from torch.autograd import Variable
import numpy as np
import os
import glob
import xarray as xr
from sklearn import preprocessing
import netCDF4 as nc
import matplotlib.pyplot as plt



np.random.seed(14)  # For reproducibility
torch.manual_seed(14)  # For reproducibility

# %% [markdown]
# # Dataloader

# %% [markdown]
# ### Create input and output channels

# %%
# function that splits datasets along the spacial axes and concats them back into single array under time

def normalize(data):
    #normalized_data =  (data - data.mean(skipna=True).values)/data.std(skipna=True).values
    normalized_data = (data - np.mean(data))/np.std(data)
    return normalized_data


def load_norm_data(var_name_string):
    PATH_LIST = glob.glob(BASE+'*/preprocessed_data/'+var_name_string+'.nc') 
    data_app = normalize(xr.open_dataarray(PATH_LIST[0]).to_numpy()[:,5:-5,5:-5])
    for i_file in np.arange(1,len(PATH_LIST)):
        PATH = PATH_LIST[i_file]
        data = xr.open_dataarray(PATH).to_numpy()[:,5:-5,5:-5]
        data_norm = normalize(data)
        data_app = np.concatenate((data_app,data_norm),axis=0)
    return data_app

# depth of CNN * (kernel_num-1)/2
#def load_norm_data_out(var_name_string): #with cropping for output
#    PATH_LIST = glob.glob(BASE+'*/preprocessed_data/'+var_name_string+'.nc') 
#    data_app = normalize(xr.open_dataarray(PATH_LIST[0]).to_numpy()[:,14:-14,14:-14])
#    for i_file in np.arange(1,len(PATH_LIST)):
#        PATH = PATH_LIST[i_file]
#        data = xr.open_dataarray(PATH).to_numpy()[:,14:-14,14:-14]
#        data_norm = normalize(data)
#        data_app = np.concatenate((data_app,data_norm),axis=0)
#    return data_app


def split_data(data):
    data_split_halfs = np.concatenate((np.split(data,2,axis=1)[0],np.split(data,2,axis=1)[1]),0)
    data_split_quarters = np.concatenate((np.split(data_split_halfs,2,axis=2)[0],np.split(data_split_halfs,2,axis=2)[1]),0)
    return data#data_split_quarters



def load_split_norm_data(var_name_string):
    loaded_data = load_norm_data(var_name_string)
    splitted_data = split_data(loaded_data)
    return splitted_data
    
    
def load_split_norm_data_out(var_name_string):
    loaded_data = load_norm_data(var_name_string)
    splitted_data = split_data(loaded_data)
    cropped_output = splitted_data[:,5:-5,5:-5] # for a kernel of size 3 with 5 conv layers
    return cropped_output

# %%
# load preprocessed data, convert to numpy and stack channels

BASE = '/scratch/ab10313/submeso_ML_data/'
FULL_PATH_PP = glob.glob(BASE+'*/preprocessed_data/')

# X INPUT
ds_Bm = load_split_norm_data('Bm_MLD_lowres')
ds_Um = load_split_norm_data('Um_MLD_lowres')
ds_Vm = load_split_norm_data('Vm_MLD_lowres')
ds_Wm = load_split_norm_data('Wm_MLD_lowres')


X_input = np.stack([ds_Bm,ds_Um,ds_Vm,ds_Wm],axis=1)
print('X input shape:')
print( X_input.shape)
print('')


# Y OUTPUT
ds_UsBs = load_split_norm_data('UsBs_MLD_lowres')
ds_VsBs = load_split_norm_data('VsBs_MLD_lowres')
ds_WsBs = load_split_norm_data('WsBs_MLD_lowres')

Y_output = np.stack([ds_UsBs,ds_VsBs,ds_WsBs],axis=1)
print('Y output shape:')
print(Y_output.shape)
print('')


# GRAD B
ds_Bm_x = load_split_norm_data('Bm_x_MLD_lowres')
ds_Bm_y = load_split_norm_data('Bm_y_MLD_lowres')
ds_Bm_z = load_split_norm_data('Bm_z_MLD_lowres')

grad_b = np.stack([ds_Bm_x,ds_Bm_y,ds_Bm_z],axis=1)
print('grad b shape:')
print( grad_b.shape)
# Out:
# X input shape:
# (2150, 4, 30, 30)
#
# Y output shape:
# (2150, 3, 30, 30)
#
# grad b shape:
# (2150, 3, 30, 30)

# %% [markdown]
# ### randomly generate train, test and validation sets

# %%
# TRAIN AND TEST ONLY
# randomnly generate train, test and validation time indecies 
import random
time_ind = X_input.shape[0]
rand_ind = np.arange(time_ind)
rand_seed = 14
random.Random(rand_seed).shuffle(rand_ind)
train_percent = 0.9
test_percent = 0.1 
print(f"Dataset: train {np.round(train_percent*100)}%, test {np.round(test_percent*100)}%")
train_ind, test_ind =  rand_ind[:round(train_percent*time_ind)], rand_ind[round((train_percent)*time_ind):]                                                                        

# check no overlapping indecies
if np.intersect1d(train_ind, test_ind).any():
    print('overlapping indecies')
else:
    print ('no overlapping indecies')
# Out:
# Dataset: train 90.0%, test 10.0%
# no overlapping indecies

# %% [markdown]
# ### defined train, test and val dataloaders

# %%
# Define X,Y pairs (state, subgrid fluxes) for local network.local_torch_dataset = Data.TensorDataset(
BATCH_SIZE = 64  # Number of sample in each batch


###### training dataset #######
torch_dataset_train = Data.TensorDataset(
    torch.from_numpy(X_input[train_ind]).double(),
    torch.from_numpy(Y_output[train_ind]).double(),
)

loader_train = Data.DataLoader(
    dataset=torch_dataset_train, batch_size=BATCH_SIZE, shuffle=True
)
print('TRAIN')
print('X input shape:')
print( X_input[train_ind].shape)
print('Y output shape:')
print( Y_output[train_ind].shape)
print('')

###### test dataset #######
torch_dataset_test = Data.TensorDataset(
    torch.from_numpy(X_input[test_ind]).double(),
    torch.from_numpy(Y_output[test_ind]).double(),    
)

BATCH_SIZE_TEST = len(torch_dataset_test)

loader_test = Data.DataLoader(
    dataset=torch_dataset_test, batch_size=BATCH_SIZE_TEST, shuffle=True
)

print('TEST')
print('X input shape:')
print( X_input[test_ind].shape)
print('Y output shape:')
print( Y_output[test_ind].shape)
print('')

###### validation dataset #######
#torch_dataset_val = Data.TensorDataset(
#    torch.from_numpy(X_input[val_ind]).double(),
#    torch.from_numpy(Y_output[val_ind]).double(),
#)


#loader_val = Data.DataLoader(
#    dataset=torch_dataset_val, batch_size=BATCH_SIZE, shuffle=True
#)

#print('VAL')
#print('X input shape:')
#print( X_input[val_ind].shape)
#print('Y output shape:')
#print( Y_output[val_ind].shape)
#print('')
# Out:
# TRAIN
# X input shape:
# (1935, 4, 30, 30)
# Y output shape:
# (1935, 3, 30, 30)
#
# TEST
# X input shape:
# (215, 4, 30, 30)
# Y output shape:
# (215, 3, 30, 30)

# %% [markdown]
# ## CNN - direct fluxes 3 output channels

# %%
# define network structure in pytorch
import torch.nn.functional as FF

class CNN_direct(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(4, 32, 3, padding='same', padding_mode='reflect')  # 4 inputs, 64 neurons for first hidden layer
        self.dropout1 = nn.Dropout(0.2)
        self.conv1_bn=nn.BatchNorm2d(32)
        self.conv2 = nn.Conv2d(32, 16, 3, padding='same', padding_mode='reflect')  # 64 inputs, 32 neurons for first hidden layer
        self.dropout2 = nn.Dropout(0.2)
        self.conv2_bn=nn.BatchNorm2d(16)
        self.conv3 = nn.Conv2d(16, 3, 3, padding='same', padding_mode='reflect')  # 32 inputs, 24 neurons for first hidden layer
        self.dropout3 = nn.Dropout(0.2)
        self.conv3_bn=nn.BatchNorm2d(3) 

    def forward(self, x):
        x = self.conv1(x)
        x = self.dropout1(x)
        x = F.relu(self.conv1_bn(x))
        x = self.conv2(x)
        x = self.dropout2(x)
        x = F.relu(self.conv2_bn(x))
        x = self.conv3(x)
        x = self.dropout3(x)
        x = self.conv3_bn(x)
        return x
 
    
# define network structure in pytorch
import torch.nn.functional as FF

#class CNN_direct(nn.Module):
#    def __init__(self):
#        super().__init__()
#        self.conv1 = nn.Conv2d(4, 64, 5,padding='same')  # 4 inputs, 128 neurons for first hidden layer
#        self.conv2 = nn.Conv2d(64, 32, 5,padding='same')  # 64 inputs, 32 neurons for first hidden layer
#        self.conv3 = nn.Conv2d(32, 3, 5,padding='same')  # 32 inputs, 24 neurons for first hidden layer

#    def forward(self, x):
#        x = FF.relu(self.conv1(x))
#        x = FF.relu(self.conv2(x))
#        x = self.conv3(x)
#        return x

# %% [markdown]
# ## Train and test model: direct fluxes

# %%
# train network 
def train_model_direct(net, criterion, trainloader, optimizer, len_train_dataset, text="train"):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    net.to(device)
    device_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else "cpu"
    print(f"Training starts on device {device_name}, number of samples {len(trainloader)}")
    
    net.train()
    train_loss = 0
    for step, (batch_x, batch_y) in enumerate(trainloader):  # for each training step
        b_x = Variable(batch_x)  # Inputs
        b_y = Variable(batch_y)  # outputs
        prediction = net(b_x.to(device))
        loss = criterion(prediction, b_y.to(device))  # Calculating loss
        optimizer.zero_grad()  # clear gradients for next train
        loss.backward()  # backpropagation, compute gradients
        optimizer.step()  # apply gradients to update weights
        nb = b_y.shape[0]
        train_loss = train_loss + nb * loss.detach().cpu().numpy()  # Keep track of the loss
    train_loss /= len_train_dataset  # dividing by the number of batches
    print(text + " loss:", train_loss)
    return train_loss


def test_model_direct(net, criterion, testloader, optimizer,len_test_dataset, text="test"):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    net.to(device)
    device_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else "cpu"
    print(f"Training starts on device {device_name}, number of samples {len(testloader)}")
    
    net.eval()  # Evaluation mode (important when having dropout layers)
    test_loss = 0
    with torch.no_grad():
        for step, (batch_x, batch_y) in enumerate(
            testloader
        ):  # for each training step
            b_x = Variable(batch_x)  # Inputs
            b_y = Variable(batch_y)  # outputs
            prediction = net(b_x.to(device))
            loss = criterion(prediction, b_y.to(device))  # Calculating loss
            nb = b_y.shape[0]
            test_loss = test_loss + nb * loss.detach().cpu().numpy()  # Keep track of the loss
        test_loss /= len_test_dataset  # dividing by the number of batches
        #         print(len(trainloader))
        print(text + " loss:", test_loss)
    return test_loss



def plot_model_direct(net, criterion, testloader, optimizer, len_test_dataset, text="test"):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    net.to(device)
    device_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else "cpu"
    print(f"Training starts on device {device_name}, number of samples {len(testloader)}")
    
    net.eval()  # Evaluation mode (important when having dropout layers)
    test_loss = 0
    with torch.no_grad():
        for step, (batch_x, batch_y) in enumerate(
            testloader
        ):  # for each training step
            b_x = Variable(batch_x)  # Inputs
            b_y = Variable(batch_y)  # outputs
            prediction = net(b_x.to(device))
            loss = criterion(prediction, b_y.to(device))  # Calculating loss
            nb = b_y.shape[0]
            test_loss = test_loss + nb * loss.detach().cpu().numpy()  # Keep track of the loss
        test_loss /= len_test_dataset  # dividing by the number of batches
        #         print(len(trainloader))
        print(text + " loss:", test_loss)
    return b_x, b_y, prediction


criterion = torch.nn.MSELoss()  # MSE loss function

# %% [markdown]
# ## train CNN!

# %%
torch.manual_seed(14)  # For reproducibility
cnn_submeso = CNN_direct().double()

n_epochs = 100  # Number of epocs could be increased
optimizer = optim.Adam(cnn_submeso.parameters(), lr=0.01)
test_loss = list()
train_loss = list()
for epoch in range(1, n_epochs + 1):
    print("epoch:", epoch)
    train_loss.append(train_model_direct(cnn_submeso, criterion, loader_train, optimizer,len(torch_dataset_train)))
    test_loss.append(test_model_direct(cnn_submeso, criterion, loader_test, optimizer,len(torch_dataset_test)))
# Out:
# epoch: 1
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 1.466950328226932
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 1.0425411241156144
# epoch: 2
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 1.0887905742399249
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.9439276227243565
# epoch: 3
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.9600914870987425
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.9095088133005858
# epoch: 4
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.9220897904505013
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.911575303857096
# epoch: 5
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.9144204211672348
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8965455165904513
# epoch: 6
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.9061632280246162
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8948629060088926
# epoch: 7
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.900838203759381
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8809709652268538
# epoch: 8
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8947885701468129
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8787031027635508
# epoch: 9
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8877835291020812
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8614374669670264
# epoch: 10
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8851773556121526
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8564765056674704
# epoch: 11
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8805871453096051
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8472092366001186
# epoch: 12
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8796684128174842
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8550233395104436
# epoch: 13
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8739945279244548
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.847095394950739
# epoch: 14
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.870479364412585
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8334814502296363
# epoch: 15
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8698177742170727
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8418591885958342
# epoch: 16
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8644301297516856
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8446187707076344
# epoch: 17
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8624240938762231
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8321212893624378
# epoch: 18
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8589135206546004
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.83577256781007
# epoch: 19
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8543434512814345
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8253200206034756
# epoch: 20
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8555685527888197
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8218994983428207
# epoch: 21
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8535813290312396
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8498823484968314
# epoch: 22
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8569171525687573
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8189298812101081
# epoch: 23
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8535178984795151
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8294135988737515
# epoch: 24
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8500087343516941
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8224952328610105
# epoch: 25
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8506413537510346
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8172619370781784
# epoch: 26
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8489038871851998
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8133724797680525
# epoch: 27
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8472280175795135
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8068018785087729
# epoch: 28
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8451362338945589
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8172667774148306
# epoch: 29
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8432991575889117
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8160202523689528
# epoch: 30
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8446059737694621
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8225069997983508
# epoch: 31
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8437616383624709
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8083222404365848
# epoch: 32
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8417698831587923
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8107221008256235
# epoch: 33
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8437636079020052
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8095356831136356
# epoch: 34
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8419897728011516
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7942701292711372
# epoch: 35
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8400014239016851
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8077507630880502
# epoch: 36
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8386679387409085
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8074804079835326
# epoch: 37
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8395482041002038
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.801615080324031
# epoch: 38
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8373035579800521
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8240575483956247
# epoch: 39
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8389598509881492
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8172183864692685
# epoch: 40
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8365525605898058
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7992327207331806
# epoch: 41
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8322478467415142
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8117165428769914
# epoch: 42
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.834752086522648
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8079370993888142
# epoch: 43
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8359685886725899
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7985876606271873
# epoch: 44
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8328769241831983
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7964771906852394
# epoch: 45
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8346283132211856
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.811770296307879
# epoch: 46
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8316658180752541
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7974136721184928
# epoch: 47
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8294291303180297
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8051298497408913
# epoch: 48
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8300136244131522
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7966037791845271
# epoch: 49
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8301836474270456
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7931271416118352
# epoch: 50
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8262851423872183
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7942712135440264
# epoch: 51
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8276713523637887
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7910317286994699
# epoch: 52
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8290454046018264
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7965784707887161
# epoch: 53
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8287929902136042
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.792914738820573
# epoch: 54
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8295462392106052
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7913842455648724
# epoch: 55
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8263772091254865
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8020371469805375
# epoch: 56
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8280123669580767
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7822939295593266
# epoch: 57
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.826137990499953
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7845932137993786
# epoch: 58
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8265190921697213
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7943758464365697
# epoch: 59
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8239297091441333
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7925935822633237
# epoch: 60
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8275555035008638
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.784198818380866
# epoch: 61
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8239498449065766
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7809819498042325
# epoch: 62
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8250977710913623
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7847694209388886
# epoch: 63
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.825974001445857
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7938819165417799
# epoch: 64
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8232750712877103
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8082864526377396
# epoch: 65
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8266011464186526
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7802991252356924
# epoch: 66
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8256938852736591
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.810903636500274
# epoch: 67
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8250771101126447
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7905105348661529
# epoch: 68
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8223443367513731
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8021682219752396
# epoch: 69
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8220514878192424
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7890853634852566
# epoch: 70
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8260204003552778
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7921605993833011
# epoch: 71
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8221247145026693
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7861571930937751
# epoch: 72
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.821948109600965
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7770289160127779
# epoch: 73
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8187101266223356
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7807465754839514
# epoch: 74
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.818280196135987
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7879924961086693
# epoch: 75
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8241919844917045
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7935024174989465
# epoch: 76
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8194494996452824
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7826124565913147
# epoch: 77
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8233432225409526
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7898373987120273
# epoch: 78
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8205852562069671
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7761154459168315
# epoch: 79
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.819972905643999
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7895238321329006
# epoch: 80
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8186300100962531
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7860113796018627
# epoch: 81
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8191643711243577
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7787970559705222
# epoch: 82
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8194943131697776
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7754392666171152
# epoch: 83
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8178795652748463
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7778107785561135
# epoch: 84
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8196637080323271
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7885525040230337
# epoch: 85
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8197672285395041
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.8088271014934116
# epoch: 86
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8208268411742451
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7913891262158784
# epoch: 87
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8206056084517531
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7847647491770695
# epoch: 88
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8185326340035342
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7775105211074316
# epoch: 89
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.817319852317886
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7721244088960291
# epoch: 90
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8191842495788739
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7912069193051452
# epoch: 91
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8157379244812276
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7815727027773273
# epoch: 92
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.813501694913405
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7729890013424713
# epoch: 93
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8164444137134412
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7927898597872121
# epoch: 94
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8143254065663965
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7761428586948771
# epoch: 95
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8176415316128066
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7850451816859003
# epoch: 96
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8148894240788267
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7904188556241846
# epoch: 97
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8171614608109883
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7994946459292839
# epoch: 98
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8169039442953816
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7805854410139121
# epoch: 99
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8170865699171608
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7898538964769607
# epoch: 100
# Training starts on device Tesla V100-SXM2-16GB, number of samples 31
# train loss: 0.8165224529574056
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7766502708234997

# %%
import matplotlib.pyplot as plt

plt.plot(train_loss[1:], "b", label="training loss")
plt.plot(test_loss[1:], "r", label="test loss")

plt.legend();

# %%
b_x, b_y, prediction = plot_model_direct(cnn_submeso, criterion, loader_test, optimizer,len(torch_dataset_test))
# Out:
# Training starts on device Tesla V100-SXM2-16GB, number of samples 1
# test loss: 0.7785457179469301

# %%
from scipy import stats
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")


corr_pred_ub = stats.pearsonr(cnn_submeso(b_x.to(device)).detach().cpu().numpy()[:,0,:,:].flatten(), b_y[:,0,:,:].flatten())
corr_pred_vb = stats.pearsonr(cnn_submeso(b_x.to(device)).detach().cpu().numpy()[:,1,:,:].flatten(), b_y[:,1,:,:].flatten())
corr_pred_wb = stats.pearsonr(cnn_submeso(b_x.to(device)).detach().cpu().numpy()[:,2,:,:].flatten(), b_y[:,2,:,:].flatten())

print("correlation between prediction and target,  u'b':",corr_pred_ub )
print("correlation between prediction and target,  v'b':",corr_pred_vb )
print("correlation between prediction and target,  w'b':",corr_pred_wb )
# Out:
# correlation between prediction and target,  u'b': (0.5468554230512231, 0.0)
# correlation between prediction and target,  v'b': (0.5654670403918904, 0.0)
# correlation between prediction and target,  w'b': (0.4453990889195751, 0.0)

# %%
# visualize
it =0

fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(8, 4))
fig.tight_layout() # Or equivalently,  "plt.tight_layout()"

plt.subplot(231)
plt.pcolor(cnn_submeso(b_x.to(device)).detach().cpu().numpy()[it,0,:,:],cmap='viridis',vmin=-1,vmax =1)
plt.title('ub prediction')
plt.colorbar()

plt.subplot(234)
plt.pcolor(b_y[it,0,:,:],cmap='viridis',vmin=-1,vmax =1)
plt.title('ub target')
plt.colorbar()

plt.subplot(232)
plt.pcolor(cnn_submeso(b_x.to(device)).detach().cpu().numpy()[it,1,:,:],cmap='viridis',vmin=-1,vmax =1)
plt.title('vb prediction')
plt.colorbar()

plt.subplot(235)
plt.pcolor(b_y[it,1,:,:],cmap='viridis',vmin=-1,vmax =1)
plt.title('vb target')
plt.colorbar()

plt.subplot(233)
plt.pcolor(cnn_submeso(b_x.to(device)).detach().cpu().numpy()[it,2,:,:],cmap='viridis',vmin=-1,vmax =1)
plt.title('wb prediction')
plt.colorbar()

plt.subplot(236)
plt.pcolor(b_y[it,2,:,:],cmap='viridis',vmin=-1,vmax =1)
plt.title('wb target')
plt.colorbar()

# %%
_=plt.hist(b_y.detach().cpu().numpy().flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="target")
_=plt.hist(cnn_submeso(b_x.to(device)).detach().cpu().numpy().flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="prediction")

plt.xlim([-3,3])
plt.legend()
