# %%
import torch
import torch.nn.functional as F
import torch.utils.data as Data
import torchvision
from torch import nn, optim
from torch.autograd import Variable
import numpy as np
import os
import glob
import xarray as xr
from sklearn import preprocessing
import netCDF4 as nc
import matplotlib.pyplot as plt



np.random.seed(14)  # For reproducibility
torch.manual_seed(14)  # For reproducibility

# %% [markdown]
# # Dataloader

# %% [markdown]
# ### Create input and output channels

# %%
# function that splits datasets along the spacial axes and concats them back into single array under time

def normalize(data):
    #normalized_data =  (data - data.mean(skipna=True).values)/data.std(skipna=True).values
    normalized_data = (data - np.mean(data))/np.std(data)
    return normalized_data


def load_norm_data(var_name_string):
    PATH_LIST = glob.glob(BASE+'*/preprocessed_data/'+var_name_string+'.nc') 
    data_app = normalize(xr.open_dataarray(PATH_LIST[0]).to_numpy()[:,5:-5,5:-5])
    for i_file in np.arange(1,len(PATH_LIST)):
        PATH = PATH_LIST[i_file]
        data = xr.open_dataarray(PATH).to_numpy()[:,5:-5,5:-5]
        data_norm = normalize(data)
        data_app = np.concatenate((data_app,data_norm),axis=0)
    return data_app



def split_data(data):
    data_split_halfs = np.concatenate((np.split(data,2,axis=1)[0],np.split(data,2,axis=1)[1]),0)
    data_split_quarters = np.concatenate((np.split(data_split_halfs,2,axis=2)[0],np.split(data_split_halfs,2,axis=2)[1]),0)
    return data_split_quarters



def load_split_norm_data(var_name_string):
    loaded_data = load_norm_data(var_name_string)
    splitted_data = split_data(loaded_data)
    return splitted_data
    
    
def load_split_norm_data_out(var_name_string):
    loaded_data = load_norm_data(var_name_string)
    splitted_data = split_data(loaded_data)
    cropped_output = splitted_data[:,5:-5,5:-5] # for a kernel of size 3 with 5 conv layers
    return cropped_output

# %%
# load preprocessed data, convert to numpy and stack channels

BASE = '/scratch/ab10313/submeso_ML_data/'
FULL_PATH_PP = glob.glob(BASE+'*/preprocessed_data/')

# X INPUT
ds_Bm = load_split_norm_data('Bm_MLD_lowres')
ds_Um = load_split_norm_data('Um_MLD_lowres')
ds_Vm = load_split_norm_data('Vm_MLD_lowres')
ds_Wm = load_split_norm_data('Wm_MLD_lowres')


X_input = np.stack([ds_Bm,ds_Um,ds_Vm,ds_Wm],axis=1)
print('X input shape:')
print( X_input.shape)
print('')


# Y OUTPUT
ds_UsBs = load_split_norm_data('UsBs_MLD_lowres')
ds_VsBs = load_split_norm_data('VsBs_MLD_lowres')
ds_WsBs = load_split_norm_data('WsBs_MLD_lowres')

Y_output = np.stack([ds_UsBs,ds_VsBs,ds_WsBs],axis=1)
print('Y output shape:')
print(Y_output.shape)
print('')


# GRAD B
ds_Bm_x = load_split_norm_data('Bm_x_MLD_lowres')
ds_Bm_y = load_split_norm_data('Bm_y_MLD_lowres')
ds_Bm_z = load_split_norm_data('Bm_z_MLD_lowres')

grad_b = np.stack([ds_Bm_x,ds_Bm_y,ds_Bm_z],axis=1)
print('grad b shape:')
print( grad_b.shape)
# Out:
# X input shape:
# (8600, 4, 15, 15)
#
# Y output shape:
# (8600, 3, 15, 15)
#
# grad b shape:
# (8600, 3, 15, 15)

# %% [markdown]
# ### randomly generate train, test and validation sets

# %%
# TRAIN AND TEST ONLY
# randomnly generate train, test and validation time indecies 
import random
time_ind = X_input.shape[0]
rand_ind = np.arange(time_ind)
rand_seed = 14
random.Random(rand_seed).shuffle(rand_ind)
train_percent = 0.9
test_percent = 0.1 
print(f"Dataset: train {np.round(train_percent*100)}%, test {np.round(test_percent*100)}%")
train_ind, test_ind =  rand_ind[:round(train_percent*time_ind)], rand_ind[round((train_percent)*time_ind):]                                                                        

# check no overlapping indecies
if np.intersect1d(train_ind, test_ind).any():
    print('overlapping indecies')
else:
    print ('no overlapping indecies')
# Out:
# Dataset: train 90.0%, test 10.0%
# no overlapping indecies

# %% [markdown]
# ### defined train, test and val dataloaders

# %%
# Define X,Y pairs (state, subgrid fluxes) for local network.local_torch_dataset = Data.TensorDataset(
BATCH_SIZE = 32  # Number of sample in each batch


###### training dataset #######
torch_dataset_train = Data.TensorDataset(
    torch.from_numpy(X_input[train_ind]).double(),
    torch.from_numpy(Y_output[train_ind]).double(),
    torch.from_numpy(grad_b[train_ind]).double(),
)

loader_train = Data.DataLoader(
    dataset=torch_dataset_train, batch_size=BATCH_SIZE, shuffle=True
)
print('TRAIN')
print('X input shape:')
print( X_input[train_ind].shape)
print('Y output shape:')
print( Y_output[train_ind].shape)
print('grad b shape:')
print( grad_b[train_ind].shape)
print('')

###### test dataset #######
torch_dataset_test = Data.TensorDataset(
    torch.from_numpy(X_input[test_ind]).double(),
    torch.from_numpy(Y_output[test_ind]).double(),
    torch.from_numpy(grad_b[test_ind]).double(),
    
)

loader_test = Data.DataLoader(
    dataset=torch_dataset_test, batch_size=BATCH_SIZE, shuffle=True
)

print('TEST')
print('X input shape:')
print( X_input[test_ind].shape)
print('Y output shape:')
print( Y_output[test_ind].shape)
print('grad b shape:')
print( grad_b[test_ind].shape)
print('')

###### validation dataset #######
#torch_dataset_val = Data.TensorDataset(
#    torch.from_numpy(X_input[val_ind]).double(),
#    torch.from_numpy(Y_output[val_ind]).double(),
#    torch.from_numpy(grad_b[val_ind]).double(),
#)

#BATCH_SIZE_TEST = len(torch_dataset_test)

#loader_val = Data.DataLoader(
#    dataset=torch_dataset_val, batch_size=BATCH_SIZE_TEST, shuffle=True
#)

#print('VAL')
#print('X input shape:')
#print( X_input[val_ind].shape)
#print('Y output shape:')
#print( Y_output[val_ind].shape)
#print('grad b shape:')
#print( grad_b[val_ind].shape)
#print('')
# Out:
# TRAIN
# X input shape:
# (7740, 4, 15, 15)
# Y output shape:
# (7740, 3, 15, 15)
# grad b shape:
# (7740, 3, 15, 15)
#
# TEST
# X input shape:
# (860, 4, 15, 15)
# Y output shape:
# (860, 3, 15, 15)
# grad b shape:
# (860, 3, 15, 15)

# %% [markdown]
# ## CNN - skew fluxes 9 output channels represeting 3X3 J matrix

# %%
# define network structure in pytorch
import torch.nn.functional as FF

class CNN_skew(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(4, 128, 3, padding='same', padding_mode='reflect')  # 4 inputs, 64 neurons for first hidden layer
        self.dropout1 = nn.Dropout(0.05)
        self.conv1_bn=nn.BatchNorm2d(128)
        self.conv2 = nn.Conv2d(128, 96, 3, padding='same', padding_mode='reflect')  # 64 inputs, 32 neurons for first hidden layer
        self.dropout2 = nn.Dropout(0.05)
        self.conv2_bn=nn.BatchNorm2d(96)
        self.conv3 = nn.Conv2d(96, 64, 3, padding='same', padding_mode='reflect')  # 32 inputs, 16 neurons for first hidden layer
        self.dropout3 = nn.Dropout(0.05)
        self.conv3_bn=nn.BatchNorm2d(64)  
        self.conv4 = nn.Conv2d(64, 32, 3, padding='same', padding_mode='reflect')  # 16 inputs, 3 neurons for first hidden layer
        self.dropout4 = nn.Dropout(0.05)
        self.conv4_bn=nn.BatchNorm2d(32) 
        self.conv5 = nn.Conv2d(32,24, 3, padding='same', padding_mode='reflect')  # 32 inputs, 24 neurons for first hidden layer
        self.dropout5 = nn.Dropout(0.05)
        self.conv5_bn=nn.BatchNorm2d(24) # 9 outputs
        self.conv6 = nn.Conv2d(24, 16, 3, padding='same', padding_mode='reflect')  # 32 inputs, 24 neurons for first hidden layer
        self.dropout6 = nn.Dropout(0.05)
        self.conv6_bn=nn.BatchNorm2d(16) # 3 outputs
        self.conv7 = nn.Conv2d(16, 9, 3, padding='same', padding_mode='reflect')  # 32 inputs, 24 neurons for first hidden layer
        self.dropout7 = nn.Dropout(0.05)
        self.conv7_bn=nn.BatchNorm2d(9) # 3 outputs

    def forward(self, x):
        x = self.conv1(x)
        x = self.dropout1(x)
        x = F.relu(self.conv1_bn(x))
        x = self.conv2(x)
        x = self.dropout2(x)
        x = F.relu(self.conv2_bn(x))
        x = self.conv3(x)
        x = self.dropout3(x)
        x = F.relu(self.conv3_bn(x))
        x = self.conv4(x)
        x = self.dropout4(x)
        x = F.relu(self.conv4_bn(x))
        x = self.conv5(x)
        x = self.dropout5(x)
        x = F.relu(self.conv5_bn(x))
        x = self.conv6(x)
        x = self.dropout6(x)
        x = F.relu(self.conv6_bn(x))
        x = self.conv7(x)
        x = self.dropout7(x)
        x = self.conv7_bn(x)
        return x
 
    
# define network structure in pytorch
import torch.nn.functional as FF

#class CNN_direct(nn.Module):
#    def __init__(self):
#        super().__init__()
#        self.conv1 = nn.Conv2d(4, 64, 5,padding='same')  # 4 inputs, 128 neurons for first hidden layer
#        self.conv2 = nn.Conv2d(64, 32, 5,padding='same')  # 64 inputs, 32 neurons for first hidden layer
#        self.conv3 = nn.Conv2d(32, 3, 5,padding='same')  # 32 inputs, 24 neurons for first hidden layer

#    def forward(self, x):
#        x = FF.relu(self.conv1(x))
#        x = FF.relu(self.conv2(x))
#        x = self.conv3(x)
#        return x
    
    
# define network structure in pytorch
import torch.nn.functional as FF

#class CNN_direct(nn.Module):
#    def __init__(self):
#        super().__init__()
#        self.conv1 = nn.Conv2d(4, 64, 5,padding='same')  # 4 inputs, 128 neurons for first hidden layer
#        self.conv2 = nn.Conv2d(64, 32, 5,padding='same')  # 64 inputs, 32 neurons for first hidden layer
#        self.conv3 = nn.Conv2d(32, 3, 5,padding='same')  # 32 inputs, 24 neurons for first hidden layer

#    def forward(self, x):
#        x = FF.relu(self.conv1(x))
#        x = FF.relu(self.conv2(x))
#        x = self.conv3(x)
#        return x

# %% [markdown]
# ## Train and test model: direct fluxes

# %%
# train network 
def train_model_skew(net, criterion, trainloader, optimizer, len_train_dataset, text="train"):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    net.to(device)
    device_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else "cpu"
    print(f"Training starts on device {device_name}, number of samples {len(trainloader)}")
    
    net.train()
    train_loss = 0
    for step, (batch_x, batch_y, batch_g) in enumerate(trainloader):  # for each training step
        b_x = Variable(batch_x)  # Inputs
        b_y = Variable(batch_y)  # outputs
        b_grad = Variable(batch_g) # grad b
        prediction = net(b_x.to(device))
            
        prediction_reshape = torch.reshape(prediction, (prediction.shape[0],prediction.shape[2],prediction.shape[3],3, 3))
        grad_b_reshape = torch.reshape(b_grad, (b_grad.shape[0],b_grad.shape[2],b_grad.shape[3],3,1)).to(device)
            
        b_grad_view = grad_b_reshape.view(-1,3,1)
        prediction_view = prediction_reshape.view(-1,3,3)
            
        #print(prediction_reshape.shape)
        #print(grad_b_reshape.shape)
        
        #b_y_reshape = torch.reshape(b_y, (3, b_y.shape[0],b_y.shape[2],b_y.shape[3]))
        product = torch.bmm(prediction_view,b_grad_view)
        #print(product.shape)
        product_reshape = torch.reshape(product, (b_grad.shape[0],b_grad.shape[1],b_grad.shape[2],b_grad.shape[3])).to(device)
        #print(product_reshape.shape)
        #print(b_y.shape)
        
        
        # Calculating loss to find J which is the prediction
        loss = criterion(product_reshape, b_y.to(device)) 
        optimizer.zero_grad()  # clear gradients for next train
        loss.backward()  # backpropagation, compute gradients
        optimizer.step()  # apply gradients to update weights
        nb = b_y.shape[0]
        train_loss = train_loss + nb * loss.detach().cpu().numpy()  # Keep track of the loss
    train_loss /= len_train_dataset # dividing by the number of batches
    print(text + " loss:", train_loss)
    return train_loss


def test_model_skew(net, criterion, testloader, optimizer,len_test_dataset, text="validation"):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    net.to(device)
    device_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else "cpu"
    print(f"Training starts on device {device_name}, number of samples {len(testloader)}")
    
    net.eval()  # Evaluation mode (important when having dropout layers)
    test_loss = 0
    with torch.no_grad():
        for step, (batch_x, batch_y, batch_g) in enumerate(
            testloader
        ):  # for each training step
            b_x = Variable(batch_x)  # Inputs
            b_y = Variable(batch_y)  # outputs
            b_grad = Variable(batch_g) # grad b
            prediction = net(b_x.to(device))
            prediction_reshape = torch.reshape(prediction, (prediction.shape[0],prediction.shape[2],prediction.shape[3],3, 3))
            grad_b_reshape = torch.reshape(b_grad, (b_grad.shape[0],b_grad.shape[2],b_grad.shape[3],3,1)).to(device)
            
            b_grad_view = grad_b_reshape.view(-1,3,1)
            prediction_view = prediction_reshape.view(-1,3,3)
            
        #print(prediction_reshape.shape)
        #print(grad_b_reshape.shape)
        
        #b_y_reshape = torch.reshape(b_y, (3, b_y.shape[0],b_y.shape[2],b_y.shape[3]))
            product = torch.bmm(prediction_view,b_grad_view)
        #print(product.shape)
            product_reshape = torch.reshape(product, (b_grad.shape[0],b_grad.shape[1],b_grad.shape[2],b_grad.shape[3])).to(device)
        #print(product_reshape.shape)
        #print(b_y.shape)
        
        
        # Calculating loss to find J which is the prediction
            loss = criterion(product_reshape, b_y.to(device)) 
            nb = b_y.shape[0]
            test_loss = test_loss + nb * loss.detach().cpu().numpy()  # Keep track of the loss
        test_loss /= len_test_dataset  # dividing by the number of batches
        #         print(len(trainloader))
        print(text + " loss:", test_loss)
    return test_loss



def plot_model_skew(net, criterion, testloader, optimizer, len_test_dataset,text="validation"):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    net.to(device)
    device_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else "cpu"
    print(f"Training starts on device {device_name}, number of samples {len(testloader)}")
    
    net.eval()  # Evaluation mode (important when having dropout layers)
    test_loss = 0
    with torch.no_grad():
        for step, (batch_x, batch_y,batch_g) in enumerate(
            testloader
        ):  # for each training step
            b_x = Variable(batch_x)  # Inputs
            b_y = Variable(batch_y)  # outputs
            b_grad = Variable(batch_g) # grad b
            prediction = net(b_x.to(device))
            prediction_reshape = torch.reshape(prediction, (prediction.shape[0],prediction.shape[2],prediction.shape[3],3, 3))
            grad_b_reshape = torch.reshape(b_grad, (b_grad.shape[0],b_grad.shape[2],b_grad.shape[3],3,1)).to(device)
            
            b_grad_view = grad_b_reshape.view(-1,3,1)
            prediction_view = prediction_reshape.view(-1,3,3)
            
        #print(prediction_reshape.shape)
        #print(grad_b_reshape.shape)
        
        #b_y_reshape = torch.reshape(b_y, (3, b_y.shape[0],b_y.shape[2],b_y.shape[3]))
            product = torch.bmm(prediction_view,b_grad_view)
        #print(product.shape)
            product_reshape = torch.reshape(product, (b_grad.shape[0],b_grad.shape[1],b_grad.shape[2],b_grad.shape[3])).to(device)
        #print(product_reshape.shape)
        #print(b_y.shape)
        
        
        # Calculating loss to find J which is the prediction
            loss = criterion(product_reshape, b_y.to(device)) 
            
            
            nb = b_y.shape[0]
            test_loss = test_loss + nb * loss.detach().cpu().numpy()  # Keep track of the loss
        test_loss /= len_test_dataset  # dividing by the number of batches
        #         print(len(trainloader))
        print(text + " loss:", test_loss)
    return b_x, b_y, product_reshape, prediction_view, b_grad_view


criterion = torch.nn.MSELoss()  # MSE loss function

# %% [markdown]
# ## train CNN!

# %%
torch.manual_seed(14)  # For reproducibility
cnn_submeso = CNN_skew().double()

n_epochs = 100  # Number of epocs could be increased
optimizer = optim.Adam(cnn_submeso.parameters(), lr=0.03)
test_loss = list()
train_loss = list()
for epoch in range(1, n_epochs + 1):
    print("epoch:", epoch)
    train_loss.append(train_model_skew(cnn_submeso, criterion, loader_train, optimizer,len(torch_dataset_train)))
    test_loss.append(test_model_skew(cnn_submeso, criterion, loader_test, optimizer,len(torch_dataset_test)))
# Out:
# epoch: 1
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 1.2234984452249882
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9478337241323599
# epoch: 2
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9787755948804351
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9430332868829981
# epoch: 3
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9784547204911246
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9416153220465084
# epoch: 4
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9757324250327475
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9341328197850044
# epoch: 5
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9740031533657573
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9348778956591661
# epoch: 6
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9722345784488817
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9364888813128729
# epoch: 7
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9708316943512054
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9308650081093184
# epoch: 8
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9707136583847611
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9449459711767668
# epoch: 9
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.970998721068931
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.929038872925979
# epoch: 10
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9669966171706479
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9251663207432493
# epoch: 11
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9661982532421871
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.928109367242441
# epoch: 12
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9658436324584968
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9368662076781581
# epoch: 13
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9657577674562441
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9374385951573033
# epoch: 14
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9652961628427975
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9317977212525312
# epoch: 15
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9645158392290015
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9423469284330996
# epoch: 16
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9628169761394304
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9170464551009793
# epoch: 17
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9621302948616884
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9190073224844783
# epoch: 18
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9622235960898748
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9222793243477985
# epoch: 19
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9613143490083375
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9241237663274273
# epoch: 20
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9603146972263451
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.926670798750505
# epoch: 21
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9588210551508499
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9170445342731854
# epoch: 22
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9591483382326716
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9136691568405869
# epoch: 23
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9572898085307008
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9154705991410613
# epoch: 24
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9561589812039963
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9293657183737054
# epoch: 25
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9564343683291221
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9106525196020965
# epoch: 26
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9545930803945756
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9194597963851779
# epoch: 27
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.956008698870417
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9240429927312773
# epoch: 28
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.957766348633898
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9203821723233842
# epoch: 29
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9560422397789604
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9182672401075976
# epoch: 30
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.953698741809648
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9111624040301454
# epoch: 31
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.953554295125698
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9073442624371055
# epoch: 32
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.952000420264738
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9138862888553302
# epoch: 33
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9533375324397394
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9099306325165492
# epoch: 34
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9512428724505009
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9065008045233824
# epoch: 35
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9504384947171239
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9079198256286733
# epoch: 36
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9506937383115006
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9131392654258331
# epoch: 37
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9514892681155274
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9113776171643141
# epoch: 38
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9515515239839331
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9120708273485135
# epoch: 39
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9501699566740515
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9060104191387425
# epoch: 40
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9486521968798937
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9082457115929098
# epoch: 41
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9488320669718174
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.910192881172668
# epoch: 42
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9466192391992317
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9130940060791553
# epoch: 43
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9487077234736281
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.906183853052824
# epoch: 44
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9447070584214468
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9094032787420585
# epoch: 45
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9450665538069257
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.8999218766321476
# epoch: 46
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9461249722168249
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.904381818068798
# epoch: 47
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.944117626933544
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9150430288342946
# epoch: 48
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9454269538544532
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9169858003782699
# epoch: 49
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9436844164095745
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9082579404389254
# epoch: 50
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9404244768035193
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9019801527678231
# epoch: 51
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9413984940528642
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9055916514842348
# epoch: 52
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9405251021858748
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9116319149092751
# epoch: 53
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9392779623546805
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.8961217529465189
# epoch: 54
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.939757144990481
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.903012002508363
# epoch: 55
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9372584292896304
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9046033141625811
# epoch: 56
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9347983274023678
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9083163306693209
# epoch: 57
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9371648378763504
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9013723140298271
# epoch: 58
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9315192704778028
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9385484597179684
# epoch: 59
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9367718277737441
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9075835410499434
# epoch: 60
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9321705051938273
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9121345093883623
# epoch: 61
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9326960460944611
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9146786706211444
# epoch: 62
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9287705397938396
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.8944067627033694
# epoch: 63
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9278123987654783
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9084167357776862
# epoch: 64
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9263331696342629
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9223324002867311
# epoch: 65
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.928561623123485
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9002619314327327
# epoch: 66
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9276774493368225
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9028059347736495
# epoch: 67
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9273541087815307
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.8950680180248994
# epoch: 68
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9269242858189963
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9035879037435561
# epoch: 69
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.921076893407566
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9106986229075661
# epoch: 70
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9207438167797822
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.8975632239090725
# epoch: 71
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9203817054435521
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9058924408402498
# epoch: 72
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9185990464736471
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9002071117815724
# epoch: 73
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9204291016764532
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.8993092207374183
# epoch: 74
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9139400501875179
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9029511308470196
# epoch: 75
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9208035410238146
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.8959442342550104
# epoch: 76
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9121048166749757
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.8983428111799966
# epoch: 77
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9139283409007876
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.8943814713578414
# epoch: 78
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9135439135604042
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.8921160049424165
# epoch: 79
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9129013362774444
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9005586964022372
# epoch: 80
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9134341461543657
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.8977767679254472
# epoch: 81
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9080741474365867
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9020577614407722
# epoch: 82
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9076740604535005
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9037898700779327
# epoch: 83
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9028538953238913
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9001544090757261
# epoch: 84
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9052982108319662
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.8886041591010759
# epoch: 85
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9037326690566547
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.8954993367371463
# epoch: 86
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9043138861364586
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9013168966576146
# epoch: 87
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9023085580757135
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.8938892133516821
# epoch: 88
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.8975009169240223
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.905746747164246
# epoch: 89
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9000830123425552
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.8996537770093664
# epoch: 90
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.8949703286288301
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9017536003227711
# epoch: 91
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.8972751337691081
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9052677669997001
# epoch: 92
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9034337338217251
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.8885359473442407
# epoch: 93
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.9041270379091803
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.8992517034138391
# epoch: 94
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.8924389532544309
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.8989909949582597
# epoch: 95
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.8967827567659332
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.8917026688621715
# epoch: 96
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.8910291057545511
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.8912335000247762
# epoch: 97
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.8942057927789692
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.9020759660876079
# epoch: 98
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.8881747587173578
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.8921158200258635
# epoch: 99
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.8892373525062195
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.890838736800731
# epoch: 100
# Training starts on device Tesla V100-SXM2-16GB, number of samples 242
# train loss: 0.8858834472973182
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.8928568406835989

# %%
import matplotlib.pyplot as plt

plt.plot(train_loss[1:], "b", label="training loss")
plt.plot(test_loss[1:], "r", label="test loss")


plt.legend();

# %%
b_x, b_y, product_reshape, prediction_view, b_grad_view = plot_model_skew(cnn_submeso, criterion, loader_test, optimizer,len(torch_dataset_test))
# Out:
# Training starts on device Tesla V100-SXM2-16GB, number of samples 27
# validation loss: 0.8928568406835992

# %%
from scipy import stats
corr_pred_ub = stats.pearsonr(product_reshape.detach().cpu().numpy()[:,0,:,:].flatten(), b_y[:,0,:,:].flatten())
corr_pred_vb = stats.pearsonr(product_reshape.detach().cpu().numpy()[:,1,:,:].flatten(), b_y[:,1,:,:].flatten())
corr_pred_wb = stats.pearsonr(product_reshape.detach().cpu().numpy()[:,2,:,:].flatten(), b_y[:,2,:,:].flatten())

print("correlation between prediction and target,  u'b':",corr_pred_ub )
print("correlation between prediction and target,  v'b':",corr_pred_vb )
print("correlation between prediction and target,  w'b':",corr_pred_wb )
# Out:
# correlation between prediction and target,  u'b': (0.21323757148436492, 1.0691590507085742e-65)
# correlation between prediction and target,  v'b': (0.25496756040636903, 4.6584742565676973e-94)
# correlation between prediction and target,  w'b': (0.40835471181722116, 8.064356320333609e-252)

# %%
# visualize
it =18

fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(8, 4))
fig.tight_layout() # Or equivalently,  "plt.tight_layout()"

plt.subplot(231)
plt.pcolor(product_reshape.detach().cpu().numpy()[it,0,:,:],cmap='viridis',vmin=-1,vmax =1)
plt.title('ub prediction')
plt.colorbar()

plt.subplot(234)
plt.pcolor(b_y[it,0,:,:],cmap='viridis',vmin=-1,vmax =1)
plt.title('ub target')
plt.colorbar()

plt.subplot(232)
plt.pcolor(product_reshape.detach().cpu().numpy()[it,1,:,:],cmap='viridis',vmin=-1,vmax =1)
plt.title('vb prediction')
plt.colorbar()

plt.subplot(235)
plt.pcolor(b_y[it,1,:,:],cmap='viridis',vmin=-1,vmax =1)
plt.title('vb target')
plt.colorbar()

plt.subplot(233)
plt.pcolor(product_reshape.detach().cpu().numpy()[it,2,:,:],cmap='viridis',vmin=-1,vmax =1)
plt.title('wb prediction')
plt.colorbar()

plt.subplot(236)
plt.pcolor(b_y[it,2,:,:],cmap='viridis',vmin=-1,vmax =1)
plt.title('wb target')
plt.colorbar()

# %%
_=plt.hist(b_y.detach().cpu().numpy().flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="target")
_=plt.hist(product_reshape.detach().cpu().numpy().flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="prediction")

plt.xlim([-3,3])
plt.legend()

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(12, 4))
fig.tight_layout() # Or equivalently,  "plt.tight_layout()"

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

plt.subplot(131)
_=plt.hist(b_y.detach().cpu().numpy()[:,0,:,:].flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="target")
_=plt.hist(product_reshape.detach().cpu().numpy()[:,0,:,:].flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="prediction")
plt.xlim([-3,3])
plt.legend()
plt.title('ub')


plt.subplot(132)
_=plt.hist(b_y.detach().cpu().numpy()[:,1,:,:].flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="target")
_=plt.hist(product_reshape.detach().cpu().numpy()[:,1,:,:].flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="prediction")
plt.xlim([-3,3])
plt.legend()
plt.title('vb')

plt.subplot(133)
_=plt.hist(b_y.detach().cpu().numpy()[:,2,:,:].flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="target")
_=plt.hist(product_reshape.detach().cpu().numpy()[:,2,:,:].flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="prediction")
plt.xlim([-3,3])
plt.legend()
plt.title('wb')
# Out:
# Text(0.5, 1.0, 'wb')

# %%
target_da = xr.DataArray(b_y.detach().cpu().numpy(), dims=["time", "axis", "i","j"])
prediction_da = xr.DataArray(cnn_submeso(b_x.to(device)).detach().cpu().numpy(), dims=["time", "axis", "i","j"])

# %%
import xrft

# target vs prediction spectra
UsBs_target_spectra = xrft.isotropic_power_spectrum(target_da.isel(axis=0),dim=['i','j'], 
                                           detrend='linear', window=True).compute().mean('time')

UsBs_prediction_spectra = xrft.isotropic_power_spectrum(prediction_da.isel(axis=0),dim=['i','j'], 
                                           detrend='linear', window=True).compute().mean('time')


VsBs_target_spectra = xrft.isotropic_power_spectrum(target_da.isel(axis=1),dim=['i','j'], 
                                           detrend='linear', window=True).compute().mean('time')

VsBs_prediction_spectra = xrft.isotropic_power_spectrum(prediction_da.isel(axis=1),dim=['i','j'], 
                                           detrend='linear', window=True).compute().mean('time')


WsBs_target_spectra = xrft.isotropic_power_spectrum(target_da.isel(axis=2),dim=['i','j'], 
                                           detrend='linear', window=True).compute().mean('time')

WsBs_prediction_spectra = xrft.isotropic_power_spectrum(prediction_da.isel(axis=2),dim=['i','j'], 
                                           detrend='linear', window=True).compute().mean('time')
# Out:
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:47: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:1025: FutureWarning: Isotropic wavenumber larger than the Nyquist wavenumber may result.
#   warnings.warn(msg, FutureWarning)
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:47: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:1025: FutureWarning: Isotropic wavenumber larger than the Nyquist wavenumber may result.
#   warnings.warn(msg, FutureWarning)
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:47: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:1025: FutureWarning: Isotropic wavenumber larger than the Nyquist wavenumber may result.
#   warnings.warn(msg, FutureWarning)
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:47: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:1025: FutureWarning: Isotropic wavenumber larger than the Nyquist wavenumber may result.
#   warnings.warn(msg, FutureWarning)
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:47: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:1025: FutureWarning: Isotropic wavenumber larger than the Nyquist wavenumber may result.
#   warnings.warn(msg, FutureWarning)
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:47: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:1025: FutureWarning: Isotropic wavenumber larger than the Nyquist wavenumber may result.
#   warnings.warn(msg, FutureWarning)

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(20, 5))
fig.tight_layout() # Or equivalently,  "plt.tight_layout()"

plt.subplot(131)
#plt.loglog(UsBs_target_spectra.freq_r*2*np.pi, 5e-3*UsBs_target_spectra.freq_r**-2, '--',linewidth=1.5,color='black', label='k^{-2}')
#plt.loglog(UsBs_target_spectra.freq_r*2*np.pi, 2e-3*UsBs_target_spectra.freq_r**-3, '--',linewidth=1.5,color='gray', label='k^{-3}')
plt.loglog(UsBs_target_spectra.freq_r*2*np.pi, UsBs_target_spectra/UsBs_target_spectra[0],linewidth=2, label='target')
plt.loglog(UsBs_prediction_spectra.freq_r*2*np.pi, UsBs_prediction_spectra/UsBs_target_spectra[0],linewidth=2, label='prediction')
plt.legend()
plt.xlabel('$k_r$')
plt.ylabel('Normalized isotropic spectra')
plt.title('UsBs')


plt.subplot(132)
#plt.loglog(VsBs_target_spectra.freq_r*2*np.pi, 5e-3*VsBs_target_spectra.freq_r**-2, '--',linewidth=1.5,color='black', label='k^{-2}')
#plt.loglog(VsBs_target_spectra.freq_r*2*np.pi, 2e-3*VsBs_target_spectra.freq_r**-3, '--',linewidth=1.5,color='gray', label='k^{-3}')
plt.loglog(VsBs_target_spectra.freq_r*2*np.pi, VsBs_target_spectra/VsBs_target_spectra[0],linewidth=2, label='target')
plt.loglog(VsBs_prediction_spectra.freq_r*2*np.pi, VsBs_prediction_spectra/VsBs_target_spectra[0],linewidth=2, label='prediction')
plt.legend()
plt.xlabel('$k_r$')
#plt.ylabel('Normalized isotropic spectra')
plt.title('VsBs')


plt.subplot(133)
#plt.loglog(WsBs_target_spectra.freq_r*2*np.pi, 5e-3*WsBs_target_spectra.freq_r**-2, '--',linewidth=1.5,color='black', label='k^{-2}')
#plt.loglog(WsBs_target_spectra.freq_r*2*np.pi, 2e-3*WsBs_target_spectra.freq_r**-3, '--',linewidth=1.5,color='gray', label='k^{-3}')
plt.loglog(WsBs_target_spectra.freq_r*2*np.pi, WsBs_target_spectra/WsBs_target_spectra[0],linewidth=2, label='target')
plt.loglog(WsBs_target_spectra.freq_r*2*np.pi, WsBs_prediction_spectra/WsBs_target_spectra[0],linewidth=2, label='prediction')
plt.legend()
plt.xlabel('$k_r$')
#plt.ylabel('Normalized isotropic spectra')
plt.title('WsBs')
# Out:
# Text(0.5, 1.0, 'WsBs')
