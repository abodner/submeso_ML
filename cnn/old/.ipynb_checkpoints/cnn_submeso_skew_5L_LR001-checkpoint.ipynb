# %%
import torch
import torch.nn.functional as F
import torch.utils.data as Data
import torchvision
from torch import nn, optim
from torch.autograd import Variable
import numpy as np
import os
import glob
import xarray as xr
from sklearn import preprocessing
import netCDF4 as nc
import matplotlib.pyplot as plt



np.random.seed(14)  # For reproducibility
torch.manual_seed(14)  # For reproducibility

# %% [markdown]
# # Dataloader

# %% [markdown]
# ### Create input and output channels

# %%
# function that splits datasets along the spacial axes and concats them back into single array under time

def normalize(data):
    #normalized_data =  (data - data.mean(skipna=True).values)/data.std(skipna=True).values
    normalized_data = (data - np.mean(data))/np.std(data)
    return normalized_data


def load_norm_data(var_name_string):
    PATH_LIST = glob.glob(BASE+'*/preprocessed_data/'+var_name_string+'.nc') 
    data_app = normalize(xr.open_dataarray(PATH_LIST[0]).to_numpy()[:,5:-5,5:-5])
    for i_file in np.arange(1,len(PATH_LIST)):
        PATH = PATH_LIST[i_file]
        data = xr.open_dataarray(PATH).to_numpy()[:,5:-5,5:-5]
        data_norm = normalize(data)
        data_app = np.concatenate((data_app,data_norm),axis=0)
    return data_app



def split_data(data):
    data_split_halfs = np.concatenate((np.split(data,2,axis=1)[0],np.split(data,2,axis=1)[1]),0)
    data_split_quarters = np.concatenate((np.split(data_split_halfs,2,axis=2)[0],np.split(data_split_halfs,2,axis=2)[1]),0)
    return data#data_split_quarters



def load_split_norm_data(var_name_string):
    loaded_data = load_norm_data(var_name_string)
    splitted_data = split_data(loaded_data)
    return splitted_data
    
    
def load_split_norm_data_out(var_name_string):
    loaded_data = load_norm_data(var_name_string)
    splitted_data = split_data(loaded_data)
    cropped_output = splitted_data[:,5:-5,5:-5] # for a kernel of size 3 with 5 conv layers
    return cropped_output

# %%
# load preprocessed data, convert to numpy and stack channels

BASE = '/scratch/ab10313/submeso_ML_data/'
FULL_PATH_PP = glob.glob(BASE+'*/preprocessed_data/')

# X INPUT
ds_Bm = load_split_norm_data('Bm_MLD_lowres')
ds_Um = load_split_norm_data('Um_MLD_lowres')
ds_Vm = load_split_norm_data('Vm_MLD_lowres')
ds_Wm = load_split_norm_data('Wm_MLD_lowres')


X_input = np.stack([ds_Bm,ds_Um,ds_Vm,ds_Wm],axis=1)
print('X input shape:')
print( X_input.shape)
print('')


# Y OUTPUT
ds_UsBs = load_split_norm_data('UsBs_MLD_lowres')
ds_VsBs = load_split_norm_data('VsBs_MLD_lowres')
ds_WsBs = load_split_norm_data('WsBs_MLD_lowres')

Y_output = np.stack([ds_UsBs,ds_VsBs,ds_WsBs],axis=1)
print('Y output shape:')
print(Y_output.shape)
print('')


# GRAD B
ds_Bm_x = load_split_norm_data('Bm_x_MLD_lowres')
ds_Bm_y = load_split_norm_data('Bm_y_MLD_lowres')
ds_Bm_z = load_split_norm_data('Bm_z_MLD_lowres')

grad_b = np.stack([ds_Bm_x,ds_Bm_y,ds_Bm_z],axis=1)
print('grad b shape:')
print( grad_b.shape)
# Out:
# X input shape:
# (2150, 4, 30, 30)
#
# Y output shape:
# (2150, 3, 30, 30)
#
# grad b shape:
# (2150, 3, 30, 30)

# %% [markdown]
# ### randomly generate train, test and validation sets

# %%
# TRAIN AND TEST ONLY
# randomnly generate train, test and validation time indecies 
import random
time_ind = X_input.shape[0]
rand_ind = np.arange(time_ind)
rand_seed = 14
random.Random(rand_seed).shuffle(rand_ind)
train_percent = 0.9
test_percent = 0.1 
print(f"Dataset: train {np.round(train_percent*100)}%, test {np.round(test_percent*100)}%")
train_ind, test_ind =  rand_ind[:round(train_percent*time_ind)], rand_ind[round((train_percent)*time_ind):]                                                                        

# check no overlapping indecies
if np.intersect1d(train_ind, test_ind).any():
    print('overlapping indecies')
else:
    print ('no overlapping indecies')
# Out:
# Dataset: train 90.0%, test 10.0%
# no overlapping indecies

# %% [markdown]
# ### defined train, test and val dataloaders

# %%
# Define X,Y pairs (state, subgrid fluxes) for local network.local_torch_dataset = Data.TensorDataset(
BATCH_SIZE = 32  # Number of sample in each batch


###### training dataset #######
torch_dataset_train = Data.TensorDataset(
    torch.from_numpy(X_input[train_ind]).double(),
    torch.from_numpy(Y_output[train_ind]).double(),
    torch.from_numpy(grad_b[train_ind]).double(),
)

loader_train = Data.DataLoader(
    dataset=torch_dataset_train, batch_size=BATCH_SIZE, shuffle=True
)
print('TRAIN')
print('X input shape:')
print( X_input[train_ind].shape)
print('Y output shape:')
print( Y_output[train_ind].shape)
print('grad b shape:')
print( grad_b[train_ind].shape)
print('')

###### test dataset #######
torch_dataset_test = Data.TensorDataset(
    torch.from_numpy(X_input[test_ind]).double(),
    torch.from_numpy(Y_output[test_ind]).double(),
    torch.from_numpy(grad_b[test_ind]).double(),
    
)

loader_test = Data.DataLoader(
    dataset=torch_dataset_test, batch_size=BATCH_SIZE, shuffle=True
)

print('TEST')
print('X input shape:')
print( X_input[test_ind].shape)
print('Y output shape:')
print( Y_output[test_ind].shape)
print('grad b shape:')
print( grad_b[test_ind].shape)
print('')

###### validation dataset #######
#torch_dataset_val = Data.TensorDataset(
#    torch.from_numpy(X_input[val_ind]).double(),
#    torch.from_numpy(Y_output[val_ind]).double(),
#    torch.from_numpy(grad_b[val_ind]).double(),
#)

#BATCH_SIZE_TEST = len(torch_dataset_test)

#loader_val = Data.DataLoader(
#    dataset=torch_dataset_val, batch_size=BATCH_SIZE_TEST, shuffle=True
#)

#print('VAL')
#print('X input shape:')
#print( X_input[val_ind].shape)
#print('Y output shape:')
#print( Y_output[val_ind].shape)
#print('grad b shape:')
#print( grad_b[val_ind].shape)
#print('')
# Out:
# TRAIN
# X input shape:
# (1935, 4, 30, 30)
# Y output shape:
# (1935, 3, 30, 30)
# grad b shape:
# (1935, 3, 30, 30)
#
# TEST
# X input shape:
# (215, 4, 30, 30)
# Y output shape:
# (215, 3, 30, 30)
# grad b shape:
# (215, 3, 30, 30)

# %% [markdown]
# ## CNN - skew fluxes 9 output channels represeting 3X3 J matrix

# %%
# define network structure in pytorch
import torch.nn.functional as FF

class CNN_skew(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(4, 128, 3, padding='same', padding_mode='reflect')  # 4 inputs, 64 neurons for first hidden layer
        self.dropout1 = nn.Dropout(0.2)
        self.conv1_bn=nn.BatchNorm2d(128)
        self.conv2 = nn.Conv2d(128, 64, 3, padding='same', padding_mode='reflect')  # 64 inputs, 32 neurons for first hidden layer
        self.dropout2 = nn.Dropout(0.2)
        self.conv2_bn=nn.BatchNorm2d(64)
        self.conv3 = nn.Conv2d(64, 32, 3, padding='same', padding_mode='reflect')  # 32 inputs, 16 neurons for first hidden layer
        self.dropout3 = nn.Dropout(0.2)
        self.conv3_bn=nn.BatchNorm2d(32)  
        self.conv4 = nn.Conv2d(32, 16, 3, padding='same', padding_mode='reflect')  # 16 inputs, 3 neurons for first hidden layer
        self.dropout4 = nn.Dropout(0.2)
        self.conv4_bn=nn.BatchNorm2d(16) 
        self.conv5 = nn.Conv2d(16, 9, 3, padding='same', padding_mode='reflect')  # 32 inputs, 24 neurons for first hidden layer
        self.dropout5 = nn.Dropout(0.2)
        self.conv5_bn=nn.BatchNorm2d(9) # 9 outputs

    def forward(self, x):
        x = self.conv1(x)
        x = self.dropout1(x)
        x = F.relu(self.conv1_bn(x))
        x = self.conv2(x)
        x = self.dropout2(x)
        x = F.relu(self.conv2_bn(x))
        x = self.conv3(x)
        x = self.dropout3(x)
        x = F.relu(self.conv3_bn(x))
        x = self.conv4(x)
        x = self.dropout4(x)
        x = F.relu(self.conv4_bn(x))
        x = self.conv5(x)
        x = self.dropout5(x)
        x = self.conv5_bn(x)
        return x
 
    
# define network structure in pytorch
import torch.nn.functional as FF

#class CNN_direct(nn.Module):
#    def __init__(self):
#        super().__init__()
#        self.conv1 = nn.Conv2d(4, 64, 5,padding='same')  # 4 inputs, 128 neurons for first hidden layer
#        self.conv2 = nn.Conv2d(64, 32, 5,padding='same')  # 64 inputs, 32 neurons for first hidden layer
#        self.conv3 = nn.Conv2d(32, 3, 5,padding='same')  # 32 inputs, 24 neurons for first hidden layer

#    def forward(self, x):
#        x = FF.relu(self.conv1(x))
#        x = FF.relu(self.conv2(x))
#        x = self.conv3(x)
#        return x

# %% [markdown]
# ## Train and test model: direct fluxes

# %%
# train network 
def train_model_skew(net, criterion, trainloader, optimizer, len_train_dataset, text="train"):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    net.to(device)
    device_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else "cpu"
    print(f"Training starts on device {device_name}, number of samples {len(trainloader)}")
    
    net.train()
    train_loss = 0
    for step, (batch_x, batch_y, batch_g) in enumerate(trainloader):  # for each training step
        b_x = Variable(batch_x)  # Inputs
        b_y = Variable(batch_y)  # outputs
        b_grad = Variable(batch_g) # grad b
        prediction = net(b_x.to(device))
            
        prediction_reshape = torch.reshape(prediction, (prediction.shape[0],prediction.shape[2],prediction.shape[3],3, 3))
        grad_b_reshape = torch.reshape(b_grad, (b_grad.shape[0],b_grad.shape[2],b_grad.shape[3],3,1)).to(device)
            
        b_grad_view = grad_b_reshape.view(-1,3,1)
        prediction_view = prediction_reshape.view(-1,3,3)
            
        #print(prediction_reshape.shape)
        #print(grad_b_reshape.shape)
        
        #b_y_reshape = torch.reshape(b_y, (3, b_y.shape[0],b_y.shape[2],b_y.shape[3]))
        product = torch.bmm(prediction_view,b_grad_view)
        #print(product.shape)
        product_reshape = torch.reshape(product, (b_grad.shape[0],b_grad.shape[1],b_grad.shape[2],b_grad.shape[3])).to(device)
        #print(product_reshape.shape)
        #print(b_y.shape)
        
        
        # Calculating loss to find J which is the prediction
        loss = criterion(product_reshape, b_y.to(device)) 
        optimizer.zero_grad()  # clear gradients for next train
        loss.backward()  # backpropagation, compute gradients
        optimizer.step()  # apply gradients to update weights
        nb = b_y.shape[0]
        train_loss = train_loss + nb * loss.detach().cpu().numpy()  # Keep track of the loss
    train_loss /= len_train_dataset # dividing by the number of batches
    print(text + " loss:", train_loss)
    return train_loss


def test_model_skew(net, criterion, testloader, optimizer,len_test_dataset, text="validation"):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    net.to(device)
    device_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else "cpu"
    print(f"Training starts on device {device_name}, number of samples {len(testloader)}")
    
    net.eval()  # Evaluation mode (important when having dropout layers)
    test_loss = 0
    with torch.no_grad():
        for step, (batch_x, batch_y, batch_g) in enumerate(
            testloader
        ):  # for each training step
            b_x = Variable(batch_x)  # Inputs
            b_y = Variable(batch_y)  # outputs
            b_grad = Variable(batch_g) # grad b
            prediction = net(b_x.to(device))
            prediction_reshape = torch.reshape(prediction, (prediction.shape[0],prediction.shape[2],prediction.shape[3],3, 3))
            grad_b_reshape = torch.reshape(b_grad, (b_grad.shape[0],b_grad.shape[2],b_grad.shape[3],3,1)).to(device)
            
            b_grad_view = grad_b_reshape.view(-1,3,1)
            prediction_view = prediction_reshape.view(-1,3,3)
            
        #print(prediction_reshape.shape)
        #print(grad_b_reshape.shape)
        
        #b_y_reshape = torch.reshape(b_y, (3, b_y.shape[0],b_y.shape[2],b_y.shape[3]))
            product = torch.bmm(prediction_view,b_grad_view)
        #print(product.shape)
            product_reshape = torch.reshape(product, (b_grad.shape[0],b_grad.shape[1],b_grad.shape[2],b_grad.shape[3])).to(device)
        #print(product_reshape.shape)
        #print(b_y.shape)
        
        
        # Calculating loss to find J which is the prediction
            loss = criterion(product_reshape, b_y.to(device)) 
            nb = b_y.shape[0]
            test_loss = test_loss + nb * loss.detach().cpu().numpy()  # Keep track of the loss
        test_loss /= len_test_dataset  # dividing by the number of batches
        #         print(len(trainloader))
        print(text + " loss:", test_loss)
    return test_loss



def plot_model_skew(net, criterion, testloader, optimizer, len_test_dataset,text="validation"):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    net.to(device)
    device_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else "cpu"
    print(f"Training starts on device {device_name}, number of samples {len(testloader)}")
    
    net.eval()  # Evaluation mode (important when having dropout layers)
    test_loss = 0
    with torch.no_grad():
        for step, (batch_x, batch_y,batch_g) in enumerate(
            testloader
        ):  # for each training step
            b_x = Variable(batch_x)  # Inputs
            b_y = Variable(batch_y)  # outputs
            b_grad = Variable(batch_g) # grad b
            prediction = net(b_x.to(device))
            prediction_reshape = torch.reshape(prediction, (prediction.shape[0],prediction.shape[2],prediction.shape[3],3, 3))
            grad_b_reshape = torch.reshape(b_grad, (b_grad.shape[0],b_grad.shape[2],b_grad.shape[3],3,1)).to(device)
            
            b_grad_view = grad_b_reshape.view(-1,3,1)
            prediction_view = prediction_reshape.view(-1,3,3)
            
        #print(prediction_reshape.shape)
        #print(grad_b_reshape.shape)
        
        #b_y_reshape = torch.reshape(b_y, (3, b_y.shape[0],b_y.shape[2],b_y.shape[3]))
            product = torch.bmm(prediction_view,b_grad_view)
        #print(product.shape)
            product_reshape = torch.reshape(product, (b_grad.shape[0],b_grad.shape[1],b_grad.shape[2],b_grad.shape[3])).to(device)
        #print(product_reshape.shape)
        #print(b_y.shape)
        
        
        # Calculating loss to find J which is the prediction
            loss = criterion(product_reshape, b_y.to(device)) 
            
            
            nb = b_y.shape[0]
            test_loss = test_loss + nb * loss.detach().cpu().numpy()  # Keep track of the loss
        test_loss /= len_test_dataset  # dividing by the number of batches
        #         print(len(trainloader))
        print(text + " loss:", test_loss)
    return b_x, b_y, product_reshape, prediction_view, b_grad_view


criterion = torch.nn.MSELoss()  # MSE loss function

# %% [markdown]
# ## train CNN!

# %%
torch.manual_seed(14)  # For reproducibility
cnn_submeso = CNN_skew().double()

n_epochs = 150  # Number of epocs could be increased
optimizer = optim.Adam(cnn_submeso.parameters(), lr=0.01)
test_loss = list()
train_loss = list()
for epoch in range(1, n_epochs + 1):
    print("epoch:", epoch)
    train_loss.append(train_model_skew(cnn_submeso, criterion, loader_train, optimizer,len(torch_dataset_train)))
    test_loss.append(test_model_skew(cnn_submeso, criterion, loader_test, optimizer,len(torch_dataset_test)))
# Out:
# epoch: 1
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 1.8633475995252204
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9822491636664633
# epoch: 2
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 1.1292957311854805
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.972813330526972
# epoch: 3
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 1.0214809212994096
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9700043510021391
# epoch: 4
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9824398435957924
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9692600865421196
# epoch: 5
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9672046780444802
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9683590734764911
# epoch: 6
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9627113616270532
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9685452662704326
# epoch: 7
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9604078085501043
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.967499052950856
# epoch: 8
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9604248083061487
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.966127098429113
# epoch: 9
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9592687753016527
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9654353845308018
# epoch: 10
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9588481464556408
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9668539590668366
# epoch: 11
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9586124161589104
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.966360912794489
# epoch: 12
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.958061480549881
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9666735626482071
# epoch: 13
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9575864134370895
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9667384487111413
# epoch: 14
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9572357586789796
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9686115269020003
# epoch: 15
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9562656510579626
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9665426374197451
# epoch: 16
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9570073174345102
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9640180978630888
# epoch: 17
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9557733251911925
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.966131345752996
# epoch: 18
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9565221773574318
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9643537370396198
# epoch: 19
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9568262730715119
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9664668521748022
# epoch: 20
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9556631273983905
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9671662206482866
# epoch: 21
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9555615891578204
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9659204337698645
# epoch: 22
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9544922313524307
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9627028631919164
# epoch: 23
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9541569707867843
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9638168231213675
# epoch: 24
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9549611384813135
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9630056349849879
# epoch: 25
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9547753229018523
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9619539718080709
# epoch: 26
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9525178104553969
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9604319370901425
# epoch: 27
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9520963023887038
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9614006063183212
# epoch: 28
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.952961805169746
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9617367611314175
# epoch: 29
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9525778288296984
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9632478934632361
# epoch: 30
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9499303356937775
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.966827336553466
# epoch: 31
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9531688377306543
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.960038586936588
# epoch: 32
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9499701989484145
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9584088361320398
# epoch: 33
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9493009917313913
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9580409113504913
# epoch: 34
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9482911406706515
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9590260601607689
# epoch: 35
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9480877951794738
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9576534239327237
# epoch: 36
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9481817846223859
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9591122157024583
# epoch: 37
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.947216717895567
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9613476981961041
# epoch: 38
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9473879244182708
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.955523548908793
# epoch: 39
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9465207740516174
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9543647104517727
# epoch: 40
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9444540870585543
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9573410168431027
# epoch: 41
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9462715774565881
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9605626510557475
# epoch: 42
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9450478192660449
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9578657670990467
# epoch: 43
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9455963546124423
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9564423085393945
# epoch: 44
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.944139363671004
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9566134093645762
# epoch: 45
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9444204478753352
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9554767982079351
# epoch: 46
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9436054371266817
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9615784165468744
# epoch: 47
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9419370125462545
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.969099348661516
# epoch: 48
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.94361346619009
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9568776530830843
# epoch: 49
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9410261289371379
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.966264843752416
# epoch: 50
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9422840037548293
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9526467428929172
# epoch: 51
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.941067521191639
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.955003951441945
# epoch: 52
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9411606592867464
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.955070684758373
# epoch: 53
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9407318716155749
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9575361307339195
# epoch: 54
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9414221554977683
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9573565235792842
# epoch: 55
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9412383782973904
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9629797549017477
# epoch: 56
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9394863715930374
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9539757437118002
# epoch: 57
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9393726226857687
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9602829321104346
# epoch: 58
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9391270259609077
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9588131690065139
# epoch: 59
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9392516604953868
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9521813344106856
# epoch: 60
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9407686048604532
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.953163261759224
# epoch: 61
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9380612543027818
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9677851746761623
# epoch: 62
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.941659172446385
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9529627221415129
# epoch: 63
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9411225873208271
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9527743264271209
# epoch: 64
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9367204835162726
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9527498702449758
# epoch: 65
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9373481639327628
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.958248200795704
# epoch: 66
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9382648913294618
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9525290363065707
# epoch: 67
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9389846454595496
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9541961745498277
# epoch: 68
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9372501673706177
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9585933901444318
# epoch: 69
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9369224066681554
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.966030998297891
# epoch: 70
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9362252204990306
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9497317733876803
# epoch: 71
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9351020928780926
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9532148174286099
# epoch: 72
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9336563998873562
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9556557175626952
# epoch: 73
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9341849330561852
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9530036809778564
# epoch: 74
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9350536066523583
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9489908450160689
# epoch: 75
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9357429216366009
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9486665249650332
# epoch: 76
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9334017186002542
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9556501038581529
# epoch: 77
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9316510042390416
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9518010060835534
# epoch: 78
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.93187321514712
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9503166182313905
# epoch: 79
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9309572382842997
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9521441308015999
# epoch: 80
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.932598780342653
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9566275727088297
# epoch: 81
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9303197272300483
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.951515135176233
# epoch: 82
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9322149865722975
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9584904114369728
# epoch: 83
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9302049918234633
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.950497198731375
# epoch: 84
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9314560361921899
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9478224363005151
# epoch: 85
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9315628739456305
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9478280271617708
# epoch: 86
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9301135768648047
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9549221700223429
# epoch: 87
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9294930014182132
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.966098659784729
# epoch: 88
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.932559009196238
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9471945994507469
# epoch: 89
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9285064484011898
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9605366009661017
# epoch: 90
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9328400136483667
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9443394821803585
# epoch: 91
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9298926986731341
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9635736325101477
# epoch: 92
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9290286657752759
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9463293414726234
# epoch: 93
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9279158871584663
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9520050347188478
# epoch: 94
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9261786249840711
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.949273719259049
# epoch: 95
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9252642383974169
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9587685754864096
# epoch: 96
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9259994865940927
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9597620152552395
# epoch: 97
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9267336490405387
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9431669782230019
# epoch: 98
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9249658310300614
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9643219057903502
# epoch: 99
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9299545963591056
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9534307214448051
# epoch: 100
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9247792719180983
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9597649722317836
# epoch: 101
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9266939894535058
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9526330506145112
# epoch: 102
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9230829429663515
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9474221633371431
# epoch: 103
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9254186731029085
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9530872559318502
# epoch: 104
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9242471060939232
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9523783138296759
# epoch: 105
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9248405790190195
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9640934044128433
# epoch: 106
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9234692161933405
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9509865981429005
# epoch: 107
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9241766575297495
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9458982120736076
# epoch: 108
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9237523364507539
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9566870258929537
# epoch: 109
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9223784016694552
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9493819746923285
# epoch: 110
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.922838035269233
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9509564854798429
# epoch: 111
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9271692663442065
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9473549971604286
# epoch: 112
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9219327116028412
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9486307080865944
# epoch: 113
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9212772043987413
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9519900580960633
# epoch: 114
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9227019427863334
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9497035788136452
# epoch: 115
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9222686597396723
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9464481501732733
# epoch: 116
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.92178099016765
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9450015715182267
# epoch: 117
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9182482109694031
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9447097784688153
# epoch: 118
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9196361167718634
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.948306030442096
# epoch: 119
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9207133276290165
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9473201056366813
# epoch: 120
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9204715991332094
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9493403680410114
# epoch: 121
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9190096540191056
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9445365904484094
# epoch: 122
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9188600557734278
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9517140526880276
# epoch: 123
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9199978211648057
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9481711364127164
# epoch: 124
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9197179915579539
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9499246084118659
# epoch: 125
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9190620067512848
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9553858177600785
# epoch: 126
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9190794278739806
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9405471186830774
# epoch: 127
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9183481308161001
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9428486265829841
# epoch: 128
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9169322851866925
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9525141387848446
# epoch: 129
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9189463453083593
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9490891850128738
# epoch: 130
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9196284221769959
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9443813780956161
# epoch: 131
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9162255550751092
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9480479161265138
# epoch: 132
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9159713190953829
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9534202642722592
# epoch: 133
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9178894055960573
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9525140345726867
# epoch: 134
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9155526945346025
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9532027538374431
# epoch: 135
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9179458717429293
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9474196098133727
# epoch: 136
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9146676373830768
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9415085694658116
# epoch: 137
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9142068399612563
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9625068378201762
# epoch: 138
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9170025032642142
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9425846478394263
# epoch: 139
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9183221510934176
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.941302751465884
# epoch: 140
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.916685270761775
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.943787047351111
# epoch: 141
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9130988485875853
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9478191852777014
# epoch: 142
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9148651265816835
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.948330336259882
# epoch: 143
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9152758264616413
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.945378141704117
# epoch: 144
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9160202013452784
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9472490724638553
# epoch: 145
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9112382761445311
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9519568200252456
# epoch: 146
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9172809485972647
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9455991200144194
# epoch: 147
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9151469603840625
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9704919013908392
# epoch: 148
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9133133075875189
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.945930156053513
# epoch: 149
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.9122794311278893
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9474493913950345
# epoch: 150
# Training starts on device Quadro RTX 8000, number of samples 61
# train loss: 0.91293835560477
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9497171177582466

# %%
import matplotlib.pyplot as plt

plt.plot(train_loss[1:], "b", label="training loss")
plt.plot(test_loss[1:], "r", label="test loss")

plt.legend();

# %%
b_x, b_y, product_reshape, prediction_view, b_grad_view = plot_model_skew(cnn_submeso, criterion, loader_test, optimizer,len(torch_dataset_test))
# Out:
# Training starts on device Quadro RTX 8000, number of samples 7
# validation loss: 0.9497171177582465

# %%
from scipy import stats
corr_pred_ub = stats.pearsonr(product_reshape.detach().cpu().numpy()[:,0,:,:].flatten(), b_y[:,0,:,:].flatten())
corr_pred_vb = stats.pearsonr(product_reshape.detach().cpu().numpy()[:,1,:,:].flatten(), b_y[:,1,:,:].flatten())
corr_pred_wb = stats.pearsonr(product_reshape.detach().cpu().numpy()[:,2,:,:].flatten(), b_y[:,2,:,:].flatten())

print("correlation between prediction and target,  u'b':",corr_pred_ub )
print("correlation between prediction and target,  v'b':",corr_pred_vb )
print("correlation between prediction and target,  w'b':",corr_pred_wb )
# Out:
# correlation between prediction and target,  u'b': (0.2644677078206175, 0.0)
# correlation between prediction and target,  v'b': (0.20859278023848218, 3.0308690275697104e-202)
# correlation between prediction and target,  w'b': (0.37201870831279943, 0.0)

# %%
# visualize
it =18

fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(8, 4))
fig.tight_layout() # Or equivalently,  "plt.tight_layout()"

plt.subplot(231)
plt.pcolor(product_reshape.detach().cpu().numpy()[it,0,:,:],cmap='viridis',vmin=-1,vmax =1)
plt.title('ub prediction')
plt.colorbar()

plt.subplot(234)
plt.pcolor(b_y[it,0,:,:],cmap='viridis',vmin=-1,vmax =1)
plt.title('ub target')
plt.colorbar()

plt.subplot(232)
plt.pcolor(product_reshape.detach().cpu().numpy()[it,1,:,:],cmap='viridis',vmin=-1,vmax =1)
plt.title('vb prediction')
plt.colorbar()

plt.subplot(235)
plt.pcolor(b_y[it,1,:,:],cmap='viridis',vmin=-1,vmax =1)
plt.title('vb target')
plt.colorbar()

plt.subplot(233)
plt.pcolor(product_reshape.detach().cpu().numpy()[it,2,:,:],cmap='viridis',vmin=-1,vmax =1)
plt.title('wb prediction')
plt.colorbar()

plt.subplot(236)
plt.pcolor(b_y[it,2,:,:],cmap='viridis',vmin=-1,vmax =1)
plt.title('wb target')
plt.colorbar()

# %%
_=plt.hist(b_y.detach().cpu().numpy().flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="target")
_=plt.hist(product_reshape.detach().cpu().numpy().flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="prediction")

plt.xlim([-3,3])
plt.legend()
