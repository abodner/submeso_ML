# %%
import torch
import torch.nn.functional as F
import torch.utils.data as Data
import torchvision
from torch import nn, optim
from torch.autograd import Variable
import numpy as np
import os
import glob
import xarray as xr
from sklearn import preprocessing
import netCDF4 as nc
import matplotlib.pyplot as plt



np.random.seed(14)  # For reproducibility
torch.manual_seed(14)  # For reproducibility

# %% [markdown]
# # Dataloader

# %% [markdown]
# ### Create input and output channels

# %%
# function that splits datasets along the spacial axes and concats them back into single array under time

def normalize(data):
    #normalized_data =  (data - data.mean(skipna=True).values)/data.std(skipna=True).values
    normalized_data = (data - np.mean(data))/np.std(data)
    return normalized_data


def load_norm_data(var_name_string):
    PATH_LIST = glob.glob(BASE+'*/preprocessed_data/'+var_name_string+'.nc') 
    data_app = normalize(xr.open_dataarray(PATH_LIST[0]).to_numpy()[:,4:-4,4:-4])
    for i_file in np.arange(1,len(PATH_LIST)):
        PATH = PATH_LIST[i_file]
        data = xr.open_dataarray(PATH).to_numpy()[:,4:-4,4:-4]
        data_norm = normalize(data)
        data_app = np.concatenate((data_app,data_norm),axis=0)
    return data_app

# depth of CNN * (kernel_num-1)/2
#def load_norm_data_out(var_name_string): #with cropping for output
#    PATH_LIST = glob.glob(BASE+'*/preprocessed_data/'+var_name_string+'.nc') 
#    data_app = normalize(xr.open_dataarray(PATH_LIST[0]).to_numpy()[:,14:-14,14:-14])
#    for i_file in np.arange(1,len(PATH_LIST)):
#        PATH = PATH_LIST[i_file]
#        data = xr.open_dataarray(PATH).to_numpy()[:,14:-14,14:-14]
#        data_norm = normalize(data)
#        data_app = np.concatenate((data_app,data_norm),axis=0)
#    return data_app


def split_data(data):
    data_split_halfs = np.concatenate((np.split(data,2,axis=1)[0],np.split(data,2,axis=1)[1]),0)
    data_split_quarters = np.concatenate((np.split(data_split_halfs,2,axis=2)[0],np.split(data_split_halfs,2,axis=2)[1]),0)
    return data_split_quarters



def load_split_norm_data(var_name_string):
    loaded_data = load_norm_data(var_name_string)
    splitted_data = split_data(loaded_data)
    return splitted_data
    
    
def load_split_norm_data_out(var_name_string):
    loaded_data = load_norm_data(var_name_string)
    splitted_data = split_data(loaded_data)
    cropped_output = splitted_data[:,7:-7,7:-7] # for a kernel of size 3 with 5 conv layers
    return cropped_output

# %%
# load preprocessed data, convert to numpy and stack channels

BASE = '/scratch/ab10313/submeso_ML_data/'
FULL_PATH_PP = glob.glob(BASE+'*/preprocessed_data/')

# X INPUT
ds_Bm = load_split_norm_data('Bm_MLD_lowres')
ds_Um = load_split_norm_data('Um_MLD_lowres')
ds_Vm = load_split_norm_data('Vm_MLD_lowres')
ds_Wm = load_split_norm_data('Wm_MLD_lowres')


X_input = np.stack([ds_Bm,ds_Um,ds_Vm,ds_Wm],axis=1)
print('X input shape:')
print( X_input.shape)
print('')


# Y OUTPUT
ds_UsBs = load_split_norm_data_out('UsBs_MLD_lowres')
ds_VsBs = load_split_norm_data_out('VsBs_MLD_lowres')
ds_WsBs = load_split_norm_data_out('WsBs_MLD_lowres')

Y_output = np.stack([ds_UsBs,ds_VsBs,ds_WsBs],axis=1)
print('Y output shape:')
print(Y_output.shape)
print('')


# GRAD B
ds_Bm_x = load_split_norm_data_out('Bm_x_MLD_lowres')
ds_Bm_y = load_split_norm_data_out('Bm_y_MLD_lowres')
ds_Bm_z = load_split_norm_data_out('Bm_z_MLD_lowres')

grad_b = np.stack([ds_Bm_x,ds_Bm_y,ds_Bm_z],axis=1)
print('grad b shape:')
print( grad_b.shape)
# Out:
# X input shape:
# (6880, 4, 16, 16)
#
# Y output shape:
# (6880, 3, 2, 2)
#
# grad b shape:
# (6880, 3, 2, 2)

# %% [markdown]
# ### randomly generate train, test and validation sets

# %%
# randomnly generate train, test and validation time indecies 
import random
time_ind = X_input.shape[0]
rand_ind = np.arange(time_ind)
rand_seed = 14
random.Random(rand_seed).shuffle(rand_ind)
train_percent = 0.8
test_percent = 0.1 
print(f"Dataset: train {np.round(train_percent*100)}%, test {np.round(test_percent*100)}%, val {np.round((1-train_percent-test_percent)*100)}%")
train_ind, test_ind, val_ind =  rand_ind[:round(train_percent*time_ind)], rand_ind[round(train_percent*time_ind):round((train_percent+test_percent)*time_ind)], rand_ind[round((train_percent+test_percent)*time_ind):]                                                                        

# check no overlapping indecies
if np.intersect1d(train_ind, test_ind).any() or np.intersect1d(train_ind, val_ind).any() or np.intersect1d(val_ind, test_ind).any():
    print('overlapping indecies')
else:
    print ('no overlapping indecies')
# Out:
# Dataset: train 80.0%, test 10.0%, val 10.0%
# no overlapping indecies

# %% [markdown]
# ### defined train, test and val dataloaders

# %%
# Define X,Y pairs (state, subgrid fluxes) for local network.local_torch_dataset = Data.TensorDataset(
BATCH_SIZE = 32  # Number of sample in each batch


###### training dataset #######
torch_dataset_train = Data.TensorDataset(
    torch.from_numpy(X_input[train_ind]).double(),
    torch.from_numpy(Y_output[train_ind]).double(),
    torch.from_numpy(grad_b[train_ind]).double(),
)

loader_train = Data.DataLoader(
    dataset=torch_dataset_train, batch_size=BATCH_SIZE, shuffle=True
)
print('TRAIN')
print('X input shape:')
print( X_input[train_ind].shape)
print('Y output shape:')
print( Y_output[train_ind].shape)
print('grad b shape:')
print( grad_b[train_ind].shape)
print('')

###### test dataset #######
torch_dataset_test = Data.TensorDataset(
    torch.from_numpy(X_input[test_ind]).double(),
    torch.from_numpy(Y_output[test_ind]).double(),
    torch.from_numpy(grad_b[test_ind]).double(),
    
)

loader_test = Data.DataLoader(
    dataset=torch_dataset_test, batch_size=BATCH_SIZE, shuffle=True
)

print('TEST')
print('X input shape:')
print( X_input[test_ind].shape)
print('Y output shape:')
print( Y_output[test_ind].shape)
print('grad b shape:')
print( grad_b[test_ind].shape)
print('')

###### validation dataset #######
torch_dataset_val = Data.TensorDataset(
    torch.from_numpy(X_input[val_ind]).double(),
    torch.from_numpy(Y_output[val_ind]).double(),
    torch.from_numpy(grad_b[val_ind]).double(),
)

BATCH_SIZE_TEST = len(torch_dataset_test)

loader_val = Data.DataLoader(
    dataset=torch_dataset_val, batch_size=BATCH_SIZE_TEST, shuffle=True
)

print('VAL')
print('X input shape:')
print( X_input[val_ind].shape)
print('Y output shape:')
print( Y_output[val_ind].shape)
print('grad b shape:')
print( grad_b[val_ind].shape)
print('')
# Out:
# TRAIN
# X input shape:
# (5504, 4, 16, 16)
# Y output shape:
# (5504, 3, 2, 2)
# grad b shape:
# (5504, 3, 2, 2)
#
# TEST
# X input shape:
# (688, 4, 16, 16)
# Y output shape:
# (688, 3, 2, 2)
# grad b shape:
# (688, 3, 2, 2)
#
# VAL
# X input shape:
# (688, 4, 16, 16)
# Y output shape:
# (688, 3, 2, 2)
# grad b shape:
# (688, 3, 2, 2)

# %% [markdown]
# ## CNN - skew fluxes 9 output channels represeting 3X3 J matrix

# %%
# define network structure in pytorch
import torch.nn.functional as FF

class CNN_direct(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(4, 128, 3)  # 4 inputs, 64 neurons for first hidden layer
        self.dropout1 = nn.Dropout(0.25)
        self.conv1_bn=nn.BatchNorm2d(128)
        self.conv2 = nn.Conv2d(128, 96, 3)  # 64 inputs, 32 neurons for first hidden layer
        self.dropout2 = nn.Dropout(0.25)
        self.conv2_bn=nn.BatchNorm2d(96)
        self.conv3 = nn.Conv2d(96, 64, 3)  # 32 inputs, 16 neurons for first hidden layer
        self.dropout3 = nn.Dropout(0.25)
        self.conv3_bn=nn.BatchNorm2d(64)  
        self.conv4 = nn.Conv2d(64, 32, 3)  # 16 inputs, 3 neurons for first hidden layer
        self.dropout4 = nn.Dropout(0.25)
        self.conv4_bn=nn.BatchNorm2d(32) 
        self.conv5 = nn.Conv2d(32,24, 3)  # 32 inputs, 24 neurons for first hidden layer
        self.dropout5 = nn.Dropout(0.25)
        self.conv5_bn=nn.BatchNorm2d(24) # 9 outputs
        self.conv6 = nn.Conv2d(24, 16, 3)  # 32 inputs, 24 neurons for first hidden layer
        self.dropout6 = nn.Dropout(0.25)
        self.conv6_bn=nn.BatchNorm2d(16) # 9 outputs
        self.conv7 = nn.Conv2d(16, 9, 3)  # 32 inputs, 24 neurons for first hidden layer
        self.dropout7 = nn.Dropout(0.25)
        self.conv7_bn=nn.BatchNorm2d(9) # 9 outputs

    def forward(self, x):
        x = self.conv1(x)
        x = self.dropout1(x)
        x = F.relu(self.conv1_bn(x))
        x = self.conv2(x)
        x = self.dropout2(x)
        x = F.relu(self.conv2_bn(x))
        x = self.conv3(x)
        x = self.dropout3(x)
        x = F.relu(self.conv3_bn(x))
        x = self.conv4(x)
        x = self.dropout4(x)
        x = F.relu(self.conv4_bn(x))
        x = self.conv5(x)
        x = self.dropout5(x)
        x = F.relu(self.conv5_bn(x))
        x = self.conv6(x)
        x = self.dropout6(x)
        x = F.relu(self.conv6_bn(x))
        x = self.conv7(x)
        x = self.dropout7(x)
        x = self.conv7_bn(x)
        return x
 
    
# define network structure in pytorch
import torch.nn.functional as FF

#class CNN_direct(nn.Module):
#    def __init__(self):
#        super().__init__()
#        self.conv1 = nn.Conv2d(4, 64, 5,padding='same')  # 4 inputs, 128 neurons for first hidden layer
#        self.conv2 = nn.Conv2d(64, 32, 5,padding='same')  # 64 inputs, 32 neurons for first hidden layer
#        self.conv3 = nn.Conv2d(32, 3, 5,padding='same')  # 32 inputs, 24 neurons for first hidden layer

#    def forward(self, x):
#        x = FF.relu(self.conv1(x))
#        x = FF.relu(self.conv2(x))
#        x = self.conv3(x)
#        return x

# %% [markdown]
# ## Train and test model: direct fluxes

# %%
# train network 
def train_model_direct(net, criterion, trainloader, optimizer, len_train_dataset, text="train"):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    net.to(device)
    device_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else "cpu"
    print(f"Training starts on device {device_name}, number of samples {len(trainloader)}")
    
    net.train()
    train_loss = 0
    for step, (batch_x, batch_y, batch_g) in enumerate(trainloader):  # for each training step
        b_x = Variable(batch_x)  # Inputs
        b_y = Variable(batch_y)  # outputs
        b_grad = Variable(batch_g) # grad b
        prediction = net(b_x.to(device))
            
        prediction_reshape = torch.reshape(prediction, (prediction.shape[0],prediction.shape[2],prediction.shape[3],3, 3))
        grad_b_reshape = torch.reshape(b_grad, (b_grad.shape[0],b_grad.shape[2],b_grad.shape[3],3,1)).to(device)
            
        b_grad_view = grad_b_reshape.view(-1,3,1)
        prediction_view = prediction_reshape.view(-1,3,3)
            
        #print(prediction_reshape.shape)
        #print(grad_b_reshape.shape)
        
        #b_y_reshape = torch.reshape(b_y, (3, b_y.shape[0],b_y.shape[2],b_y.shape[3]))
        product = torch.bmm(prediction_view,b_grad_view)
        #print(product.shape)
        product_reshape = torch.reshape(product, (b_grad.shape[0],b_grad.shape[1],b_grad.shape[2],b_grad.shape[3])).to(device)
        #print(product_reshape.shape)
        #print(b_y.shape)
        
        
        # Calculating loss to find J which is the prediction
        loss = criterion(product_reshape, b_y.to(device)) 
        optimizer.zero_grad()  # clear gradients for next train
        loss.backward()  # backpropagation, compute gradients
        optimizer.step()  # apply gradients to update weights
        nb = b_y.shape[0]
        train_loss = train_loss + nb * loss.detach().cpu().numpy()  # Keep track of the loss
    train_loss /= len_train_dataset # dividing by the number of batches
    print(text + " loss:", train_loss)
    return train_loss


def test_model_direct(net, criterion, testloader, optimizer,len_test_dataset, text="validation"):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    net.to(device)
    device_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else "cpu"
    print(f"Training starts on device {device_name}, number of samples {len(testloader)}")
    
    net.eval()  # Evaluation mode (important when having dropout layers)
    test_loss = 0
    with torch.no_grad():
        for step, (batch_x, batch_y, batch_g) in enumerate(
            testloader
        ):  # for each training step
            b_x = Variable(batch_x)  # Inputs
            b_y = Variable(batch_y)  # outputs
            b_grad = Variable(batch_g) # grad b
            prediction = net(b_x.to(device))
            prediction_reshape = torch.reshape(prediction, (prediction.shape[0],prediction.shape[2],prediction.shape[3],3, 3))
            grad_b_reshape = torch.reshape(b_grad, (b_grad.shape[0],b_grad.shape[2],b_grad.shape[3],3,1)).to(device)
            
            b_grad_view = grad_b_reshape.view(-1,3,1)
            prediction_view = prediction_reshape.view(-1,3,3)
            
        #print(prediction_reshape.shape)
        #print(grad_b_reshape.shape)
        
        #b_y_reshape = torch.reshape(b_y, (3, b_y.shape[0],b_y.shape[2],b_y.shape[3]))
            product = torch.bmm(prediction_view,b_grad_view)
        #print(product.shape)
            product_reshape = torch.reshape(product, (b_grad.shape[0],b_grad.shape[1],b_grad.shape[2],b_grad.shape[3])).to(device)
        #print(product_reshape.shape)
        #print(b_y.shape)
        
        
        # Calculating loss to find J which is the prediction
            loss = criterion(product_reshape, b_y.to(device)) 
            nb = b_y.shape[0]
            test_loss = test_loss + nb * loss.detach().cpu().numpy()  # Keep track of the loss
        test_loss /= len_test_dataset  # dividing by the number of batches
        #         print(len(trainloader))
        print(text + " loss:", test_loss)
    return test_loss



def plot_model_skew(net, criterion, testloader, optimizer, text="validation"):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    net.to(device)
    device_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else "cpu"
    print(f"Training starts on device {device_name}, number of samples {len(testloader)}")
    
    net.eval()  # Evaluation mode (important when having dropout layers)
    test_loss = 0
    with torch.no_grad():
        for step, (batch_x, batch_y,batch_g) in enumerate(
            testloader
        ):  # for each training step
            b_x = Variable(batch_x)  # Inputs
            b_y = Variable(batch_y)  # outputs
            b_grad = Variable(batch_g) # grad b
            prediction = net(b_x.to(device))
            prediction_reshape = torch.reshape(prediction, (prediction.shape[0],prediction.shape[2],prediction.shape[3],3, 3))
            grad_b_reshape = torch.reshape(b_grad, (b_grad.shape[0],b_grad.shape[2],b_grad.shape[3],3,1)).to(device)
            
            b_grad_view = grad_b_reshape.view(-1,3,1)
            prediction_view = prediction_reshape.view(-1,3,3)
            
        #print(prediction_reshape.shape)
        #print(grad_b_reshape.shape)
        
        #b_y_reshape = torch.reshape(b_y, (3, b_y.shape[0],b_y.shape[2],b_y.shape[3]))
            product = torch.bmm(prediction_view,b_grad_view)
        #print(product.shape)
            product_reshape = torch.reshape(product, (b_grad.shape[0],b_grad.shape[1],b_grad.shape[2],b_grad.shape[3])).to(device)
        #print(product_reshape.shape)
        #print(b_y.shape)
        
        
        # Calculating loss to find J which is the prediction
            loss = criterion(product_reshape, b_y.to(device)) 
            
            
            nb = b_y.shape[0]
            test_loss = test_loss + nb * loss.detach().cpu().numpy()  # Keep track of the loss
        test_loss /= len(testloader)  # dividing by the number of batches
        #         print(len(trainloader))
        print(text + " loss:", test_loss)
    return b_x, b_y, product_reshape, prediction_view, b_grad_view


criterion = torch.nn.MSELoss()  # MSE loss function

# %% [markdown]
# ## train CNN!

# %%
torch.manual_seed(14)  # For reproducibility
cnn_submeso = CNN_direct().double()

n_epochs = 200  # Number of epocs could be increased
optimizer = optim.Adam(cnn_submeso.parameters(), lr=0.03)
validation_loss = list()
train_loss = list()
for epoch in range(1, n_epochs + 1):
    print("epoch:", epoch)
    train_loss.append(train_model_direct(cnn_submeso, criterion, loader_train, optimizer,len(torch_dataset_train)))
    validation_loss.append(test_model_direct(cnn_submeso, criterion, loader_val, optimizer,len(torch_dataset_val)))
# Out:
# epoch: 1
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.8383527007731721
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.46315859572376544
# epoch: 2
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5700305065145151
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.46451204672450364
# epoch: 3
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5719299311654858
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4626626111120119
# epoch: 4
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5706844530731437
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4670704816726008
# epoch: 5
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5716357771231763
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.46522893796749615
# epoch: 6
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5735423248950499
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.46298973051237857
# epoch: 7
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5730102123947943
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.47202568436441034
# epoch: 8
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5778003978466247
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.46327494404168046
# epoch: 9
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5714425630506464
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4700539068247231
# epoch: 10
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5745369789148264
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4629355297202731
# epoch: 11
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.578956326059781
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.47056667265971225
# epoch: 12
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5761729428794495
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.46755688807599466
# epoch: 13
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5706714103623217
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4796705285318931
# epoch: 14
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5739898453238744
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4670568578248226
# epoch: 15
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5734767776260766
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4639751001198297
# epoch: 16
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5883880136175016
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4650569438833524
# epoch: 17
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5707791820760632
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4714338111584457
# epoch: 18
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5765706210464518
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4629095584604323
# epoch: 19
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5734617150018697
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4732169339237298
# epoch: 20
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5726774860221474
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.46765423208459317
# epoch: 21
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5714800440099131
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.463773211574309
# epoch: 22
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.566560509063644
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.7236152803464634
# epoch: 23
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5838930905125419
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4618633893946641
# epoch: 24
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5694399492394765
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.46550704210041316
# epoch: 25
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5690937194142519
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.45838965939348264
# epoch: 26
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5701774038310702
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4639806032751927
# epoch: 27
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5760538172145507
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4847255815088465
# epoch: 28
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5748273911525581
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.463997720904066
# epoch: 29
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.571681271377046
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.46272621107611195
# epoch: 30
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5729445266382893
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.46475026476615167
# epoch: 31
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5792952485122402
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4869729347286978
# epoch: 32
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5701366825756717
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4741126689521631
# epoch: 33
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5688330039541497
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4577706164400683
# epoch: 34
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5764377727039048
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4621580988473536
# epoch: 35
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5652319639187737
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4636324351537993
# epoch: 36
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5676933717769779
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4668856251885127
# epoch: 37
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5674066159670418
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.46433177564518585
# epoch: 38
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5620899000382872
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.45955946762729033
# epoch: 39
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5627913606593146
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.45069855295264105
# epoch: 40
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5617456394201032
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4531935751375564
# epoch: 41
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.56411327470315
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.45348987223022064
# epoch: 42
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5658120479484592
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.45906975864628174
# epoch: 43
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5650080474258353
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4594732815157206
# epoch: 44
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.566776451678501
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.47029720511762907
# epoch: 45
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5690265613743146
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4531567356332479
# epoch: 46
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5631804456158861
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.45289796851723846
# epoch: 47
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5621615650853538
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4543174386704795
# epoch: 48
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5619520030499146
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.45869718465511955
# epoch: 49
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5644008688640246
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4627903859883226
# epoch: 50
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5694765249771896
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4664411395285668
# epoch: 51
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5665078647359286
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4519308365821618
# epoch: 52
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5679881915778459
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4537848213953177
# epoch: 53
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5673709553690004
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4610327352218848
# epoch: 54
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5684115237515527
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4639727772445838
# epoch: 55
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5700967628089174
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.45044367648121914
# epoch: 56
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5678068071383511
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.45358756126690664
# epoch: 57
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5645912129326115
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.45694539154866143
# epoch: 58
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5743908504952469
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.45893431739096896
# epoch: 59
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5659069953791774
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.45423013059626177
# epoch: 60
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5663764641489499
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4578352533769321
# epoch: 61
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5658682060219711
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.45104286360204
# epoch: 62
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5700527429213956
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4606890663282699
# epoch: 63
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.570143456356078
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4547980002786689
# epoch: 64
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5666095616362053
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.45122576446004437
# epoch: 65
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5637879145038693
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.45246629890596124
# epoch: 66
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5609727931234534
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4544965585000888
# epoch: 67
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5639465199575845
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4710098278444277
# epoch: 68
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5679092769417704
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.45844151635260944
# epoch: 69
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5617783081850409
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.46196177410934103
# epoch: 70
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5659433336587297
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.45055819183354495
# epoch: 71
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5671213074835446
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.45020440587553323
# epoch: 72
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5634138717069963
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4573461519103685
# epoch: 73
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5631590113632161
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4532703219560012
# epoch: 74
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5632913227774847
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4668744883475335
# epoch: 75
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5650304847799932
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.45758646999334807
# epoch: 76
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5647619765184136
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.45771567235587
# epoch: 77
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5609700561471924
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.47811656381734496
# epoch: 78
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5669528833543653
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.44643659384081397
# epoch: 79
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5653340969360897
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4548832474558777
# epoch: 80
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5680415515635531
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.45528661754550676
# epoch: 81
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.568689463764135
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4573433513873768
# epoch: 82
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5615766619843803
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.44692209726086657
# epoch: 83
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5642726322963606
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4491159617399127
# epoch: 84
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5647152698742821
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4446516561233896
# epoch: 85
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5612473990779713
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4528450617262123
# epoch: 86
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5664506338666512
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4522341778943386
# epoch: 87
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.565026852081149
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.45516770959853997
# epoch: 88
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5625996788574342
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4535855344351021
# epoch: 89
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5614008315645588
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4537252986995879
# epoch: 90
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5616755185700676
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4510696003860342
# epoch: 91
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.564746519782858
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.45236805388857837
# epoch: 92
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5636384634334269
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4441347544914527
# epoch: 93
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5626247458378646
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.44754486495082363
# epoch: 94
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5602838058529613
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.44659363101520594
# epoch: 95
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5622897010492192
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4623565646985501
# epoch: 96
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.568444131672397
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.45887871151859394
# epoch: 97
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.566818161965896
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.450163898437989
# epoch: 98
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5602396823161164
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4430436469599742
# epoch: 99
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5608786222937427
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4477817480827692
# epoch: 100
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5605112938955449
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.44579979999075814
# epoch: 101
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5581376289442832
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4466460565381514
# epoch: 102
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5603213053296754
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.45363524117455695
# epoch: 103
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.558204420262043
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4504193970540695
# epoch: 104
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5583587864601607
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.45087212290320894
# epoch: 105
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5655818239671597
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4499850562462033
# epoch: 106
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5593127845602525
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4480326097293688
# epoch: 107
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5610006365467375
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.44347791760650707
# epoch: 108
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5604147198006851
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4409441770033131
# epoch: 109
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5634839447520527
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4473291345632618
# epoch: 110
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5564496077281209
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4464474108983748
# epoch: 111
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.557830888565159
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.45033831940078034
# epoch: 112
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.555590874238176
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.45016150795120863
# epoch: 113
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5590239194087586
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.44840741017721103
# epoch: 114
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5584580098566474
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.44747538355996
# epoch: 115
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5581568176378789
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.45491696933387143
# epoch: 116
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5572016519273858
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4445714109895491
# epoch: 117
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.558771566692528
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4539317100151758
# epoch: 118
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5622221673794002
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.45191895138470456
# epoch: 119
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5675799897296466
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4500353444603985
# epoch: 120
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5584219847427229
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.44991761874721825
# epoch: 121
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5536992380278811
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4432494084446095
# epoch: 122
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5571912660095926
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4534451572020975
# epoch: 123
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5661324076426232
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4460158380237542
# epoch: 124
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5603112144213945
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4432915870462564
# epoch: 125
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5539357606302726
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.44309973248051854
# epoch: 126
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5575357442909606
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.44446222379907296
# epoch: 127
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5538705766465901
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.45745170474831964
# epoch: 128
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5529332958500338
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4451296434420912
# epoch: 129
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5802465199408894
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4487432980930918
# epoch: 130
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5568538234593511
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.44237051023498525
# epoch: 131
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5521452813649055
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.44482449879808766
# epoch: 132
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.555365249046202
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.43921607504408533
# epoch: 133
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5513857799327408
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4429876648493917
# epoch: 134
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5519281553012634
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.43940781649158855
# epoch: 135
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5511169224925042
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4515407375780628
# epoch: 136
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5482300983936912
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.44932198649300187
# epoch: 137
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5394310129840332
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4437516414146964
# epoch: 138
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5430845914602993
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.44494252646154586
# epoch: 139
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5519090940759669
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4433985602187907
# epoch: 140
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5458297990697947
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.44780420681883476
# epoch: 141
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5528147514756138
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4377882171533971
# epoch: 142
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5482487149013896
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4418998777202791
# epoch: 143
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5500305756632927
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4484111618562237
# epoch: 144
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5474587455371909
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.439758234746985
# epoch: 145
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.545249597966593
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4434954461708938
# epoch: 146
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5464355300529308
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.45232614048953323
# epoch: 147
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.549020424424446
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.5750552013203502
# epoch: 148
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5404119947662088
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.44152098565473535
# epoch: 149
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5402054731731265
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4412584326528524
# epoch: 150
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5443090434812953
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.44721643016773616
# epoch: 151
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5460903817290511
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4448976093905317
# epoch: 152
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5495911054551177
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.44841779259153025
# epoch: 153
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5404559229701215
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.45492955985572536
# epoch: 154
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5440277901200156
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.46053470417285886
# epoch: 155
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5527391978519727
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.44219124036656643
# epoch: 156
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5400659872797428
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.44086257663675926
# epoch: 157
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5478482379646619
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4472084482546863
# epoch: 158
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5406274894013872
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4596080064904895
# epoch: 159
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.566087298114275
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.44283197456271034
# epoch: 160
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5420336608151021
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4425366724791396
# epoch: 161
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5429435005729323
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4404275345268656
# epoch: 162
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5405191736690689
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.43587150560627635
# epoch: 163
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5453533970513703
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4638877745282122
# epoch: 164
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.535668664440197
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4350455933180174
# epoch: 165
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5396552333540469
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.44129479291575674
# epoch: 166
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5349777155166606
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.43703043610129205
# epoch: 167
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5523499453078276
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4369019380797244
# epoch: 168
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5369512741216987
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.46014512379427824
# epoch: 169
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5408456941903937
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.45084722603639954
# epoch: 170
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5486831075777489
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.44749978585375005
# epoch: 171
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5354294811916278
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.43885044130186407
# epoch: 172
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5296948691624409
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4419061182772726
# epoch: 173
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5429221400232859
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.48019872041559486
# epoch: 174
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5407903733244883
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4346407655160171
# epoch: 175
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5386143360524526
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.439668001852538
# epoch: 176
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5241673235972496
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4822681418975954
# epoch: 177
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5515766858559051
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4509345248413865
# epoch: 178
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5370936091174654
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.44928499994225835
# epoch: 179
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5373263163994602
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4542849076555047
# epoch: 180
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.538672644828221
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.43797129470821444
# epoch: 181
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5410858120178483
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.44131621761949413
# epoch: 182
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5309834872053658
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4385829671486306
# epoch: 183
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5424834018377203
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4429571209639951
# epoch: 184
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5338140946345186
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.44108958081464494
# epoch: 185
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5288204355874637
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.43155955612863617
# epoch: 186
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5332221232960402
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4487700229407516
# epoch: 187
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5375856995950765
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4422860998959592
# epoch: 188
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5336659653926541
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.44190726352534476
# epoch: 189
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5261720752576016
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.45880582230290956
# epoch: 190
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5404695526628811
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4420073415669159
# epoch: 191
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5316312009993325
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.43063269643131313
# epoch: 192
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5421580590901443
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.43880368595308167
# epoch: 193
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5340499713431844
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4377823208094149
# epoch: 194
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5318988891861959
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4425804571927612
# epoch: 195
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.537347423404435
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.44242085057160946
# epoch: 196
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.526710096112827
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.5002901192396702
# epoch: 197
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5300584748639117
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4409496791890291
# epoch: 198
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5410103775011106
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.455975441833686
# epoch: 199
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.5322322195955856
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4392846350870132
# epoch: 200
# Training starts on device Quadro RTX 8000, number of samples 172
# train loss: 0.538748231720325
# Training starts on device Quadro RTX 8000, number of samples 1
# validation loss: 0.4312651411991965

# %%
import matplotlib.pyplot as plt

plt.plot(train_loss[1:], "b", label="training loss")
plt.plot(validation_loss[1:], "r", label="validation loss")

plt.legend();

# %%
b_x, b_y, product_reshape, prediction_view, b_grad_view = plot_model_skew(cnn_submeso, criterion, loader_test, optimizer)

#plt.pcolor(b_y[0,0,:,:])
#plt.colorbar()
# Out:
# Training starts on device Quadro RTX 8000, number of samples 22
# validation loss: 13.647949794885868

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
plt.pcolor(cnn_submeso(b_x.to(device)).detach().cpu().numpy()[0,0,:,:])
plt.colorbar()

# %%
plt.pcolor(b_y[0,0,:,:])
plt.colorbar()

# %%
from scipy import stats
corr_pred = stats.pearsonr(product_reshape.detach().cpu().numpy().flatten(), b_y.cpu().numpy().flatten().flatten())
#corr_pred = np.corrcoef(cnn_submeso(b_x.to(device)).detach().cpu().numpy().flatten(), b_y.flatten())
corr_pred
# Out:
# (0.09616066705999345, 0.18456912153769817)

# %%
_=plt.hist(b_y.detach().cpu().numpy().flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="target")
_=plt.hist(product_reshape.detach().cpu().numpy().flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="prediction")

plt.xlim([-3,3])
plt.legend()
