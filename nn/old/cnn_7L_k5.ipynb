# %%
import torch
import torch.nn.functional as F
import torch.utils.data as Data
import torchvision
from torch import nn, optim
from torch.autograd import Variable
import numpy as np
import os
import glob
import xarray as xr
from sklearn import preprocessing
import netCDF4 as nc
import matplotlib.pyplot as plt



np.random.seed(14)  # For reproducibility
torch.manual_seed(14)  # For reproducibility

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %% [markdown]
# # Dataloader

# %% [markdown]
# ### Create input and output channels

# %%
# load preprocessed data into input and output channels

BASE = '/scratch/ab10313/pleiades/'
PATH_NN = BASE+'NN_data/'

# X INPUT
grad_B = np.load(PATH_NN+'grad_B.npy')
HML = np.load(PATH_NN+'HML.npy')
TAU = np.load(PATH_NN+'TAU.npy')
U = np.load(PATH_NN+'U.npy')
V = np.load(PATH_NN+'V.npy')
Q = np.load(PATH_NN+'Q.npy')
HBL = np.load(PATH_NN+'HBL.npy')
FCOR = np.load(PATH_NN+'FCOR.npy')


X_input = np.stack([FCOR, grad_B, HML, TAU, U, V, Q, HBL],axis=1)
print('X input shape:')
print( X_input.shape)
print('')


# Y OUTPUT
WB_sg = np.load(PATH_NN+'WB_sg.npy')
              
Y_output = np.tile(WB_sg,(1,1,1,1)).reshape(WB_sg.shape[0],1,WB_sg.shape[1],WB_sg.shape[2]) 
print('Y output shape:')
print(Y_output.shape)
print('')

np.isnan(X_input).any()
np.isnan(Y_output).any()
# Out:
# X input shape:
# (8460, 8, 40, 40)
#
# Y output shape:
# (8460, 1, 40, 40)
# False

# %% [markdown]
# ### randomly generate train, test and validation sets

# %%
# TRAIN AND TEST ONLY
# randomnly generate train, test and validation time indecies 
import random
time_ind = X_input.shape[0]
rand_ind = np.arange(time_ind)
rand_seed = 14
random.Random(rand_seed).shuffle(rand_ind)
train_percent = 0.9
test_percent = 0.1 
print(f"Dataset: train {np.round(train_percent*100)}%, test {np.round(test_percent*100)}%")
train_ind, test_ind =  rand_ind[:round(train_percent*time_ind)], rand_ind[round((train_percent)*time_ind):]                                                                        

# check no overlapping indecies
if np.intersect1d(train_ind, test_ind).any():
    print('overlapping indecies')
else:
    print ('no overlapping indecies')
# Out:
# Dataset: train 90.0%, test 10.0%
# no overlapping indecies

# %% [markdown]
# ### defined train, test and val dataloaders

# %%
# Define X,Y pairs (state, subgrid fluxes) for local network.local_torch_dataset = Data.TensorDataset(
BATCH_SIZE = 64  # Number of sample in each batch


###### training dataset #######
torch_dataset_train = Data.TensorDataset(
    torch.from_numpy(X_input[train_ind]).double(),
    torch.from_numpy(Y_output[train_ind]).double(),
)

loader_train = Data.DataLoader(
    dataset=torch_dataset_train, batch_size=BATCH_SIZE, shuffle=True
)
print('TRAIN')
print('X input shape:')
print( X_input[train_ind].shape)
print('Y output shape:')
print( Y_output[train_ind].shape)
print('')

###### test dataset #######
torch_dataset_test = Data.TensorDataset(
    torch.from_numpy(X_input[test_ind]).double(),
    torch.from_numpy(Y_output[test_ind]).double(),    
)

BATCH_SIZE_TEST = len(torch_dataset_test)

loader_test = Data.DataLoader(
    dataset=torch_dataset_test, batch_size=BATCH_SIZE_TEST, shuffle=False
)

print('TEST')
print('X input shape:')
print( X_input[test_ind].shape)
print('Y output shape:')
print( Y_output[test_ind].shape)
print('')
# Out:
# TRAIN
# X input shape:
# (7614, 8, 40, 40)
# Y output shape:
# (7614, 1, 40, 40)
#
# TEST
# X input shape:
# (846, 8, 40, 40)
# Y output shape:
# (846, 1, 40, 40)

# %% [markdown]
# ## CNN - direct fluxes 3 output channels

# %%
# define network structure in pytorch
import torch.nn.functional as FF

class CNN_direct(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(8, 128, 5, padding='same', padding_mode='reflect')  # 7 inputs, 128 neurons for first hidden layer
        self.conv1_bn=nn.BatchNorm2d(128)
        self.conv2 = nn.Conv2d(128, 64, 5, padding='same', padding_mode='reflect')  # 128 inputs, 64 neurons for first hidden layer
        self.conv2_bn=nn.BatchNorm2d(64)
        self.conv3 = nn.Conv2d(64, 48, 5, padding='same', padding_mode='reflect')  # 64 inputs, 32 neurons for first hidden layer
        self.conv3_bn=nn.BatchNorm2d(48)  
        self.conv4 = nn.Conv2d(48, 32, 5, padding='same', padding_mode='reflect')  # 32 inputs, 16 neurons for first hidden layer
        self.conv4_bn=nn.BatchNorm2d(32) 
        self.conv5 = nn.Conv2d(32, 16, 5, padding='same', padding_mode='reflect')  # 64 inputs, 32 neurons for first hidden layer
        self.conv5_bn=nn.BatchNorm2d(16)  
        self.conv6 = nn.Conv2d(16, 8, 5, padding='same', padding_mode='reflect')  # 32 inputs, 16 neurons for first hidden layer
        self.conv6_bn=nn.BatchNorm2d(8) 
        self.conv7 = nn.Conv2d(8, 1, 5, padding='same', padding_mode='reflect')  # 16 inputs, 1 neurons for first hidden layer
        self.conv7_bn=nn.BatchNorm2d(1) 

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(self.conv1_bn(x))
        x = self.conv2(x)
        x = F.relu(self.conv2_bn(x))
        x = self.conv3(x)
        x = F.relu(self.conv3_bn(x))
        x = self.conv4(x)
        x = F.relu(self.conv4_bn(x))
        x = self.conv5(x)
        x = F.relu(self.conv5_bn(x))
        x = self.conv6(x)
        x = F.relu(self.conv6_bn(x))
        x = self.conv7(x)
        x = self.conv7_bn(x)
        return x

# %% [markdown]
# ## Train and test model: direct fluxes

# %%
# train network 
def train_model_direct(net, criterion, trainloader, optimizer, len_train_dataset, text="train"):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    net.to(device)
    device_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else "cpu"
    print(f"Training starts on device {device_name}, number of samples {len(trainloader)}")
    
    net.train()
    train_loss = 0
    for step, (batch_x, batch_y) in enumerate(trainloader):  # for each training step
        b_x = Variable(batch_x)  # Inputs
        b_y = Variable(batch_y)  # outputs
        prediction = net(b_x.to(device))
        loss = criterion(prediction, b_y.to(device))  # Calculating loss
        optimizer.zero_grad()  # clear gradients for next train
        loss.backward()  # backpropagation, compute gradients
        optimizer.step()  # apply gradients to update weights
        nb = b_y.shape[0]
        train_loss = train_loss + nb * loss.detach().cpu().numpy()  # Keep track of the loss
    train_loss /= len_train_dataset  # dividing by the number of batches
    print(text + " loss:", train_loss)
    return train_loss


def test_model_direct(net, criterion, testloader, optimizer,len_test_dataset, text="test"):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    net.to(device)
    device_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else "cpu"
    print(f"Training starts on device {device_name}, number of samples {len(testloader)}")
    
    net.eval()  # Evaluation mode (important when having dropout layers)
    test_loss = 0
    with torch.no_grad():
        for step, (batch_x, batch_y) in enumerate(
            testloader
        ):  # for each training step
            b_x = Variable(batch_x)  # Inputs
            b_y = Variable(batch_y)  # outputs
            prediction = net(b_x.to(device))
            loss = criterion(prediction, b_y.to(device))  # Calculating loss
            nb = b_y.shape[0]
            test_loss = test_loss + nb * loss.detach().cpu().numpy()  # Keep track of the loss
        test_loss /= len_test_dataset  # dividing by the number of batches
        #         print(len(trainloader))
        print(text + " loss:", test_loss)
    return test_loss



def plot_model_direct(net, criterion, testloader, optimizer, len_test_dataset, text="test"):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    net.to(device)
    device_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else "cpu"
    print(f"Training starts on device {device_name}, number of samples {len(testloader)}")
    
    net.eval()  # Evaluation mode (important when having dropout layers)
    test_loss = 0
    with torch.no_grad():
        for step, (batch_x, batch_y) in enumerate(
            testloader
        ):  # for each training step
            b_x = Variable(batch_x)  # Inputs
            b_y = Variable(batch_y)  # outputs
            prediction = net(b_x.to(device))
            loss = criterion(prediction, b_y.to(device))  # Calculating loss
            nb = b_y.shape[0]
            test_loss = test_loss + nb * loss.detach().cpu().numpy()  # Keep track of the loss
        test_loss /= len_test_dataset  # dividing by the number of batches
        #         print(len(trainloader))
        print(text + " loss:", test_loss)
    return b_x, b_y, prediction


criterion = torch.nn.MSELoss()  # MSE loss function

# %% [markdown]
# ## train CNN!

# %%
torch.manual_seed(14)  # For reproducibility
cnn_submeso = CNN_direct().double()

n_epochs = 100  # Number of epocs could be increased
optimizer = optim.Adam(cnn_submeso.parameters(), lr=0.1)
test_loss = list()
train_loss = list()
for epoch in range(1, n_epochs + 1):
    print("epoch:", epoch)
    train_loss.append(train_model_direct(cnn_submeso, criterion, loader_train, optimizer,len(torch_dataset_train)))
    test_loss.append(test_model_direct(cnn_submeso, criterion, loader_test, optimizer,len(torch_dataset_test)))

torch.save(cnn_submeso.state_dict(), PATH_NN+'cnn_7l_k5')
# Out:
# epoch: 1
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.9680636751544272
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.938334006123446
# epoch: 2
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.9086394485473333
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.9224859616677612
# epoch: 3
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.9035692832004897
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.9130023581732758
# epoch: 4
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.9042490641887636
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.9173551979490818
# epoch: 5
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.901220786135719
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.929400918491156
# epoch: 6
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.9011374806610697
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.9200902515999508
# epoch: 7
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.8997400108175454
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.9290775299120251
# epoch: 8
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.8915910336669675
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.9057891202550253
# epoch: 9
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.8836582569456256
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.9033731019492082
# epoch: 10
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.8739099766592109
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.9006951640497309
# epoch: 11
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.8721893839722368
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8854287286194927
# epoch: 12
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.8644723236780889
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8931154104709514
# epoch: 13
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.8550130450619668
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8821298606019127
# epoch: 14
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.8544638626204741
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.880297059922289
# epoch: 15
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.8447261825475357
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8633792064810659
# epoch: 16
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.8416969016433519
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8634077118751974
# epoch: 17
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.8396837002806481
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.9065495935502953
# epoch: 18
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.8339372197430082
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.9071067045465793
# epoch: 19
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.831825451798705
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8811493890815054
# epoch: 20
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.8297652593468093
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8509430382537189
# epoch: 21
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.82676002800179
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8540935941861166
# epoch: 22
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.8192869964293611
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8309402135992305
# epoch: 23
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.820557539449666
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8462868311801909
# epoch: 24
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.8176175553207808
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8617390138844399
# epoch: 25
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.8149106697122589
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.876069783677533
# epoch: 26
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.8145939717752041
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.821632649981056
# epoch: 27
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.8084416221562294
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8505075479099219
# epoch: 28
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.806956682832107
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8251689999669811
# epoch: 29
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.8062297905815751
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8246790354751693
# epoch: 30
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.8033547746569639
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8347698932822295
# epoch: 31
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7959152467347846
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8917147751218053
# epoch: 32
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7959086822819934
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8493580295990534
# epoch: 33
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7894473750224563
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.894917630610284
# epoch: 34
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7890285557688796
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8499567956567061
# epoch: 35
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7863294592633318
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.801524128661477
# epoch: 36
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7798083996992803
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8062381962683088
# epoch: 37
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7799447084588121
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8146539001927899
# epoch: 38
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7765990244521919
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.785904491198201
# epoch: 39
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7664979788431708
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.9510997185116378
# epoch: 40
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7749322283495864
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8906143572814084
# epoch: 41
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7593807922260758
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.823895002632998
# epoch: 42
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7541750926181972
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8179268031954148
# epoch: 43
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7587944241085463
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8720207673582849
# epoch: 44
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7507604246262368
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7969612523650975
# epoch: 45
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7406415504895251
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8126296676791398
# epoch: 46
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7410338893471735
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7698700393489313
# epoch: 47
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7352385710583675
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7592814005182205
# epoch: 48
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7325869158568091
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.9776633661312274
# epoch: 49
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7355535280920497
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7852949860639469
# epoch: 50
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7246398916441197
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7429047898703306
# epoch: 51
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7171722579018199
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8910605844668564
# epoch: 52
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7134239159081889
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.9843532909339127
# epoch: 53
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7044132258850937
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7294057554599626
# epoch: 54
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7017770540125843
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7467478309156601
# epoch: 55
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7041254034053093
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7546671652359341
# epoch: 56
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.7028133289771095
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7859864779026059
# epoch: 57
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6913185909342161
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7604299850073792
# epoch: 58
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.688258499647726
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7668999160662157
# epoch: 59
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6885645287412749
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7128238347470541
# epoch: 60
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6803788309891587
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7158238759987412
# epoch: 61
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6865527585418296
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7272677419366089
# epoch: 62
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6829100569081842
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.9043495258928284
# epoch: 63
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6732518681706148
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7346730393140068
# epoch: 64
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6716403245508444
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7344746261562083
# epoch: 65
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6630439239479279
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 1.0495992455785328
# epoch: 66
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.665598043997445
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7158286653073961
# epoch: 67
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6586637447487562
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 1.0511759442426942
# epoch: 68
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6567072533073051
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8869366433533538
# epoch: 69
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6612589686166335
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6783286234068866
# epoch: 70
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6540122691102356
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6821500460763116
# epoch: 71
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6496841743117412
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6905692484888323
# epoch: 72
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6451263182237472
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.991564789306259
# epoch: 73
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.642690543262985
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7383938184822109
# epoch: 74
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6386472607696724
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6630062650572435
# epoch: 75
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6399453007889468
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.750141705220258
# epoch: 76
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.635467356156182
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8854364076940338
# epoch: 77
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.638613826851383
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6938397745263404
# epoch: 78
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6297147398677341
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6871858116491699
# epoch: 79
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6282518982426679
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6426651098811641
# epoch: 80
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6221492630464914
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6381513069524832
# epoch: 81
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6227822840973367
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6657006363421789
# epoch: 82
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6289195497986718
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8192456105349182
# epoch: 83
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6175559130299527
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.650705727609354
# epoch: 84
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.614421066634176
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6702909067930604
# epoch: 85
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6136938787320261
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6425819039731095
# epoch: 86
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.614046187737198
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6536569196018773
# epoch: 87
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6132091294322045
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6270530782799104
# epoch: 88
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6074114147179107
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6605315680830369
# epoch: 89
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6074892864228113
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.650676487173575
# epoch: 90
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6036374088277673
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6711115551567329
# epoch: 91
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6009788757791209
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6360214185804041
# epoch: 92
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.5979775142589778
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6440848896541118
# epoch: 93
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.6051905764440967
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.62822036732264
# epoch: 94
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.5988229928678018
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6521360349325581
# epoch: 95
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.590091837279036
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6951542990333703
# epoch: 96
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.5931381357703686
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6496079776441793
# epoch: 97
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.5945408940716592
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6039935950766917
# epoch: 98
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.5984593319554907
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6383134934400284
# epoch: 99
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.5826970603448547
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6302062194248135
# epoch: 100
# Training starts on device Quadro RTX 8000, number of samples 119
# train loss: 0.5813129253966698
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.654552706619713
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /state/partition1/job-30387511/ipykernel_957056/1894220711.py in <module>
#      11     test_loss.append(test_model_direct(cnn_submeso, criterion, loader_test, optimizer,len(torch_dataset_test)))
#      12
# ---> 13 torch.save(model.state_dict(), PATH_NN+'cnn_7l_k5')
#
# NameError: name 'model' is not defined

# %%
torch.save(cnn_submeso, PATH_NN+'cnn_7l_k5')

# %%
import matplotlib.pyplot as plt

plt.plot(train_loss[1:], "b", linewidth=3,label="training loss")
plt.plot(test_loss[1:], "lightblue",linewidth=3, label="test loss")
plt.xlabel('Epochs')
plt.ylabel('MSE Loss')
plt.legend();

# %%
total_params = sum(
	param.numel() for param in cnn_submeso.parameters()
)
total_params
# Out:
# 362691

# %%
b_x, b_y, prediction = plot_model_direct(cnn_submeso, criterion, loader_test, optimizer,len(torch_dataset_test))
# Out:
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.654552706619713

# %%
# compare with FK
WB_FK = np.load(PATH_NN+'WB_FK.npy')
WB_FK_test = WB_FK[test_ind]

# %%
from scipy import stats

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

corr_pred_wb = stats.pearsonr(cnn_submeso(b_x.to(device)).detach().cpu().numpy().flatten(), b_y.flatten())

print("correlation between prediction and target,  w'b':",corr_pred_wb )
# Out:
# correlation between prediction and target,  w'b': (0.6325378389250172, 0.0)

# %%
# visualize
it =2

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(12, 6))
fig.tight_layout() # Or equivalently,  "plt.tight_layout()"

plt.subplot(231)
plt.pcolor(cnn_submeso(b_x.to(device)).detach().cpu().numpy()[it,0,:,:],cmap='coolwarm',vmin=-2,vmax =2)
plt.title('wb prediction')
plt.colorbar()
plt.axis('off')

plt.subplot(232)
plt.pcolor(b_y[it,0,:,:],cmap='coolwarm',vmin=-2,vmax =2)
plt.title('wb target')
plt.colorbar()
plt.axis('off')

plt.subplot(233)
plt.pcolor(WB_FK_test[it],cmap='coolwarm',vmin=-2,vmax =2)
plt.title('wb FK')
plt.colorbar()
plt.axis('off')
# Out:
# (0.0, 40.0, 0.0, 40.0)

# %%
_=plt.hist(b_y.detach().cpu().numpy().flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="target")
_=plt.hist(cnn_submeso(b_x.to(device)).detach().cpu().numpy().flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="prediction")

plt.xlim([-3,3])
plt.legend()

# %%
b_y.detach().cpu().numpy().shape
# Out:
# (846, 1, 40, 40)

# %%
target_da = xr.DataArray(b_y.detach().cpu().numpy(), dims=["time", "axis", "i","j"])[:,0,:,:]
prediction_da = xr.DataArray(cnn_submeso(b_x.to(device)).detach().cpu().numpy(), dims=["time", "axis", "i","j"])[:,0,:,:]

# %%
import xrft

# target vs prediction spectra

WsBs_target_spectra = xrft.isotropic_power_spectrum(target_da,dim=['i','j'], 
                                           detrend='linear', window=True).compute().mean('time')

WsBs_prediction_spectra = xrft.isotropic_power_spectrum(prediction_da,dim=['i','j'], 
                                           detrend='linear', window=True).compute().mean('time')
# Out:
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:47: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:1025: FutureWarning: Isotropic wavenumber larger than the Nyquist wavenumber may result.
#   warnings.warn(msg, FutureWarning)
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:47: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:1025: FutureWarning: Isotropic wavenumber larger than the Nyquist wavenumber may result.
#   warnings.warn(msg, FutureWarning)

# %%
WsBs_target_spectra
# Out:
# <xarray.DataArray (freq_r: 10)>
# array([0.0231168 , 0.02819176, 0.03467243, 0.03242226, 0.03966008,
#        0.03814904, 0.03636939, 0.03721488, 0.03496538, 0.03527698])
# Coordinates:
#   * freq_r   (freq_r) float64 0.04232 0.1063 0.1767 ... 0.524 0.5938 0.6585

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(4, 10))
fig.tight_layout() # Or equivalently,  "plt.tight_layout()"

plt.subplot(311)
#plt.loglog(WsBs_target_spectra.freq_r*2*np.pi, 5e-3*WsBs_target_spectra.freq_r**-2, '--',linewidth=1.5,color='black', label='k^{-2}')
#plt.loglog(WsBs_target_spectra.freq_r*2*np.pi, 2e-3*WsBs_target_spectra.freq_r**-3, '--',linewidth=1.5,color='gray', label='k^{-3}')
plt.loglog(WsBs_target_spectra.freq_r*2*np.pi, WsBs_target_spectra/WsBs_target_spectra[0],linewidth=3, label='target')
plt.loglog(WsBs_target_spectra.freq_r*2*np.pi, WsBs_prediction_spectra/WsBs_prediction_spectra[0],linewidth=3, label='prediction')
plt.legend()
plt.xlabel('$k_r$')
#plt.ylabel('Normalized isotropic spectra')
plt.title('WsBs')
plt.ylim([1e-3,3])
# Out:
# (0.001, 3)

# %%
np.save(PATH_NN+'test_prediction_7L_k7.npy',cnn_submeso(b_x.to(device)).detach().cpu().numpy()[:,0,:,:])
np.save(PATH_NN+'test_target_7L_k7.npy',b_y[:,0,:,:])
np.save(PATH_NN+'test_WB_FK.npy',WB_FK_test)

# %%
test_prediction = np.load(PATH_NN+'test_prediction_7L_k7.npy')
test_target = np.load(PATH_NN+'test_target_7L_k7.npy')
test_FK = np.load(PATH_NN+'test_WB_FK.npy')

# %%
# visualize
it =20

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(12, 6))
fig.tight_layout() # Or equivalently,  "plt.tight_layout()"

plt.subplot(231)
plt.pcolor(test_prediction[it],cmap='coolwarm',vmin=-1.5,vmax =1.5)
plt.title('wb prediction')
plt.colorbar()
plt.axis('off')

plt.subplot(232)
plt.pcolor(test_target[it,:,:],cmap='coolwarm',vmin=-1.5,vmax =1.5)
plt.title('wb target')
plt.colorbar()
plt.axis('off')

plt.subplot(233)
plt.pcolor(-test_FK[it],cmap='coolwarm',vmin=-1.5,vmax =1.5)
plt.title('wb FK')
plt.colorbar()
plt.axis('off')
# Out:
# (0.0, 40.0, 0.0, 40.0)

# %%
_=plt.hist(test_target.flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="target")
_=plt.hist(test_prediction.flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="prediction")

plt.ylim([0,.3e6])
plt.xlim([-3,3])
plt.legend()

# %%
_=plt.hist(b_y.detach().cpu().numpy().flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="target")
_=plt.hist(cnn_submeso(b_x.to(device)).detach().cpu().numpy().flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="prediction")

plt.xlim([-3,3])
plt.legend()
