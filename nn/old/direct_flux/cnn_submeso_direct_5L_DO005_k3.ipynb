# %%
import torch
import torch.nn.functional as F
import torch.utils.data as Data
import torchvision
from torch import nn, optim
from torch.autograd import Variable
import numpy as np
import os
import glob
import xarray as xr
from sklearn import preprocessing
import netCDF4 as nc
import matplotlib.pyplot as plt



np.random.seed(14)  # For reproducibility
torch.manual_seed(14)  # For reproducibility

# %% [markdown]
# # Dataloader

# %% [markdown]
# ### Create input and output channels

# %%
# function that splits datasets along the spacial axes and concats them back into single array under time

def normalize(data):
    #normalized_data =  (data - data.mean(skipna=True).values)/data.std(skipna=True).values
    normalized_data = (data - np.mean(data))/np.std(data)
    return normalized_data


def load_norm_data(var_name_string):
    PATH_LIST = glob.glob(BASE+'*/preprocessed_data/'+var_name_string+'.nc') 
    data_app = normalize(xr.open_dataarray(PATH_LIST[0]).to_numpy()[:,5:-5,5:-5])
    for i_file in np.arange(1,len(PATH_LIST)):
        PATH = PATH_LIST[i_file]
        data = xr.open_dataarray(PATH).to_numpy()[:,5:-5,5:-5]
        data_norm = normalize(data)
        data_app = np.concatenate((data_app,data_norm),axis=0)
    return data_app

# depth of CNN * (kernel_num-1)/2
#def load_norm_data_out(var_name_string): #with cropping for output
#    PATH_LIST = glob.glob(BASE+'*/preprocessed_data/'+var_name_string+'.nc') 
#    data_app = normalize(xr.open_dataarray(PATH_LIST[0]).to_numpy()[:,14:-14,14:-14])
#    for i_file in np.arange(1,len(PATH_LIST)):
#        PATH = PATH_LIST[i_file]
#        data = xr.open_dataarray(PATH).to_numpy()[:,14:-14,14:-14]
#        data_norm = normalize(data)
#        data_app = np.concatenate((data_app,data_norm),axis=0)
#    return data_app


def split_data(data):
    data_split_halfs = np.concatenate((np.split(data,2,axis=1)[0],np.split(data,2,axis=1)[1]),0)
    data_split_quarters = np.concatenate((np.split(data_split_halfs,2,axis=2)[0],np.split(data_split_halfs,2,axis=2)[1]),0)
    return data#data_split_quarters



def load_split_norm_data(var_name_string):
    loaded_data = load_norm_data(var_name_string)
    splitted_data = split_data(loaded_data)
    return splitted_data
    
    
def load_split_norm_data_out(var_name_string):
    loaded_data = load_norm_data(var_name_string)
    splitted_data = split_data(loaded_data)
    cropped_output = splitted_data[:,5:-5,5:-5] # for a kernel of size 3 with 5 conv layers
    return cropped_output

# %%
# load preprocessed data, convert to numpy and stack channels

BASE = '/scratch/ab10313/submeso_ML_data/'
FULL_PATH_PP = glob.glob(BASE+'*/preprocessed_data/')

# X INPUT
ds_Bm = load_split_norm_data('Bm_MLD_lowres')
ds_Um = load_split_norm_data('Um_MLD_lowres')
ds_Vm = load_split_norm_data('Vm_MLD_lowres')
ds_Wm = load_split_norm_data('Wm_MLD_lowres')


X_input = np.stack([ds_Bm,ds_Um,ds_Vm,ds_Wm],axis=1)
print('X input shape:')
print( X_input.shape)
print('')


# Y OUTPUT
ds_UsBs = load_split_norm_data('UsBs_MLD_lowres')
ds_VsBs = load_split_norm_data('VsBs_MLD_lowres')
ds_WsBs = load_split_norm_data('WsBs_MLD_lowres')

Y_output = np.stack([ds_UsBs,ds_VsBs,ds_WsBs],axis=1)
print('Y output shape:')
print(Y_output.shape)
print('')


# GRAD B
ds_Bm_x = load_split_norm_data('Bm_x_MLD_lowres')
ds_Bm_y = load_split_norm_data('Bm_y_MLD_lowres')
ds_Bm_z = load_split_norm_data('Bm_z_MLD_lowres')

grad_b = np.stack([ds_Bm_x,ds_Bm_y,ds_Bm_z],axis=1)
print('grad b shape:')
print( grad_b.shape)
# Out:
# X input shape:
# (2150, 4, 30, 30)
#
# Y output shape:
# (2150, 3, 30, 30)
#
# grad b shape:
# (2150, 3, 30, 30)

# %% [markdown]
# ### randomly generate train, test and validation sets

# %%
# TRAIN AND TEST ONLY
# randomnly generate train, test and validation time indecies 
import random
time_ind = X_input.shape[0]
rand_ind = np.arange(time_ind)
rand_seed = 14
random.Random(rand_seed).shuffle(rand_ind)
train_percent = 0.9
test_percent = 0.1 
print(f"Dataset: train {np.round(train_percent*100)}%, test {np.round(test_percent*100)}%")
train_ind, test_ind =  rand_ind[:round(train_percent*time_ind)], rand_ind[round((train_percent)*time_ind):]                                                                        

# check no overlapping indecies
if np.intersect1d(train_ind, test_ind).any():
    print('overlapping indecies')
else:
    print ('no overlapping indecies')
# Out:
# Dataset: train 90.0%, test 10.0%
# no overlapping indecies

# %% [markdown]
# ### defined train, test and val dataloaders

# %%
# Define X,Y pairs (state, subgrid fluxes) for local network.local_torch_dataset = Data.TensorDataset(
BATCH_SIZE = 64  # Number of sample in each batch


###### training dataset #######
torch_dataset_train = Data.TensorDataset(
    torch.from_numpy(X_input[train_ind]).double(),
    torch.from_numpy(Y_output[train_ind]).double(),
)

loader_train = Data.DataLoader(
    dataset=torch_dataset_train, batch_size=BATCH_SIZE, shuffle=True
)
print('TRAIN')
print('X input shape:')
print( X_input[train_ind].shape)
print('Y output shape:')
print( Y_output[train_ind].shape)
print('')

###### test dataset #######
torch_dataset_test = Data.TensorDataset(
    torch.from_numpy(X_input[test_ind]).double(),
    torch.from_numpy(Y_output[test_ind]).double(),    
)

BATCH_SIZE_TEST = len(torch_dataset_test)

loader_test = Data.DataLoader(
    dataset=torch_dataset_test, batch_size=BATCH_SIZE_TEST, shuffle=True
)

print('TEST')
print('X input shape:')
print( X_input[test_ind].shape)
print('Y output shape:')
print( Y_output[test_ind].shape)
print('')

###### validation dataset #######
#torch_dataset_val = Data.TensorDataset(
#    torch.from_numpy(X_input[val_ind]).double(),
#    torch.from_numpy(Y_output[val_ind]).double(),
#)


#loader_val = Data.DataLoader(
#    dataset=torch_dataset_val, batch_size=BATCH_SIZE, shuffle=True
#)

#print('VAL')
#print('X input shape:')
#print( X_input[val_ind].shape)
#print('Y output shape:')
#print( Y_output[val_ind].shape)
#print('')
# Out:
# TRAIN
# X input shape:
# (1935, 4, 30, 30)
# Y output shape:
# (1935, 3, 30, 30)
#
# TEST
# X input shape:
# (215, 4, 30, 30)
# Y output shape:
# (215, 3, 30, 30)

# %% [markdown]
# ## CNN - direct fluxes 3 output channels

# %%
# define network structure in pytorch
import torch.nn.functional as FF

class CNN_direct(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(4, 128, 3, padding='same', padding_mode='reflect')  # 4 inputs, 64 neurons for first hidden layer
        self.dropout1 = nn.Dropout(0.05)
        self.conv1_bn=nn.BatchNorm2d(128)
        self.conv2 = nn.Conv2d(128, 64, 3, padding='same', padding_mode='reflect')  # 64 inputs, 32 neurons for first hidden layer
        self.dropout2 = nn.Dropout(0.05)
        self.conv2_bn=nn.BatchNorm2d(64)
        self.conv3 = nn.Conv2d(64, 32, 3, padding='same', padding_mode='reflect')  # 32 inputs, 16 neurons for first hidden layer
        self.dropout3 = nn.Dropout(0.05)
        self.conv3_bn=nn.BatchNorm2d(32)  
        self.conv4 = nn.Conv2d(32, 16, 3, padding='same', padding_mode='reflect')  # 16 inputs, 3 neurons for first hidden layer
        self.dropout4 = nn.Dropout(0.05)
        self.conv4_bn=nn.BatchNorm2d(16) 
        self.conv5 = nn.Conv2d(16, 3, 3, padding='same', padding_mode='reflect')  # 32 inputs, 24 neurons for first hidden layer
        self.dropout5 = nn.Dropout(0.05)
        self.conv5_bn=nn.BatchNorm2d(3) 

    def forward(self, x):
        x = self.conv1(x)
        x = self.dropout1(x)
        x = F.relu(self.conv1_bn(x))
        x = self.conv2(x)
        x = self.dropout2(x)
        x = F.relu(self.conv2_bn(x))
        x = self.conv3(x)
        x = self.dropout3(x)
        x = F.relu(self.conv3_bn(x))
        x = self.conv4(x)
        x = self.dropout4(x)
        x = F.relu(self.conv4_bn(x))
        x = self.conv5(x)
        x = self.dropout5(x)
        x = self.conv5_bn(x)
        return x
 
    
# define network structure in pytorch
import torch.nn.functional as FF

#class CNN_direct(nn.Module):
#    def __init__(self):
#        super().__init__()
#        self.conv1 = nn.Conv2d(4, 64, 5,padding='same')  # 4 inputs, 128 neurons for first hidden layer
#        self.conv2 = nn.Conv2d(64, 32, 5,padding='same')  # 64 inputs, 32 neurons for first hidden layer
#        self.conv3 = nn.Conv2d(32, 3, 5,padding='same')  # 32 inputs, 24 neurons for first hidden layer

#    def forward(self, x):
#        x = FF.relu(self.conv1(x))
#        x = FF.relu(self.conv2(x))
#        x = self.conv3(x)
#        return x

# %% [markdown]
# ## Train and test model: direct fluxes

# %%
# train network 
def train_model_direct(net, criterion, trainloader, optimizer, len_train_dataset, text="train"):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    net.to(device)
    device_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else "cpu"
    print(f"Training starts on device {device_name}, number of samples {len(trainloader)}")
    
    net.train()
    train_loss = 0
    for step, (batch_x, batch_y) in enumerate(trainloader):  # for each training step
        b_x = Variable(batch_x)  # Inputs
        b_y = Variable(batch_y)  # outputs
        prediction = net(b_x.to(device))
        loss = criterion(prediction, b_y.to(device))  # Calculating loss
        optimizer.zero_grad()  # clear gradients for next train
        loss.backward()  # backpropagation, compute gradients
        optimizer.step()  # apply gradients to update weights
        nb = b_y.shape[0]
        train_loss = train_loss + nb * loss.detach().cpu().numpy()  # Keep track of the loss
    train_loss /= len_train_dataset  # dividing by the number of batches
    print(text + " loss:", train_loss)
    return train_loss


def test_model_direct(net, criterion, testloader, optimizer,len_test_dataset, text="test"):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    net.to(device)
    device_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else "cpu"
    print(f"Training starts on device {device_name}, number of samples {len(testloader)}")
    
    net.eval()  # Evaluation mode (important when having dropout layers)
    test_loss = 0
    with torch.no_grad():
        for step, (batch_x, batch_y) in enumerate(
            testloader
        ):  # for each training step
            b_x = Variable(batch_x)  # Inputs
            b_y = Variable(batch_y)  # outputs
            prediction = net(b_x.to(device))
            loss = criterion(prediction, b_y.to(device))  # Calculating loss
            nb = b_y.shape[0]
            test_loss = test_loss + nb * loss.detach().cpu().numpy()  # Keep track of the loss
        test_loss /= len_test_dataset  # dividing by the number of batches
        #         print(len(trainloader))
        print(text + " loss:", test_loss)
    return test_loss



def plot_model_direct(net, criterion, testloader, optimizer, len_test_dataset, text="test"):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    net.to(device)
    device_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else "cpu"
    print(f"Training starts on device {device_name}, number of samples {len(testloader)}")
    
    net.eval()  # Evaluation mode (important when having dropout layers)
    test_loss = 0
    with torch.no_grad():
        for step, (batch_x, batch_y) in enumerate(
            testloader
        ):  # for each training step
            b_x = Variable(batch_x)  # Inputs
            b_y = Variable(batch_y)  # outputs
            prediction = net(b_x.to(device))
            loss = criterion(prediction, b_y.to(device))  # Calculating loss
            nb = b_y.shape[0]
            test_loss = test_loss + nb * loss.detach().cpu().numpy()  # Keep track of the loss
        test_loss /= len_test_dataset  # dividing by the number of batches
        #         print(len(trainloader))
        print(text + " loss:", test_loss)
    return b_x, b_y, prediction


criterion = torch.nn.MSELoss()  # MSE loss function

# %% [markdown]
# ## train CNN!

# %%
torch.manual_seed(14)  # For reproducibility
cnn_submeso = CNN_direct().double()

n_epochs = 100  # Number of epocs could be increased
optimizer = optim.Adam(cnn_submeso.parameters(), lr=0.03)
test_loss = list()
train_loss = list()
for epoch in range(1, n_epochs + 1):
    print("epoch:", epoch)
    train_loss.append(train_model_direct(cnn_submeso, criterion, loader_train, optimizer,len(torch_dataset_train)))
    test_loss.append(test_model_direct(cnn_submeso, criterion, loader_test, optimizer,len(torch_dataset_test)))
# Out:
# epoch: 1
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 1.2530601287297867
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 1.0026923260571547
# epoch: 2
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.9657320625367657
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.972838097600767
# epoch: 3
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.9525194466051944
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.9544552372496661
# epoch: 4
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.9386817318178045
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.9481174471473458
# epoch: 5
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.9264173749421977
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.9275095885709013
# epoch: 6
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.9138356041745882
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.9125393684491254
# epoch: 7
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.9016842791957853
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.9047498673135336
# epoch: 8
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.8891995678585676
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8941774302693515
# epoch: 9
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.8744118819092269
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8783420558093273
# epoch: 10
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.8636718486609886
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8604305334365132
# epoch: 11
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.8512050811858647
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8660217701882557
# epoch: 12
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.8462375923026559
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8419919428897858
# epoch: 13
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.831064133622577
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8318008044141526
# epoch: 14
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.8185964282965738
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8224587333166065
# epoch: 15
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.8087229643317482
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8337294732080209
# epoch: 16
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.7991973244473944
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8235814294476669
# epoch: 17
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.795432816612294
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7907941845491652
# epoch: 18
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.7845958794674912
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8073639604794594
# epoch: 19
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.7746564433940636
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7736149465138696
# epoch: 20
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.7676277453314411
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7745615529920827
# epoch: 21
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.7645537225786917
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7649247385013763
# epoch: 22
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.7555180524671062
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7560646438982835
# epoch: 23
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.7460010668002194
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7450704353385547
# epoch: 24
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.7426944239442178
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7401457824452
# epoch: 25
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.7342912766334609
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7342654760739303
# epoch: 26
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.7297751015298097
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7371824542730413
# epoch: 27
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.7207924784767715
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7283504806810484
# epoch: 28
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.7167163606316418
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7244827305095791
# epoch: 29
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.714985628149922
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7195693016936878
# epoch: 30
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.7075392662636766
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7259519221996943
# epoch: 31
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.7005750319903565
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7005313668182339
# epoch: 32
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6950146566275773
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.73173929264498
# epoch: 33
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6935498444543713
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7092325494093304
# epoch: 34
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6869489396323277
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6872577388052316
# epoch: 35
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6867461306797529
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6935672748345661
# epoch: 36
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6800323524971476
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6778812735232566
# epoch: 37
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6774654211351908
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6785795141280286
# epoch: 38
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6720757415975844
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6738936524104305
# epoch: 39
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6734563730016994
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6875189863439124
# epoch: 40
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6675685692987743
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6655042079762356
# epoch: 41
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6673732548381981
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6921132179175958
# epoch: 42
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6621819768920287
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6962039470531469
# epoch: 43
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6635503197766746
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6585641314986033
# epoch: 44
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6602204531803618
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6675895675094702
# epoch: 45
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6560916749708172
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6713635661030242
# epoch: 46
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.650069483266491
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6599450937269917
# epoch: 47
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6523004177568269
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6776494724377629
# epoch: 48
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6539807081194674
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7234650231927466
# epoch: 49
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6532072336132796
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.662403124612874
# epoch: 50
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6480098066396827
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6674649375070131
# epoch: 51
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6445139541521077
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6917624427336581
# epoch: 52
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6422572581432683
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6736797589755945
# epoch: 53
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6446759891964492
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6506196345253985
# epoch: 54
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.642218305673494
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6742034773593487
# epoch: 55
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.643174866864666
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6872028057932418
# epoch: 56
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6371206537821537
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6682099093151223
# epoch: 57
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6403241639510739
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6573067063728418
# epoch: 58
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6363868398570648
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6573617211151693
# epoch: 59
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6352367195347806
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6475480447257066
# epoch: 60
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6308900479085123
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6576989019534861
# epoch: 61
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6300595846558655
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.638745457725103
# epoch: 62
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6305224075700063
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6508007710712607
# epoch: 63
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6303430606134506
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6523630309471633
# epoch: 64
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6268797685134614
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6519749520498644
# epoch: 65
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6282604196869656
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6495870832885374
# epoch: 66
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6278018145416401
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6471953850896406
# epoch: 67
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6238988100038662
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6412944788905814
# epoch: 68
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6238501376238608
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6392363243872974
# epoch: 69
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6224577191493217
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6633667864810535
# epoch: 70
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6249348699198541
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.655456654542277
# epoch: 71
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6259285881584584
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6544267119456321
# epoch: 72
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6207246446174906
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6686066569881024
# epoch: 73
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6205670427530348
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6562969173183645
# epoch: 74
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6178130977986804
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6416202140088868
# epoch: 75
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6164077863464577
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6502691601490748
# epoch: 76
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6198203113864691
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.65380228287335
# epoch: 77
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6197474433399129
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6629833960935515
# epoch: 78
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6177950387190948
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6923736671330969
# epoch: 79
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6137888117182672
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6422835345848007
# epoch: 80
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6126948910268537
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6544926537667715
# epoch: 81
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6133486749024315
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.649821680094728
# epoch: 82
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6118279831135979
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6497989715301691
# epoch: 83
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6126224099050709
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6444603340383152
# epoch: 84
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6119598811002697
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6552532583954405
# epoch: 85
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6115146497807993
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.64442991964571
# epoch: 86
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.610012537484304
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6454155620837858
# epoch: 87
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6133125740081622
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6703055061936173
# epoch: 88
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6089512627893264
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6430899225556815
# epoch: 89
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6112282874397234
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6290629541923779
# epoch: 90
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6082885569450666
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6442883816109433
# epoch: 91
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6070808544414023
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.635255053635736
# epoch: 92
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6050211649125765
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6460902443561701
# epoch: 93
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6041862336340369
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6366787844029469
# epoch: 94
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6060671053206483
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6424445709803465
# epoch: 95
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6043740466631977
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6340544057393361
# epoch: 96
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6044462820842145
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6488080113600321
# epoch: 97
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6023647394674464
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6775354818209773
# epoch: 98
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6032784694018731
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6470857879640697
# epoch: 99
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6052043517611064
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6368047855616628
# epoch: 100
# Training starts on device Quadro RTX 8000, number of samples 31
# train loss: 0.6042757008611179
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6417270588313444

# %%
import matplotlib.pyplot as plt

plt.plot(train_loss[1:], "b", linewidth=3,label="training loss")
plt.plot(test_loss[1:], "lightblue",linewidth=3, label="test loss")
plt.xlabel('Epochs')
plt.ylabel('MSE Loss')
plt.legend();

# %%
total_params = sum(
	param.numel() for param in cnn_submeso.parameters()
)
total_params
# Out:
# 102537

# %%
b_x, b_y, prediction = plot_model_direct(cnn_submeso, criterion, loader_test, optimizer,len(torch_dataset_test))
# Out:
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6417270588313445

# %%
from scipy import stats

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

corr_pred_ub = stats.pearsonr(cnn_submeso(b_x.to(device)).detach().cpu().numpy()[:,0,:,:].flatten(), b_y[:,0,:,:].flatten())
corr_pred_vb = stats.pearsonr(cnn_submeso(b_x.to(device)).detach().cpu().numpy()[:,1,:,:].flatten(), b_y[:,1,:,:].flatten())
corr_pred_wb = stats.pearsonr(cnn_submeso(b_x.to(device)).detach().cpu().numpy()[:,2,:,:].flatten(), b_y[:,2,:,:].flatten())

print("correlation between prediction and target,  u'b':",corr_pred_ub )
print("correlation between prediction and target,  v'b':",corr_pred_vb )
print("correlation between prediction and target,  w'b':",corr_pred_wb )
# Out:
# correlation between prediction and target,  u'b': (0.6391424748892834, 0.0)
# correlation between prediction and target,  v'b': (0.6564880411520642, 0.0)
# correlation between prediction and target,  w'b': (0.5363414822871144, 0.0)

# %%
# visualize
it =21

fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(10, 5))
fig.tight_layout() # Or equivalently,  "plt.tight_layout()"

plt.subplot(231)
plt.pcolor(cnn_submeso(b_x.to(device)).detach().cpu().numpy()[it,0,:,:],cmap='viridis',vmin=-1.5,vmax =1.5)
plt.title('ub prediction')
plt.colorbar()
plt.axis('off')

plt.subplot(234)
plt.pcolor(b_y[it,0,:,:],cmap='viridis',vmin=-1.5,vmax =1.5)
plt.title('ub target')
plt.colorbar()
plt.axis('off')

plt.subplot(232)
plt.pcolor(cnn_submeso(b_x.to(device)).detach().cpu().numpy()[it,1,:,:],cmap='viridis',vmin=-1.5,vmax =1.5)
plt.title('vb prediction')
plt.colorbar()
plt.axis('off')

plt.subplot(235)
plt.pcolor(b_y[it,1,:,:],cmap='viridis',vmin=-1.5,vmax =1.5)
plt.title('vb target')
plt.colorbar()
plt.axis('off')

plt.subplot(233)
plt.pcolor(cnn_submeso(b_x.to(device)).detach().cpu().numpy()[it,2,:,:],cmap='viridis',vmin=-1.5,vmax =1.5)
plt.title('wb prediction')
plt.colorbar()
plt.axis('off')

plt.subplot(236)
plt.pcolor(b_y[it,2,:,:],cmap='viridis',vmin=-1.5,vmax =1.5)
plt.title('wb target')
plt.colorbar()
plt.axis('off')
# Out:
# (0.0, 30.0, 0.0, 30.0)

# %%
# visualize
it =16

fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(7, 8))
fig.tight_layout() # Or equivalently,  "plt.tight_layout()"

plt.subplot(321)
plt.pcolor(cnn_submeso(b_x.to(device)).detach().cpu().numpy()[it,0,:,:],cmap='Blues',vmin=-1.5,vmax =1.5)
plt.title('ub prediction')
plt.colorbar()
plt.axis('off')

plt.subplot(322)
plt.pcolor(b_y[it,0,:,:],cmap='Blues',vmin=-1.5,vmax =1.5)
plt.title('ub target')
plt.colorbar()
plt.axis('off')

plt.subplot(323)
plt.pcolor(cnn_submeso(b_x.to(device)).detach().cpu().numpy()[it,1,:,:],cmap='Blues',vmin=-1.5,vmax =1.5)
plt.title('vb prediction')
plt.colorbar()
plt.axis('off')

plt.subplot(324)
plt.pcolor(b_y[it,1,:,:],cmap='Blues',vmin=-1.5,vmax =1.5)
plt.title('vb target')
plt.colorbar()
plt.axis('off')

plt.subplot(325)
plt.pcolor(cnn_submeso(b_x.to(device)).detach().cpu().numpy()[it,2,:,:],cmap='Blues',vmin=-1.5,vmax =1.5)
plt.title('wb prediction')
plt.colorbar()
plt.axis('off')

plt.subplot(326)
plt.pcolor(b_y[it,2,:,:],cmap='Blues',vmin=-1.5,vmax =1.5)
plt.title('wb target')
plt.colorbar()
plt.axis('off')
# Out:
# (0.0, 30.0, 0.0, 30.0)

# %%
_=plt.hist(b_y.detach().cpu().numpy().flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="target")
_=plt.hist(cnn_submeso(b_x.to(device)).detach().cpu().numpy().flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="prediction")

plt.xlim([-3,3])
plt.legend()

# %%
fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(4, 10))
fig.tight_layout() # Or equivalently,  "plt.tight_layout()"

plt.subplot(311)
_=plt.hist(b_y.detach().cpu().numpy()[:,0,:,:].flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="target")
_=plt.hist(cnn_submeso(b_x.to(device)).detach().cpu().numpy()[:,0,:,:].flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="prediction")
plt.xlim([-3,3])
plt.legend()
plt.axis('off')
plt.title('ub')


plt.subplot(312)
_=plt.hist(b_y.detach().cpu().numpy()[:,1,:,:].flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="target")
_=plt.hist(cnn_submeso(b_x.to(device)).detach().cpu().numpy()[:,1,:,:].flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="prediction")
plt.xlim([-3,3])
plt.legend()
plt.axis('off')
plt.title('vb')

plt.subplot(313)
_=plt.hist(b_y.detach().cpu().numpy()[:,2,:,:].flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="target")
_=plt.hist(cnn_submeso(b_x.to(device)).detach().cpu().numpy()[:,2,:,:].flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="prediction")
plt.xlim([-3,3])
plt.legend()
plt.title('wb')
plt.axis('off')
# Out:
# (-3.0, 3.0, 0.0, 8978.55)

# %%
target_da = xr.DataArray(b_y.detach().cpu().numpy(), dims=["time", "axis", "i","j"])
prediction_da = xr.DataArray(cnn_submeso(b_x.to(device)).detach().cpu().numpy(), dims=["time", "axis", "i","j"])

# %%
import xrft

# target vs prediction spectra
UsBs_target_spectra = xrft.isotropic_power_spectrum(target_da.isel(axis=0),dim=['i','j'], 
                                           detrend='linear', window=True).compute().mean('time')

UsBs_prediction_spectra = xrft.isotropic_power_spectrum(prediction_da.isel(axis=0),dim=['i','j'], 
                                           detrend='linear', window=True).compute().mean('time')


VsBs_target_spectra = xrft.isotropic_power_spectrum(target_da.isel(axis=1),dim=['i','j'], 
                                           detrend='linear', window=True).compute().mean('time')

VsBs_prediction_spectra = xrft.isotropic_power_spectrum(prediction_da.isel(axis=1),dim=['i','j'], 
                                           detrend='linear', window=True).compute().mean('time')


WsBs_target_spectra = xrft.isotropic_power_spectrum(target_da.isel(axis=2),dim=['i','j'], 
                                           detrend='linear', window=True).compute().mean('time')

WsBs_prediction_spectra = xrft.isotropic_power_spectrum(prediction_da.isel(axis=2),dim=['i','j'], 
                                           detrend='linear', window=True).compute().mean('time')
# Out:
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:47: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:1025: FutureWarning: Isotropic wavenumber larger than the Nyquist wavenumber may result.
#   warnings.warn(msg, FutureWarning)
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:47: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:1025: FutureWarning: Isotropic wavenumber larger than the Nyquist wavenumber may result.
#   warnings.warn(msg, FutureWarning)
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:47: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:1025: FutureWarning: Isotropic wavenumber larger than the Nyquist wavenumber may result.
#   warnings.warn(msg, FutureWarning)
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:47: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:1025: FutureWarning: Isotropic wavenumber larger than the Nyquist wavenumber may result.
#   warnings.warn(msg, FutureWarning)
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:47: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:1025: FutureWarning: Isotropic wavenumber larger than the Nyquist wavenumber may result.
#   warnings.warn(msg, FutureWarning)
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:47: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:1025: FutureWarning: Isotropic wavenumber larger than the Nyquist wavenumber may result.
#   warnings.warn(msg, FutureWarning)

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(4, 10))
fig.tight_layout() # Or equivalently,  "plt.tight_layout()"

plt.subplot(311)
#plt.loglog(UsBs_target_spectra.freq_r*2*np.pi, 5e-3*UsBs_target_spectra.freq_r**-2, '--',linewidth=1.5,color='black', label='k^{-2}')
#plt.loglog(UsBs_target_spectra.freq_r*2*np.pi, 2e-3*UsBs_target_spectra.freq_r**-3, '--',linewidth=1.5,color='gray', label='k^{-3}')
plt.loglog(UsBs_target_spectra.freq_r*2*np.pi, UsBs_target_spectra/UsBs_target_spectra[0],linewidth=3, label='target')
plt.loglog(UsBs_prediction_spectra.freq_r*2*np.pi, UsBs_prediction_spectra/UsBs_prediction_spectra[0],linewidth=3, label='prediction')
plt.legend()
#plt.xlabel('$k_r$')
plt.ylabel('Normalized isotropic spectra')
plt.title('UsBs')
plt.ylim([1e-3,3])

plt.subplot(312)
#plt.loglog(VsBs_target_spectra.freq_r*2*np.pi, 5e-3*VsBs_target_spectra.freq_r**-2, '--',linewidth=1.5,color='black', label='k^{-2}')
#plt.loglog(VsBs_target_spectra.freq_r*2*np.pi, 2e-3*VsBs_target_spectra.freq_r**-3, '--',linewidth=1.5,color='gray', label='k^{-3}')
plt.loglog(VsBs_target_spectra.freq_r*2*np.pi, VsBs_target_spectra/VsBs_target_spectra[0],linewidth=3, label='target')
plt.loglog(VsBs_prediction_spectra.freq_r*2*np.pi, VsBs_prediction_spectra/VsBs_prediction_spectra[0],linewidth=3, label='prediction')
plt.legend()
#plt.xlabel('$k_r$')
#plt.ylabel('Normalized isotropic spectra')
plt.title('VsBs')
plt.ylim([1e-3,3])


plt.subplot(313)
#plt.loglog(WsBs_target_spectra.freq_r*2*np.pi, 5e-3*WsBs_target_spectra.freq_r**-2, '--',linewidth=1.5,color='black', label='k^{-2}')
#plt.loglog(WsBs_target_spectra.freq_r*2*np.pi, 2e-3*WsBs_target_spectra.freq_r**-3, '--',linewidth=1.5,color='gray', label='k^{-3}')
plt.loglog(WsBs_target_spectra.freq_r*2*np.pi, WsBs_target_spectra/WsBs_target_spectra[0],linewidth=3, label='target')
plt.loglog(WsBs_target_spectra.freq_r*2*np.pi, WsBs_prediction_spectra/WsBs_prediction_spectra[0],linewidth=3, label='prediction')
plt.legend()
plt.xlabel('$k_r$')
#plt.ylabel('Normalized isotropic spectra')
plt.title('WsBs')
plt.ylim([1e-3,3])
# Out:
# (0.001, 3)
