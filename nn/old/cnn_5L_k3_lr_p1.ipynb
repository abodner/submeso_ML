# %%
import torch
import torch.nn.functional as F
import torch.utils.data as Data
import torchvision
from torch import nn, optim
from torch.autograd import Variable
import numpy as np
import os
import glob
import xarray as xr
from sklearn import preprocessing
import netCDF4 as nc
import matplotlib.pyplot as plt



np.random.seed(14)  # For reproducibility
torch.manual_seed(14)  # For reproducibility

# %% [markdown]
# # Dataloader

# %% [markdown]
# ### Create input and output channels

# %%
# load preprocessed data into input and output channels

BASE = '/scratch/ab10313/pleiades/'
PATH_NN = BASE+'NN_data/'

# X INPUT
grad_B = np.load(PATH_NN+'grad_B.npy')
HML = np.load(PATH_NN+'HML.npy')
TAU = np.load(PATH_NN+'TAU.npy')
U = np.load(PATH_NN+'U.npy')
V = np.load(PATH_NN+'V.npy')
Q = np.load(PATH_NN+'Q.npy')
HBL = np.load(PATH_NN+'HBL.npy')
#FCOR = np.load(PATH_NN+'FCOR.nc')


X_input = np.stack([grad_B, HML, TAU, U, V, Q, HBL],axis=1)
print('X input shape:')
print( X_input.shape)
print('')


# Y OUTPUT
WB_sg = np.load(PATH_NN+'WB_sg.npy')
              
Y_output = np.tile(WB_sg,(1,1,1,1)).reshape(WB_sg.shape[0],1,WB_sg.shape[1],WB_sg.shape[2]) 
print('Y output shape:')
print(Y_output.shape)
print('')
# Out:
# X input shape:
# (7614, 7, 40, 40)
#
# Y output shape:
# (7614, 1, 40, 40)

# %% [markdown]
# ### randomly generate train, test and validation sets

# %%
# TRAIN AND TEST ONLY
# randomnly generate train, test and validation time indecies 
import random
time_ind = X_input.shape[0]
rand_ind = np.arange(time_ind)
rand_seed = 14
random.Random(rand_seed).shuffle(rand_ind)
train_percent = 0.9
test_percent = 0.1 
print(f"Dataset: train {np.round(train_percent*100)}%, test {np.round(test_percent*100)}%")
train_ind, test_ind =  rand_ind[:round(train_percent*time_ind)], rand_ind[round((train_percent)*time_ind):]                                                                        

# check no overlapping indecies
if np.intersect1d(train_ind, test_ind).any():
    print('overlapping indecies')
else:
    print ('no overlapping indecies')
# Out:
# Dataset: train 90.0%, test 10.0%
# no overlapping indecies

# %% [markdown]
# ### defined train, test and val dataloaders

# %%
# Define X,Y pairs (state, subgrid fluxes) for local network.local_torch_dataset = Data.TensorDataset(
BATCH_SIZE = 64  # Number of sample in each batch


###### training dataset #######
torch_dataset_train = Data.TensorDataset(
    torch.from_numpy(X_input[train_ind]).double(),
    torch.from_numpy(Y_output[train_ind]).double(),
)

loader_train = Data.DataLoader(
    dataset=torch_dataset_train, batch_size=BATCH_SIZE, shuffle=True
)
print('TRAIN')
print('X input shape:')
print( X_input[train_ind].shape)
print('Y output shape:')
print( Y_output[train_ind].shape)
print('')

###### test dataset #######
torch_dataset_test = Data.TensorDataset(
    torch.from_numpy(X_input[test_ind]).double(),
    torch.from_numpy(Y_output[test_ind]).double(),    
)

BATCH_SIZE_TEST = len(torch_dataset_test)

loader_test = Data.DataLoader(
    dataset=torch_dataset_test, batch_size=BATCH_SIZE_TEST, shuffle=True
)

print('TEST')
print('X input shape:')
print( X_input[test_ind].shape)
print('Y output shape:')
print( Y_output[test_ind].shape)
print('')
# Out:
# TRAIN
# X input shape:
# (6853, 7, 40, 40)
# Y output shape:
# (6853, 1, 40, 40)
#
# TEST
# X input shape:
# (761, 7, 40, 40)
# Y output shape:
# (761, 1, 40, 40)

# %% [markdown]
# ## CNN - direct fluxes 3 output channels

# %%
# define network structure in pytorch
import torch.nn.functional as FF

class CNN_direct(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(7, 128, 3, padding='same', padding_mode='reflect')  # 7 inputs, 128 neurons for first hidden layer
        self.conv1_bn=nn.BatchNorm2d(128)
        self.conv2 = nn.Conv2d(128, 64, 3, padding='same', padding_mode='reflect')  # 128 inputs, 64 neurons for first hidden layer
        self.conv2_bn=nn.BatchNorm2d(64)
        self.conv3 = nn.Conv2d(64, 32, 3, padding='same', padding_mode='reflect')  # 64 inputs, 32 neurons for first hidden layer
        self.conv3_bn=nn.BatchNorm2d(32)  
        self.conv4 = nn.Conv2d(32, 16, 3, padding='same', padding_mode='reflect')  # 32 inputs, 16 neurons for first hidden layer
        self.conv4_bn=nn.BatchNorm2d(16) 
        self.conv5 = nn.Conv2d(16, 1, 3, padding='same', padding_mode='reflect')  # 16 inputs, 1 neurons for first hidden layer
        self.conv5_bn=nn.BatchNorm2d(1) 

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(self.conv1_bn(x))
        x = self.conv2(x)
        x = F.relu(self.conv2_bn(x))
        x = self.conv3(x)
        x = F.relu(self.conv3_bn(x))
        x = self.conv4(x)
        x = F.relu(self.conv4_bn(x))
        x = self.conv5(x)
        x = self.conv5_bn(x)
        return x

# %% [markdown]
# ## Train and test model: direct fluxes

# %%
# train network 
def train_model_direct(net, criterion, trainloader, optimizer, len_train_dataset, text="train"):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    net.to(device)
    device_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else "cpu"
    print(f"Training starts on device {device_name}, number of samples {len(trainloader)}")
    
    net.train()
    train_loss = 0
    for step, (batch_x, batch_y) in enumerate(trainloader):  # for each training step
        b_x = Variable(batch_x)  # Inputs
        b_y = Variable(batch_y)  # outputs
        prediction = net(b_x.to(device))
        loss = criterion(prediction, b_y.to(device))  # Calculating loss
        optimizer.zero_grad()  # clear gradients for next train
        loss.backward()  # backpropagation, compute gradients
        optimizer.step()  # apply gradients to update weights
        nb = b_y.shape[0]
        train_loss = train_loss + nb * loss.detach().cpu().numpy()  # Keep track of the loss
    train_loss /= len_train_dataset  # dividing by the number of batches
    print(text + " loss:", train_loss)
    return train_loss


def test_model_direct(net, criterion, testloader, optimizer,len_test_dataset, text="test"):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    net.to(device)
    device_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else "cpu"
    print(f"Training starts on device {device_name}, number of samples {len(testloader)}")
    
    net.eval()  # Evaluation mode (important when having dropout layers)
    test_loss = 0
    with torch.no_grad():
        for step, (batch_x, batch_y) in enumerate(
            testloader
        ):  # for each training step
            b_x = Variable(batch_x)  # Inputs
            b_y = Variable(batch_y)  # outputs
            prediction = net(b_x.to(device))
            loss = criterion(prediction, b_y.to(device))  # Calculating loss
            nb = b_y.shape[0]
            test_loss = test_loss + nb * loss.detach().cpu().numpy()  # Keep track of the loss
        test_loss /= len_test_dataset  # dividing by the number of batches
        #         print(len(trainloader))
        print(text + " loss:", test_loss)
    return test_loss



def plot_model_direct(net, criterion, testloader, optimizer, len_test_dataset, text="test"):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    net.to(device)
    device_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else "cpu"
    print(f"Training starts on device {device_name}, number of samples {len(testloader)}")
    
    net.eval()  # Evaluation mode (important when having dropout layers)
    test_loss = 0
    with torch.no_grad():
        for step, (batch_x, batch_y) in enumerate(
            testloader
        ):  # for each training step
            b_x = Variable(batch_x)  # Inputs
            b_y = Variable(batch_y)  # outputs
            prediction = net(b_x.to(device))
            loss = criterion(prediction, b_y.to(device))  # Calculating loss
            nb = b_y.shape[0]
            test_loss = test_loss + nb * loss.detach().cpu().numpy()  # Keep track of the loss
        test_loss /= len_test_dataset  # dividing by the number of batches
        #         print(len(trainloader))
        print(text + " loss:", test_loss)
    return b_x, b_y, prediction


criterion = torch.nn.MSELoss()  # MSE loss function

# %% [markdown]
# ## train CNN!

# %%
torch.manual_seed(14)  # For reproducibility
cnn_submeso = CNN_direct().double()

n_epochs = 100  # Number of epocs could be increased
optimizer = optim.Adam(cnn_submeso.parameters(), lr=0.1)
test_loss = list()
train_loss = list()
for epoch in range(1, n_epochs + 1):
    print("epoch:", epoch)
    train_loss.append(train_model_direct(cnn_submeso, criterion, loader_train, optimizer,len(torch_dataset_train)))
    test_loss.append(test_model_direct(cnn_submeso, criterion, loader_test, optimizer,len(torch_dataset_test)))
# Out:
# epoch: 1
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.93912577462124
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.9488645927365231
# epoch: 2
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.8953407253408505
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.9365582445266263
# epoch: 3
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.889304023193993
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.9001563520484421
# epoch: 4
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.8807974969516448
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.902262637768199
# epoch: 5
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.8687211263872546
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8849738917367056
# epoch: 6
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.8581825716783854
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.874954784826245
# epoch: 7
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.8529939380057894
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8789967547960976
# epoch: 8
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.8453856672303319
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8857700697245385
# epoch: 9
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.8481032571242405
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8650331453273885
# epoch: 10
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.8409146016692878
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8751237749551611
# epoch: 11
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.8333026106920643
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8396242807516833
# epoch: 12
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.8317453358772784
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8733861840020497
# epoch: 13
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.8241867972035516
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8364872234976506
# epoch: 14
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.8309587686657587
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.86110271192155
# epoch: 15
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.821376492286509
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8423768436348538
# epoch: 16
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.8211758695914825
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8349827740571215
# epoch: 17
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.8144477755815622
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.860011391128789
# epoch: 18
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.8126792614156758
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8534693929693459
# epoch: 19
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.8109821767528235
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8616953397119774
# epoch: 20
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.8061914253935679
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8294528701688648
# epoch: 21
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.809933624974012
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8210530226453687
# epoch: 22
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.8059171369749472
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8355813558126798
# epoch: 23
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.7981709566925782
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8302800648037671
# epoch: 24
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.7934456784369108
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8463506148301948
# epoch: 25
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.791914093956424
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.831058148950423
# epoch: 26
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.7897986820192185
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8427352750697649
# epoch: 27
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.7857782649696711
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.796419664379141
# epoch: 28
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.7840855636414543
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8266038899250047
# epoch: 29
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.7887407333768915
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8664489676288194
# epoch: 30
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.781570602215616
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7974203585316867
# epoch: 31
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.7799557055091323
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8386622847573081
# epoch: 32
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.780056560849767
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7953413444016381
# epoch: 33
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.7723648501693133
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7976567722674194
# epoch: 34
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.7718735225022739
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7861983314651523
# epoch: 35
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.7685053399019757
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7781010477707409
# epoch: 36
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.769140755277346
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7873498902728873
# epoch: 37
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.7643207029256512
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8002921615239859
# epoch: 38
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.7653688084168341
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7842247276663998
# epoch: 39
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.7605044132255446
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7725509230891909
# epoch: 40
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.7635033733630243
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7587236096879444
# epoch: 41
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.7505931080103273
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8048793738808375
# epoch: 42
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.755122642687254
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7791599742814767
# epoch: 43
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.7577480135805434
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8763036821120294
# epoch: 44
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.755927461836849
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7643060063509657
# epoch: 45
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.7474629812647449
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8702934025810464
# epoch: 46
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.7872068271644959
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7561546301103914
# epoch: 47
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.7517289314472922
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7663956828580372
# epoch: 48
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.747215733369682
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8102356656398801
# epoch: 49
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.7430054367858695
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7714589072584421
# epoch: 50
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.7405876803543753
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7754114359687004
# epoch: 51
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.7375814782928856
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7880376918648028
# epoch: 52
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.7336009414241337
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8047667866004449
# epoch: 53
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.7288059979639453
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7414481011538477
# epoch: 54
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.7405371403194343
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7455640491366684
# epoch: 55
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.7341056791433663
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7506423127681756
# epoch: 56
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.7366407849157902
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7377545700379061
# epoch: 57
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.7262498223373818
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8117761198890201
# epoch: 58
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.7304794545626533
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7462965982561398
# epoch: 59
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.7241868557265837
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7427898129149915
# epoch: 60
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.71927352553683
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7702549031059034
# epoch: 61
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.7236146646911501
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7772845187039937
# epoch: 62
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.722383777342462
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7170520364907148
# epoch: 63
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.719311832354006
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7343739204058447
# epoch: 64
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.7162646034227529
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7551324065241438
# epoch: 65
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.7170091590787929
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.8263925735040238
# epoch: 66
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.7156949483650565
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.723803965147232
# epoch: 67
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.7177155861229654
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7778639502059611
# epoch: 68
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.7123560111507724
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7270936852831696
# epoch: 69
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.7085673765224907
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7619225386078706
# epoch: 70
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.7140696723369852
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7398292490909094
# epoch: 71
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.7124202479785038
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7329844477074005
# epoch: 72
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.7059914186134072
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7249924261106349
# epoch: 73
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.6990835383537308
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7125484860068848
# epoch: 74
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.7050510681016231
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7172394911326478
# epoch: 75
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.7047782651359189
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7124155682573237
# epoch: 76
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.7095555338366694
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7230338178132489
# epoch: 77
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.6974055089010859
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7177997853479641
# epoch: 78
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.6973110421142935
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.714181781931733
# epoch: 79
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.7054281122080538
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7040170708454495
# epoch: 80
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.6930748080575344
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7114098308609669
# epoch: 81
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.6870893403952205
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7307721381452938
# epoch: 82
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.7016229091128038
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.713338306189566
# epoch: 83
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.6921508646270982
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6938841453159009
# epoch: 84
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.6860193770828271
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7012029281266248
# epoch: 85
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.6901585870875305
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7227030680029294
# epoch: 86
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.6966342393744352
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.716359306451996
# epoch: 87
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.6828386065776414
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7109786687572184
# epoch: 88
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.6864892432267344
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7186710809646185
# epoch: 89
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.6903911826715804
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7186553583135376
# epoch: 90
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.6878626357166839
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7210609325810221
# epoch: 91
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.6921112496747441
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7577211073503591
# epoch: 92
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.6868682523029092
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7053897445395376
# epoch: 93
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.6844083480053296
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7019941775153532
# epoch: 94
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.6762967655629002
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7006187301759765
# epoch: 95
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.6836478864838592
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6959065657416318
# epoch: 96
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.6882043401342234
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7066652737316127
# epoch: 97
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.6776230731373184
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7021513943198646
# epoch: 98
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.677634935731801
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.6974699303332224
# epoch: 99
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.6816113962989743
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7529716049960375
# epoch: 100
# Training starts on device Quadro RTX 8000, number of samples 108
# train loss: 0.6859895471168388
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7177248388084166

# %%
import matplotlib.pyplot as plt

plt.plot(train_loss[1:], "b", linewidth=3,label="training loss")
plt.plot(test_loss[1:], "lightblue",linewidth=3, label="test loss")
plt.xlabel('Epochs')
plt.ylabel('MSE Loss')
plt.legend();

# %%
total_params = sum(
	param.numel() for param in cnn_submeso.parameters()
)
total_params
# Out:
# 105699

# %%
b_x, b_y, prediction = plot_model_direct(cnn_submeso, criterion, loader_test, optimizer,len(torch_dataset_test))
# Out:
# Training starts on device Quadro RTX 8000, number of samples 1
# test loss: 0.7177248388084166

# %%
# compare with FK
WB_FK = np.load(PATH_NN+'WB_FK.npy')
WB_FK_test = WB_FK[test_ind]

# %%
from scipy import stats

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

corr_pred_wb = stats.pearsonr(cnn_submeso(b_x.to(device)).detach().cpu().numpy().flatten(), b_y.flatten())

print("correlation between prediction and target,  w'b':",corr_pred_wb )
# Out:
# correlation between prediction and target,  w'b': (0.5639444699841253, 0.0)

# %%
# visualize
it =3

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(12, 6))
fig.tight_layout() # Or equivalently,  "plt.tight_layout()"

plt.subplot(231)
plt.pcolor(cnn_submeso(b_x.to(device)).detach().cpu().numpy()[it,0,:,:],cmap='Blues',vmin=-2,vmax =2)
plt.title('wb prediction')
plt.colorbar()
plt.axis('off')

plt.subplot(232)
plt.pcolor(b_y[it,0,:,:],cmap='Blues',vmin=-2,vmax =2)
plt.title('wb target')
plt.colorbar()
plt.axis('off')

plt.subplot(233)
plt.pcolor(WB_FK_test[it],cmap='Blues',vmin=-2,vmax =2)
plt.title('wb FK')
plt.colorbar()
plt.axis('off')
# Out:
# (0.0, 40.0, 0.0, 40.0)

# %%
_=plt.hist(b_y.detach().cpu().numpy().flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="target")
_=plt.hist(cnn_submeso(b_x.to(device)).detach().cpu().numpy().flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="prediction")

plt.xlim([-3,3])
plt.legend()

# %%
fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(4, 10))
fig.tight_layout() # Or equivalently,  "plt.tight_layout()"

plt.subplot(311)
_=plt.hist(b_y.detach().cpu().numpy()[:,0,:,:].flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="target")
_=plt.hist(cnn_submeso(b_x.to(device)).detach().cpu().numpy()[:,0,:,:].flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="prediction")
plt.xlim([-3,3])
plt.legend()
plt.axis('off')
plt.title('ub')


plt.subplot(312)
_=plt.hist(b_y.detach().cpu().numpy()[:,1,:,:].flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="target")
_=plt.hist(cnn_submeso(b_x.to(device)).detach().cpu().numpy()[:,1,:,:].flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="prediction")
plt.xlim([-3,3])
plt.legend()
plt.axis('off')
plt.title('vb')

plt.subplot(313)
_=plt.hist(b_y.detach().cpu().numpy()[:,2,:,:].flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="target")
_=plt.hist(cnn_submeso(b_x.to(device)).detach().cpu().numpy()[:,2,:,:].flatten(),bins=500,alpha=0.5,histtype='stepfilled',label="prediction")
plt.xlim([-3,3])
plt.legend()
plt.title('wb')
plt.axis('off')
# Out:
# (-3.0, 3.0, 0.0, 8978.55)

# %%
target_da = xr.DataArray(b_y.detach().cpu().numpy(), dims=["time", "axis", "i","j"])
prediction_da = xr.DataArray(cnn_submeso(b_x.to(device)).detach().cpu().numpy(), dims=["time", "axis", "i","j"])

# %%
import xrft

# target vs prediction spectra
UsBs_target_spectra = xrft.isotropic_power_spectrum(target_da.isel(axis=0),dim=['i','j'], 
                                           detrend='linear', window=True).compute().mean('time')

UsBs_prediction_spectra = xrft.isotropic_power_spectrum(prediction_da.isel(axis=0),dim=['i','j'], 
                                           detrend='linear', window=True).compute().mean('time')


VsBs_target_spectra = xrft.isotropic_power_spectrum(target_da.isel(axis=1),dim=['i','j'], 
                                           detrend='linear', window=True).compute().mean('time')

VsBs_prediction_spectra = xrft.isotropic_power_spectrum(prediction_da.isel(axis=1),dim=['i','j'], 
                                           detrend='linear', window=True).compute().mean('time')


WsBs_target_spectra = xrft.isotropic_power_spectrum(target_da.isel(axis=2),dim=['i','j'], 
                                           detrend='linear', window=True).compute().mean('time')

WsBs_prediction_spectra = xrft.isotropic_power_spectrum(prediction_da.isel(axis=2),dim=['i','j'], 
                                           detrend='linear', window=True).compute().mean('time')
# Out:
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:47: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:1025: FutureWarning: Isotropic wavenumber larger than the Nyquist wavenumber may result.
#   warnings.warn(msg, FutureWarning)
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:47: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:1025: FutureWarning: Isotropic wavenumber larger than the Nyquist wavenumber may result.
#   warnings.warn(msg, FutureWarning)
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:47: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:1025: FutureWarning: Isotropic wavenumber larger than the Nyquist wavenumber may result.
#   warnings.warn(msg, FutureWarning)
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:47: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:1025: FutureWarning: Isotropic wavenumber larger than the Nyquist wavenumber may result.
#   warnings.warn(msg, FutureWarning)
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:47: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:1025: FutureWarning: Isotropic wavenumber larger than the Nyquist wavenumber may result.
#   warnings.warn(msg, FutureWarning)
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:47: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(
# /home/ab10313/.local/lib/python3.9/site-packages/xrft/xrft.py:1025: FutureWarning: Isotropic wavenumber larger than the Nyquist wavenumber may result.
#   warnings.warn(msg, FutureWarning)

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(4, 10))
fig.tight_layout() # Or equivalently,  "plt.tight_layout()"

plt.subplot(311)
#plt.loglog(UsBs_target_spectra.freq_r*2*np.pi, 5e-3*UsBs_target_spectra.freq_r**-2, '--',linewidth=1.5,color='black', label='k^{-2}')
#plt.loglog(UsBs_target_spectra.freq_r*2*np.pi, 2e-3*UsBs_target_spectra.freq_r**-3, '--',linewidth=1.5,color='gray', label='k^{-3}')
plt.loglog(UsBs_target_spectra.freq_r*2*np.pi, UsBs_target_spectra/UsBs_target_spectra[0],linewidth=3, label='target')
plt.loglog(UsBs_prediction_spectra.freq_r*2*np.pi, UsBs_prediction_spectra/UsBs_prediction_spectra[0],linewidth=3, label='prediction')
plt.legend()
#plt.xlabel('$k_r$')
plt.ylabel('Normalized isotropic spectra')
plt.title('UsBs')
plt.ylim([1e-3,3])

plt.subplot(312)
#plt.loglog(VsBs_target_spectra.freq_r*2*np.pi, 5e-3*VsBs_target_spectra.freq_r**-2, '--',linewidth=1.5,color='black', label='k^{-2}')
#plt.loglog(VsBs_target_spectra.freq_r*2*np.pi, 2e-3*VsBs_target_spectra.freq_r**-3, '--',linewidth=1.5,color='gray', label='k^{-3}')
plt.loglog(VsBs_target_spectra.freq_r*2*np.pi, VsBs_target_spectra/VsBs_target_spectra[0],linewidth=3, label='target')
plt.loglog(VsBs_prediction_spectra.freq_r*2*np.pi, VsBs_prediction_spectra/VsBs_prediction_spectra[0],linewidth=3, label='prediction')
plt.legend()
#plt.xlabel('$k_r$')
#plt.ylabel('Normalized isotropic spectra')
plt.title('VsBs')
plt.ylim([1e-3,3])


plt.subplot(313)
#plt.loglog(WsBs_target_spectra.freq_r*2*np.pi, 5e-3*WsBs_target_spectra.freq_r**-2, '--',linewidth=1.5,color='black', label='k^{-2}')
#plt.loglog(WsBs_target_spectra.freq_r*2*np.pi, 2e-3*WsBs_target_spectra.freq_r**-3, '--',linewidth=1.5,color='gray', label='k^{-3}')
plt.loglog(WsBs_target_spectra.freq_r*2*np.pi, WsBs_target_spectra/WsBs_target_spectra[0],linewidth=3, label='target')
plt.loglog(WsBs_target_spectra.freq_r*2*np.pi, WsBs_prediction_spectra/WsBs_prediction_spectra[0],linewidth=3, label='prediction')
plt.legend()
plt.xlabel('$k_r$')
#plt.ylabel('Normalized isotropic spectra')
plt.title('WsBs')
plt.ylim([1e-3,3])
# Out:
# (0.001, 3)
