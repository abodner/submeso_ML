# %%
import cartopy 
import glob
import matplotlib.pyplot as plt
import os
import xarray as xr
import xgcm 
from fastjmd95 import jmd95numba 
import numpy as np


BASE = '/scratch/ab10313/pleiades/'

PATH_LIST_PP = glob.glob(BASE+'*_smooth/preprcossed_data/')

# %%
PATH_LIST_PP
# Out:
# ['/scratch/ab10313/pleiades/15_bengal_smooth/preprcossed_data/',
#  '/scratch/ab10313/pleiades/12_agulhas_smooth/preprcossed_data/',
#  '/scratch/ab10313/pleiades/11_new_zealand_smooth/preprcossed_data/',
#  '/scratch/ab10313/pleiades/10_north_pacific_smooth/preprcossed_data/',
#  '/scratch/ab10313/pleiades/04_equator_atlantic_smooth/preprcossed_data/',
#  '/scratch/ab10313/pleiades/01_gulf_smooth/preprcossed_data/',
#  '/scratch/ab10313/pleiades/03_south_atlantic_smooth/preprcossed_data/',
#  '/scratch/ab10313/pleiades/05_argentina_smooth/preprcossed_data/',
#  '/scratch/ab10313/pleiades/13_australia_smooth/preprcossed_data/',
#  '/scratch/ab10313/pleiades/14_indian_ocean_smooth/preprcossed_data/']

# %%
# load CNN data 
BASE_gulf = '/scratch/ab10313/pleiades/01_gulf_smooth/'
PATH_NN_gulf = BASE_gulf+'NN_data_smooth/'
PATH_NN = BASE+'NN_data_smooth/'

X_input_gulf = np.load(PATH_NN_gulf+'X_input_gulf.npy')
Y_output_gulf = np.load(PATH_NN_gulf+'Y_output_gulf.npy')
mean_gulf = np.load(PATH_NN+'WB_sg_mean.npy')
std_gulf = np.load(PATH_NN+'WB_sg_std.npy')

prediction_gulf = np.load(PATH_NN_gulf+'prediction_gulf.npy')

# %%
plt.subplots(nrows=3, ncols=4, figsize=(30, 20))

plt.subplot(122)
    
    
plt.subplot(341)
plt.pcolor(X_input_gulf[10,0,:,:], cmap='RdBu_r')
#plt.xlabel('Longitude')
#plt.ylabel('Latitude')
#plt.colorbar()
plt.xticks([])
plt.yticks([])
#plt.title('$f$',fontsize=20)

plt.subplot(342)
plt.pcolor(X_input_gulf[10,1,:,:], cmap='RdBu_r')
#plt.xlabel('Longitude')
#plt.ylabel('Latitude')
#plt.colorbar()
plt.xticks([])
plt.yticks([])
#plt.title(r'$\overline{ \nabla b}^z$',fontsize=20)

plt.subplot(343)
plt.pcolor(X_input_gulf[10,2,:,:],  cmap='RdBu_r')
#plt.xlabel('Longitude')
#plt.ylabel('Latitude')
#plt.colorbar()
plt.xticks([])
plt.yticks([])
#plt.title(r'$H_{ML}$',fontsize=20)

plt.subplot(344)
plt.pcolor(X_input_gulf[10,3,:,:], cmap='RdBu_r')
#plt.xlabel('Longitude')
#plt.ylabel('Latitude')
#plt.colorbar()
plt.xticks([])
plt.yticks([])
#plt.title('$N^2$',fontsize=20)


plt.subplot(345)
plt.pcolor(X_input_gulf[10,4,:,:], cmap='RdBu_r')
#plt.xlabel('Longitude')
#plt.ylabel('Latitude')
#plt.colorbar()
plt.xticks([])
plt.yticks([])
#plt.title('r$\tau$',fontsize=20)

plt.subplot(346)
plt.pcolor(X_input_gulf[10,5,:,:], cmap='RdBu_r')
#plt.xlabel('Longitude')
#plt.ylabel('Latitude')
#plt.colorbar()
plt.xticks([])
plt.yticks([])
#plt.title(r'$Q$',fontsize=20)

plt.subplot(347)
plt.pcolor(-X_input_gulf[10,6,:,:], cmap='RdBu_r')
#plt.xlabel('Longitude')
#plt.ylabel('Latitude')
#plt.colorbar()
plt.xticks([])
plt.yticks([])
#plt.title('$H_{BL}$',fontsize=20)

plt.subplot(348)
plt.pcolor(X_input_gulf[10,7,:,:], cmap='RdBu_r')
#plt.xlabel('Longitude')
#plt.ylabel('Latitude')
#plt.colorbar()
plt.xticks([])
plt.yticks([])
#plt.title('div',fontsize=20)

plt.subplot(349)
plt.pcolor(X_input_gulf[10,8,:,:], cmap='RdBu_r')
#plt.xlabel('Longitude')
#plt.ylabel('Latitude')
#plt.colorbar()
plt.xticks([])
plt.yticks([])
#plt.title('vort',fontsize=20)

plt.subplot(3,4,10)
plt.pcolor(X_input_gulf[10,9,:,:], cmap='RdBu_r')
#plt.xlabel('Longitude')
#plt.ylabel('Latitude')
#plt.colorbar()
plt.xticks([])
plt.yticks([])
#plt.title('strain',fontsize=20)

plt.subplot(3,4,11)
plt.pcolor(Y_output_gulf[10,0,:,:]*std_gulf[10] + mean_gulf[10], cmap='RdBu_r',vmin=-1e-8, vmax=1e-8)
#plt.xlabel('Longitude')
#plt.ylabel('Latitude')
#plt.colorbar()
plt.xticks([])
plt.yticks([])
#plt.title('wb',fontsize=20)

#[FCOR, grad_B, HML, Nsquared, TAU, Q, HBL, div, vort, strain]

plt.savefig('./figures/input_output.png')
